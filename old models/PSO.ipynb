# %% [markdown]
# # Importing libraries

# %%
# %pip install osmnx
# %pip install rasterio
# %pip install rasterstats
# %pip install contextily
# %pip install geopandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: osmnx in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.9.4)
# Requirement already satisfied: numpy<1.27,>=1.20 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (1.26.4)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (3.2.1)
# Requirement already satisfied: geopandas<0.15,>=0.12 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (0.14.4)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely<2.1,>=2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.0.6)
# Requirement already satisfied: pandas<2.3,>=1.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.2.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: packaging in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (24.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (1.10.1)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (2024.2.2)
# Requirement already satisfied: click~=8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (7.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (24.2.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click~=8.0->fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (0.4.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=1.1->osmnx) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: rasterio in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.4.2)
# Requirement already satisfied: click>=4.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (7.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (24.2.0)
# Requirement already satisfied: pyparsing in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (3.1.2)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->rasterio) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: rasterstats in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.20.0)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (2.4.0)
# Requirement already satisfied: simplejson in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (3.20.1)
# Requirement already satisfied: numpy>=1.9 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.26.4)
# Requirement already satisfied: shapely in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (2.0.6)
# Requirement already satisfied: rasterio>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.4.2)
# Requirement already satisfied: cligj>=0.4 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (0.7.2)
# Requirement already satisfied: fiona in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.10.1)
# Requirement already satisfied: click>7.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (8.1.7)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>7.1->rasterstats) (0.4.6)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (24.2.0)
# Requirement already satisfied: pyparsing in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (3.1.2)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (7.1.0)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (1.1.1)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->rasterio>=1.0->rasterstats) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: contextily in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.6.2)
# Requirement already satisfied: matplotlib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (3.9.2)
# Requirement already satisfied: joblib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.3.2)
# Requirement already satisfied: geopy in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: requests in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2024.9.0)
# Requirement already satisfied: pillow in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (10.2.0)
# Requirement already satisfied: rasterio in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.4.2)
# Requirement already satisfied: mercantile in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (24.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (4.50.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (6.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->contextily) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Requirement already satisfied: click>=3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (2024.2.2)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (7.1.0)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (3.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.14.4)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (2.2.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: packaging in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (24.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (24.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (7.1.0)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.9.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import networkx as nx
import numpy as np
import pandas as pd
import random
from shapely.geometry import box
import contextily as ctx
import rasterio
from scipy.spatial import cKDTree
from rasterstats import zonal_stats
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString

# %% [markdown]
# # Data

# %%
EV_ukr = 135200
population_ukr = 31000000
EV_per_capita_ukr = EV_ukr/population_ukr
print("Number of EV per capita:", round(EV_per_capita_ukr, 5))
# Out:
# Number of EV per capita: 0.00436

# %%
city_data_lviv = {
    "place": 'Lviv, Ukraine',
    "grid_size": 0.0125,
    "EV_per_capita": EV_per_capita_ukr,
    "distance_matrix": "distance_matrix_lviv1.npy",
    "raster_file_population": "ukr_ppp_2020_constrained.tif"
}

EV_data_lviv = {
    "avg_consumption_per_km": 159.9,
    "avg_distance_per_day": 33,
    "max_distance_to_charger": 3000
}

CS_data_lviv = {
    "energy_loss": 0.01,
    "station_utilization_rate": 0.15,
    "max_stations_num": 4,
    "CS_list": ["Level_2 7.4kW", "Level_2 22kW", "Level_2 50kW", "Level_3 60kW", "Level_3 120kW", "Level_3 160kW"],
    "Level_2 7.4kW": {"cost":2000, "capacity":7.4*1000, "voltage": 240},
    "Level_2 22kW": {"cost":5000, "capacity":22*1000, "voltage": 240},
    "Level_2 50kW": {"cost":7200, "capacity":50*1000, "voltage": 240},
    "Level_3 60kW": {"cost":10000, "capacity":60*1000, "voltage": 480},
    "Level_3 120kW": {"cost":30000, "capacity":120*1000, "voltage": 480},
    "Level_3 160kW": {"cost":50000, "capacity":160*1000, "voltage": 480},
    "installed_stations": "station_location_lviv.csv"
}

model_parameters_lviv = {
    "alpha": 10,
    "beta": 0.001,
    "gamma": 1,
    "lambda": 20,
    "iterations":100,
    "w": 0.3,
    "c1": 1.5,
    "c2": 1.5,
}

# %%
city_data = city_data_lviv
EV_data = EV_data_lviv
CS_data = CS_data_lviv
model_parameters = model_parameters_lviv

# %% [markdown]
# # City graph

# %%
G = ox.graph_from_place(city_data["place"], network_type="drive")

# %%
ox.plot_graph(G, node_size=5)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Adding installed charging stations

# %% [markdown]
# **The form in which installed stations are presented:**\
# $y\ =\ \{$ \
# $\ \ \ \ (i, station\_capacity): n$ \
# $\}$
#
# Where\
# $i$ - node_id,\
# $n$ - number of stations (of this type) in the node $i$

# %%
def add_charging_stations(G, CS_data, visualization = True):
    charging_stations = pd.read_csv(CS_data["installed_stations"], sep = ";")
    # print(charging_stations.head())
    installed_cs = dict()
    installed_cs_list = []
    for row_index in range(len(charging_stations)):
        latitude = charging_stations['X'][row_index]
        longitude = charging_stations['Y'][row_index]
        num_of_chargers = charging_stations['Number'][row_index]
        cs_capacity = charging_stations['Capacity'][row_index]
        station_point = Point(longitude, latitude)

        # Найближче ребро (u, v, key) and its geometry
        u, v, key = ox.distance.nearest_edges(G, longitude, latitude)

        edge_data = G.get_edge_data(u, v, key)
        geom = edge_data.get("geometry", LineString([(G.nodes[u]['x'], G.nodes[u]['y']),
                                                    (G.nodes[v]['x'], G.nodes[v]['y'])]))

        # Найближча точка на ребрі
        line = LineString(geom)
        closest_point = line.interpolate(line.project(station_point))
        # new_node_id = (closest_point.x, closest_point.y)
        new_node_id = max(G.nodes) + 1
        G.add_node(new_node_id, x=closest_point.x, y=closest_point.y)

        # Поділ ребра на два ребра
        if G.has_edge(u, v, key):
            G.remove_edge(u, v, key)
            G.add_edge(u, new_node_id, length=line.project(closest_point))
            G.add_edge(new_node_id, v, length=line.length - line.project(closest_point))
        
        if G.has_edge(v, u, key):
            G.remove_edge(v, u, key)
            G.add_edge(v, new_node_id, length=line.project(closest_point))
            G.add_edge(new_node_id, u, length=line.length - line.project(closest_point))

        if new_node_id not in installed_cs_list:
            installed_cs_list.append(new_node_id)
        installed_cs[(new_node_id, cs_capacity)] = num_of_chargers

    if visualization:
        pos = {node: (data['x'], data['y']) for node, data in G.nodes(data=True)}
        G_lviv_undirected = G.to_undirected()
        G_lviv_undirected.remove_edges_from(nx.selfloop_edges(G_lviv_undirected))
        fig, ax = plt.subplots(figsize=(12, 9), facecolor="black")

        nx.draw(G_lviv_undirected, pos, node_size=3, with_labels=False, node_color="white", edge_color="white", ax=ax)
        nx.draw_networkx_nodes(
        G_lviv_undirected, pos, nodelist=installed_cs_list, node_size=10, node_color="orange", label="Installed Stations", ax=ax)

        legend = plt.legend(scatterpoints=1, frameon=True, loc="upper right", facecolor="black", edgecolor="white", bbox_to_anchor=(1.5, 1))
        for text in legend.get_texts():
            text.set_color("white")

        plt.title("Graph with Installed Stations", color="white")
        ax.axis("off")
        fig.patch.set_facecolor("black")
        ax.set_facecolor("black")
        plt.tight_layout()
        plt.show()
    return G, installed_cs, installed_cs_list

# %% [markdown]
# # Capacity demand prediction

# %% [markdown]
# ### Division into sectors

# %%
def division_into_secors(city_data):
    city_boundary = ox.geocode_to_gdf(city_data["place"])

    xmin, ymin, xmax, ymax = city_boundary.total_bounds
    grid_size = 0.0125

    grid_cells = []
    for x in np.arange(xmin, xmax, grid_size):
        for y in np.arange(ymin, ymax, grid_size):
            grid_cells.append(box(x, y, x + grid_size, y + grid_size))

    grid = gpd.GeoDataFrame(geometry=grid_cells, crs=city_boundary.crs)
    map_with_grid = gpd.clip(grid, city_boundary)

    # ax = map_with_grid.plot(edgecolor="rosybrown", facecolor="none", figsize=(10, 10))
    # city_boundary.boundary.plot(ax=ax, color="maroon")
    # ctx.add_basemap(ax, crs=city_boundary.crs, source=ctx.providers.CartoDB.Positron)
    return map_with_grid, city_boundary

# %% [markdown]
# Assigning graph nodes to a grid cell (region)

# %%
def nodes_to_region(G, map_with_grid):
    nodes_gdf, edges_gdf = ox.graph_to_gdfs(G, nodes=True, edges=True)
    nodes_gdf = nodes_gdf.set_geometry(nodes_gdf.geometry)

    nodes_in_grid = gpd.sjoin(nodes_gdf, map_with_grid, how="left", predicate="within")
    nodes_in_grid = nodes_in_grid.reset_index()

    # Handling nodes that are not assigned to any grid cell. Creating node to region dictionary and region to nodes dictiionary
    assigned_nodes = nodes_in_grid.dropna(subset=['index_right']) 
    missing_nodes = nodes_in_grid[nodes_in_grid['index_right'].isna()]

    tree = cKDTree(assigned_nodes[['x', 'y']].values)
    _, nearest_idx = tree.query(missing_nodes[['x', 'y']].values)

    nodes_in_grid.loc[nodes_in_grid['index_right'].isna(), 'index_right'] = assigned_nodes.iloc[nearest_idx]['index_right'].values
    nodes_in_grid['index_right'] = nodes_in_grid['index_right'].astype(int)

    # region -> list of nodes
    region_to_nodes = nodes_in_grid.groupby(nodes_in_grid.index_right)['osmid'].apply(list).to_dict()
    # node -> region DI
    node_to_region = nodes_in_grid.set_index('osmid')['index_right'].to_dict()
    regions = [region for region in region_to_nodes]
    return regions, region_to_nodes, node_to_region

# %%
# map_with_grid = map_with_grid.to_crs(epsg=4326)
# edges_gdf = edges_gdf.to_crs(map_with_grid.crs)
# fig, ax = plt.subplots(figsize=(12, 10))

# map_with_grid.plot(ax=ax, edgecolor="gray", facecolor="none", linewidth=0.5, alpha=0.7, label="Grid")

# edges_gdf.plot(ax=ax, color="darkgray", linewidth=1, alpha=0.8, label="Road Network")
# nodes_gdf.plot(ax=ax, color="red", markersize=5, alpha=0.6, label="Nodes")

# ctx.add_basemap(ax, crs=map_with_grid.crs, source=ctx.providers.CartoDB.Positron)

# ax.set_title(f"Road Network and Grid Overlay in {city_data['place']}", fontsize=14)
# ax.legend()
# plt.show()

# %% [markdown]
# ### Demand estimation for each region

# %%
def demand_estimation(map_with_grid, city_boundary, city_data, visualization = False):

    # Population count for each sector
    raster_file_population = city_data["raster_file_population"]
    with rasterio.open(raster_file_population) as data:
        affine = data.transform
        array = data.read(1)
    stats = zonal_stats(map_with_grid, raster_file_population, stats=["sum"], affine=affine)
    map_with_grid["population"] = [s["sum"] if s["sum"] is not None else 0 for s in stats]
    map_with_grid["density"] = map_with_grid["population"] / map_with_grid.geometry.area

    # Calculation of the number of EV for each sector
    map_with_grid["EV"] = map_with_grid["population"] *city_data["EV_per_capita"]

    # Calculation of charging capacity demand in each region
    avg_consumption_per_km = EV_data["avg_consumption_per_km"] #Wh/km
    avg_distance_per_day = EV_data["avg_distance_per_day"] #km
    energy_loss = CS_data["energy_loss"]
    station_utilization_rate = CS_data["station_utilization_rate"]

    map_with_grid["daily_energy_consumption"] = avg_consumption_per_km * avg_distance_per_day * map_with_grid["EV"]
    map_with_grid["charging_capacity_demand"] = map_with_grid["daily_energy_consumption"]/((1-energy_loss)*station_utilization_rate)

    # Creating region to capacity demand dictionary
    map_with_grid = map_with_grid.reset_index()
    region_to_capacity_demand = dict()
    for grid_cell in range(len(map_with_grid)):
        region_id = map_with_grid.iloc[grid_cell]['index']
        charging_demand = map_with_grid.iloc[grid_cell]['charging_capacity_demand']
        region_to_capacity_demand[region_id] = charging_demand

    # Visualization
    if visualization:
        ax = map_with_grid.plot(column="charging_capacity_demand", cmap="OrRd", edgecolor="rosybrown", legend=True, figsize=(12, 10), alpha =0.6)
        city_boundary.boundary.plot(ax=ax, color="maroon")
        ctx.add_basemap(ax, crs=map_with_grid.crs, source=ctx.providers.CartoDB.Positron)
    
    return region_to_capacity_demand

# %%
# ax = map_with_grid.plot(column="charging_capacity_demand", cmap="OrRd", edgecolor="rosybrown", legend=True, figsize=(12, 10), alpha =0.6)
# city_boundary.boundary.plot(ax=ax, color="maroon")
# ctx.add_basemap(ax, crs=map_with_grid.crs, source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# # Distance matrix

# %%
def calculate_distamnce_matrix(G, nodes):
    nodes = G.nodes
    n = len(nodes)
    print(n)
    node_index = {node: idx for idx, node in enumerate(nodes)}

    D = np.full((n, n), np.inf)

    for u, v, data in G.edges(data=True):
        length = data.get("length", np.inf)
        i, j = node_index[u], node_index[v]
        D[i, j] = length

    for i in range(n): 
        D[i, i] = 0
    
    for k in range(n):
        print(k)
        for i in range(n):
            for j in range(n):
                D[i,j] = min (D[i, j], D[i, k] + D[k, j])
    return D

# %%
def distance_matrix(G, city_data):
    if city_data["distance_matrix"]:
        return np.load(city_data["distance_matrix"])
    return calculate_distamnce_matrix(G)

# %% [markdown]
# Faster method

# %%
from scipy.sparse.csgraph import floyd_warshall
# G = ox.graph_from_place('Dnipro, Ukraine', network_type='drive')
def distance_matrix1(G):
    nodes = list(G.nodes)
    n = len(nodes)
    print(f"Number of nodes: {n}")

    node_index = {node: idx for idx, node in enumerate(nodes)}
    print("Creating adjacency matrix")
    # Create adjacency matrix
    D = np.full((n, n), np.inf)

    for u, v, data in G.edges(data=True):
        length = data.get("length", np.inf)
        i, j = node_index[u], node_index[v]
        D[i, j] = length
        # D[j, i] = length  # Add for undirected graphs

    np.fill_diagonal(D, 0)  # Set diagonal to 0
    print("Using optimized Floyd-Warshall")
    # Use optimized Floyd-Warshall
    D = floyd_warshall(D, directed=True)  # False for undirected graphs
    np.save("distance_matrix_lviv1.npy", D)
    return D
# np.save("distance_matrix_lviv1.npy", distance_matrix1(G))

# %% [markdown]
# # Power grid constraints

# %% [markdown]
# # Particle Swarm Optimization

# %% [markdown]
# **The form in which the solution is presented:**\
# $x\ =\ \{$ \
# $\ \ \ \ (i, 'station\_type'): n$ \
# $\}$
#
# Where\
# $i$ - node_id,\
# $n$ - number of stations (of this type) in the node $i$

# %%
# x = {
#     (i, "level_2_22kw"): 0 for i in range (N)
# }

# %% [markdown]
# ## Initialization

# %% [markdown]
# - 30 solutions
# - 5-100 random stations for each solution
# - random cs type

# %%
def initialize_particles(nodes, station_types, num_particle = 30):
    particles = []
    velocities = []
    for i in range(num_particle):
        solution = {}
        # solution = {(node, cs_type):0 for cs_type in station_types for node in nodes}
        # print(solution)

        velocity = {}
        for node in random.sample(nodes, k=random.randint(5, 100)):
            cs_type = random.choice(station_types)
            cs_number = random.choices([1,2,3], [0.6, 0.3, 0.1])[0]
            solution[(node, cs_type)] = cs_number
            velocity[(node, cs_type)] = 0
        particles.append(solution)
        velocities.append(velocity)
    return particles, velocities

# %% [markdown]
# ## Fitness Evaluation

# %% [markdown]
# ### 1) CS cost evaluation

# %% [markdown]
# Total CS cost:\
# $cs\_cost = \sum^N_{i=1}\sum_{n \in cs\_type} cost_{n,i}*X_{n,i}$

# %%
def cs_cost_penalty(solution, CS_data):
    total_cost = 0
    for charging_station in solution:
        cs_type = charging_station[1]
        cost = CS_data[cs_type]["cost"]
        number_of_stations = solution[charging_station]
        total_cost += cost*number_of_stations
    return total_cost

# %% [markdown]
# ### 2) Coverage penalty evaluation

# %% [markdown]
# Coverage penalty takes into account how much the predicted demand for total capacity is greater than the total solution capacity, and it also takes into account how much the average distance from each node to the nearest charging station is greater than the desired maximum distance to charging stations

# %% [markdown]
# $coverage\_penalty = \frac{estimated\_demand}{total\_capacity} + \lambda*\frac{dist\_to\_closest\_cs}{max\_dist}$

# %%
def calculate_capacity_penalty(solution, region_to_capacity_demand, node_to_region, CS_data, installed_stations):

    capacity_penalty = 0
    region_total_capacity = {region: 0 for region in region_to_capacity_demand}

    # Calculating total capacity for each region
    for charging_station in solution:
        node = charging_station[0]
        cs_type = charging_station[1]
        cs_number = solution[charging_station]
        region = node_to_region[node]
        region_total_capacity[region] = region_total_capacity[region] + CS_data[cs_type]["capacity"]*cs_number

    if installed_stations:
        for charging_station in installed_stations:
            node = charging_station[0]
            cs_capacity = charging_station[1]
            cs_number = installed_stations[charging_station]
            region = node_to_region[node]
            region_total_capacity[region] = region_total_capacity[region] + cs_capacity*cs_number

    # Calculating capacity penalty
    for region in region_to_capacity_demand:
        capacity_penalty +=  region_to_capacity_demand[region]/(region_total_capacity[region]+0.001) # +0.001 to avoid division by zero
    return capacity_penalty

# %%
def calculate_distance_penalty(solution, nodes_dict, distance_matrix, max_distance, installed_stations):
    
    total_distance_to_stations = 0
    distance_penalty = 0 
    nodes = list(nodes_dict.keys())
    # Calculating total distance from each node to closest charging station
    for node in nodes:
        distance_list = []
        for charging_station in solution:
            cs_node = charging_station[0]
            # Using nodes_dict to determine node index in distance matrix
            distance = distance_matrix[nodes_dict[node], nodes_dict[cs_node]]
            if distance != float('inf'):
                distance_list.append(distance_matrix[nodes_dict[node], nodes_dict[cs_node]])
        
        if installed_stations:
            for charging_station in installed_stations:
                cs_node = charging_station[0]
                distance = distance_matrix[nodes_dict[node], nodes_dict[cs_node]]
                if distance != float('inf'):
                    distance_list.append(distance_matrix[nodes_dict[node], nodes_dict[cs_node]])
        if len(distance_list)>0:
            total_distance_to_stations += min(distance_list)

    # Calculating distance penalty
    distance_penalty = total_distance_to_stations/(max_distance*len(nodes))
    return distance_penalty

# %%
def coverage_penalty(solution, distance_matrix, region_to_capacity_demand, nodes_dict, lambda_parameter, node_to_region, max_distance, CS_data, installed_stations = None):

    capacity_penalty = calculate_capacity_penalty(solution, region_to_capacity_demand, node_to_region, CS_data, installed_stations)
    # print("Capacity penalty:", capacity_penalty)
    distance_penalty = calculate_distance_penalty(solution, nodes_dict, distance_matrix ,max_distance, installed_stations)
    # print("Distance penalty:", distance_penalty)

    penalty = capacity_penalty + lambda_parameter*distance_penalty
    # print("Total coverage penalty:", penalty)
    return penalty

# %% [markdown]
# ### 3) Grid loss

# %%
def total_grid_loss(solution):
    return 1

# %% [markdown]
# ### Evaluation function

# %% [markdown]
# $evaluation = \alpha*cs\_cost + \beta*coverage\_penalty + \gamma*grid\_loss$

# %%
def evaluate_fitness(solution, parameters, CS_data, EV_data, distance_matrix, region_to_capacity_demand, node_to_region, nodes_dict, installed_stations):
    alpha = parameters["alpha"]
    beta = parameters["beta"]
    gamma = parameters["gamma"]
    lambdaa = parameters["lambda"]

    cs_cost = cs_cost_penalty(solution, CS_data)
    # print("Cost penalty:", cs_cost)
    coverage = coverage_penalty(solution, distance_matrix, region_to_capacity_demand, nodes_dict,\
                                        lambdaa, node_to_region, EV_data["max_distance_to_charger"], CS_data, installed_stations)
    # print(coverage)
    grid_loss = total_grid_loss(solution)
    # print("Grid loss:", grid_loss)

    fitness = alpha*cs_cost + beta*coverage + gamma*grid_loss
    return fitness, alpha*cs_cost, beta*coverage, gamma*grid_loss

# %% [markdown]
# ## Update velocities of particles

# %% [markdown]
# $v^{t+1}_i = w * v^t_i + c_1*r_1(p_{best} - x_i) + c_2*r_2(g_{best} - x_i) $
#
# - $w$ - inertia weight (controls exploration vs exploitation)\
# - $c_1$, $c_2$ - acceleration coefficients (how strongly the particle moves toward the best positions)\
# - $r_1$, $r_2$  - random numbers (to add stochastic behavior)\
# - $x_i$ - current position of the particle\
# - $v_i$ - current velocity of the particle\
# - $p_best$ - best position found by the particle\
# - $g_best$ - best position found by any particle

# %%
def update_velocity(particle, velocity, personal_best, global_best, model_parameters):
    w = model_parameters["w"]
    c1 = model_parameters["c1"]
    c2 = model_parameters["c2"]

    new_velocity = dict()
    all_stations = set(particle.keys())
    all_stations = all_stations.union(personal_best.keys())
    all_stations = all_stations.union(global_best.keys())
    for station in all_stations:

        if station in personal_best:
            p_best_ports = personal_best[station]
        else:
            p_best_ports = 0

        if station in global_best:
            g_best_ports = global_best[station]
        else:
            g_best_ports = 0

        if station in particle:
            particle_ports = particle[station]
        else:
            particle_ports = 0

        p_best_diff = p_best_ports - particle_ports
        g_best_diff = g_best_ports - particle_ports
        
        new_velocity[station] = int(w * velocity.get(station, 0) + c1 * random.random() * p_best_diff + c2 * random.random() * g_best_diff)

    return new_velocity

# %% [markdown]
# ## Update positions of particles

# %% [markdown]
# $x^{t+1}_i = x^t_i + v^{t+1}_i$

# %%
def update_particle(particle, velocity, max_ports_per_node):
    new_particle = particle.copy()
    all_stations = velocity.keys()
    total_ports_in_node = {cs_node: 0 for cs_node, cs_type in all_stations}
    for station in new_particle.keys():
        total_ports_in_node[station[0]] = total_ports_in_node[station[0]] + new_particle[station]

    for station in all_stations:
        change = velocity[station]
        cs_node = station[0]

        ports_in_node = total_ports_in_node[cs_node]
        if station in new_particle.keys():
            cs_ports = new_particle[station]
        else: 
            cs_ports = 0

        new_cs_ports = max(0, cs_ports + min(change, max_ports_per_node - ports_in_node))
        new_particle[station] = new_cs_ports
        total_ports_in_node[cs_node] = total_ports_in_node[cs_node] + new_cs_ports - ports_in_node

        if new_particle[station] == 0:
            new_particle.pop(station)
        
    return new_particle

# %% [markdown]
# ## Check constraints

# %%
def check_constraints(_):
    return True

# %% [markdown]
# ## Fitness plot

# %%
def plot_fitness(fitness_list):
    plt.figure(figsize=(7, 5))
    plt.plot(range(len(fitness_list)), fitness_list)
    plt.xlabel('Iteration')
    plt.ylabel('Best fitness')
    plt.title('Fitness value of the best solution for each iteration')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## PSO

# %%
def PSO_algorithm(G, dist_matrix, EV_data, CS_data, model_parameters, region_to_capacity_demand, node_to_region, installed_cs = False):
    nodes = list(G.nodes)
    nodes_dict = {nodes[i]: i for i in range(len(nodes))}

    particles, velocities = initialize_particles(nodes, CS_data["CS_list"], num_particle = 30)
    p_best = particles.copy()
    p_best_fitness = [evaluate_fitness(particle, model_parameters, CS_data, EV_data, dist_matrix,\
                                    region_to_capacity_demand, node_to_region, nodes_dict, installed_cs)[0] for particle in particles]
    g_best = p_best[np.argmin(p_best_fitness)]
    g_best_fitness = min(p_best_fitness)

    iterations = model_parameters["iterations"]

    _, fitness_cost, fitness_coverage, fitness_loss = evaluate_fitness(g_best, model_parameters, CS_data, EV_data, dist_matrix,\
                                    region_to_capacity_demand, node_to_region, nodes_dict, installed_cs)
    best_fitness_list = [[g_best_fitness, fitness_cost, fitness_coverage, fitness_loss]]
    
    for iteration in range(iterations):
        print("Iteration", iteration + 1, "/", iterations)

        for i in range(len(particles)):
            velocities[i] = update_velocity(particles[i], velocities[i], p_best[i], g_best, model_parameters)
            particles[i] = update_particle(particles[i], velocities[i], CS_data["max_stations_num"])
            current_fitness = evaluate_fitness(particles[i], model_parameters, CS_data, EV_data, dist_matrix,\
                                    region_to_capacity_demand, node_to_region, nodes_dict, installed_cs)[0]
            
            if current_fitness < p_best_fitness[i]:
                p_best[i] = particles[i]
                p_best_fitness[i] = current_fitness

            if current_fitness < g_best_fitness:
                g_best = particles[i]
                g_best_fitness = current_fitness
        _, fitness_cost, fitness_coverage, fitness_loss = evaluate_fitness(g_best, model_parameters, CS_data, EV_data, dist_matrix,\
                                    region_to_capacity_demand, node_to_region, nodes_dict, installed_cs)
        best_fitness_list.append([g_best_fitness, fitness_cost, fitness_coverage, fitness_loss])
        print(f"Best Fitness = {g_best_fitness}")
    # plot_fitness(best_fitness_list)

    return g_best, best_fitness_list

# %% [markdown]
# ## Visualization

# %%
def visualize_solution(solution, G, installed_cs_list = None):

    cs_lists_by_type = dict()
    for charging_station in solution:
        cs_node = charging_station[0]
        cs_type = charging_station[1]
        if cs_type in list(cs_lists_by_type.keys()):
            cs_lists_by_type[cs_type].append(cs_node)
        else:
            cs_lists_by_type[cs_type] = [cs_node]


    pos = {node: (data['x'], data['y']) for node, data in G.nodes(data=True)}
    G_undirected = G.to_undirected()
    G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))
    fig, ax = plt.subplots(figsize=(12, 9), facecolor="black")

    nx.draw(G_undirected, pos, node_size=5, with_labels=False, node_color="white", edge_color="white", ax=ax)
    
    # Installed stations
    if installed_cs_list:
        nx.draw_networkx_nodes(
            G_undirected, pos, nodelist=installed_cs_list, node_size=20, node_color="orange", label="Initially Installed Stations", ax=ax
        )

    for cs_type in cs_lists_by_type:
        nx.draw_networkx_nodes(
            G_undirected, pos, nodelist=cs_lists_by_type[cs_type], node_size=20, node_color="red", label=f"{cs_type} Stations", ax=ax
        )


    legend = plt.legend(scatterpoints=1, frameon=True, loc="upper right", facecolor="black", edgecolor="white", bbox_to_anchor=(1.5, 1))
    for text in legend.get_texts():
        text.set_color("white")

    plt.title("Graph with Stations", color="white")
    ax.axis("off")

    fig.patch.set_facecolor("black")
    ax.set_facecolor("black")

    plt.tight_layout()
    plt.show()

# %%
def visualize_nodes(node_list, G):

    pos = {node: (data['x'], data['y']) for node, data in G.nodes(data=True)}
    G_undirected = G.to_undirected()
    G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))
    fig, ax = plt.subplots(figsize=(12, 9), facecolor="black")

    nx.draw(G_undirected, pos, node_size=1, with_labels=False, node_color="white", edge_color="white", ax=ax)

    nx.draw_networkx_nodes(
        G_undirected, pos, nodelist=node_list, node_size=30, node_color="green", label="Level 2 Stations", ax=ax
    )

    legend = plt.legend(scatterpoints=1, frameon=True, loc="upper right", facecolor="black", edgecolor="white", bbox_to_anchor=(1.5, 1))
    for text in legend.get_texts():
        text.set_color("white")

    plt.title("Graph", color="white")
    ax.axis("off")

    fig.patch.set_facecolor("black")
    ax.set_facecolor("black")

    plt.tight_layout()
    plt.show()

# %%
def plot_models_fitness(best_fitness_lists, parameters):
    m = len(best_fitness_lists)
    plt.figure(figsize=(15, 10))

    for i in range(m):
        
        fitness_list = best_fitness_lists[i]
        fitness = [iteration[0] for  iteration in fitness_list]
        fitness_cost = [iteration[1] for  iteration in fitness_list]
        fitness_coverage = [iteration[2] for  iteration in fitness_list]
        fitness_grid_loss = [iteration[3] for  iteration in fitness_list]
        n = parameters["iterations"] + 1

        plt.subplot((m+1)//2, 2, i+1)
        plt.plot(range(n), fitness, label = "Total evaluation")
        plt.plot(range(n), fitness_cost, label = f"Cost evaluation, weight = {parameters['alpha']}")
        plt.plot(range(n), fitness_coverage, label = f"Coverage evaluation, weight = {parameters['beta']}")
        plt.plot(range(n), fitness_grid_loss, label = f"Grid loss evaluation, weight = {parameters['gamma']}")

        plt.xlabel('Iteration')
        plt.ylabel('Best fitness')
        plt.title(f'Fitness values of the best solution for each iteration for PSO model №{i+1}')
        plt.grid(True)
        plt.legend()

    # plt.figure(figsize=(12, 7))
    # for i in range(n):
    #     plt.plot(range(len(best_fitness_lists[i])), best_fitness_lists[i], label = f"model № {i+1}")
    # plt.xlabel('Iteration')
    # plt.ylabel('Best fitness')
    # plt.title('Fitness value of the best solution for each iteration')
    # plt.grid(True)
    # plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # PSO model

# %%
def PSO_model(city_data, EV_data, CS_data, model_parameters, n = 4):
    # Graph
    G = ox.graph_from_place(city_data["place"], network_type="drive")

    # Adding installed stations
    G, installed_cs, installed_cs_list = add_charging_stations(G, CS_data, visualization = False)

    # Calculating distance matrix
    dist_matrix = distance_matrix(G, city_data)
    # Division into sectors + demand estimation
    map_with_grid, city_boundary = division_into_secors(city_data)
    regions, region_to_nodes, node_to_region = nodes_to_region(G, map_with_grid)
    region_to_capacity_demand = demand_estimation(map_with_grid, city_boundary, city_data, visualization = False)
    
    # GA
    best_fitness_lists = []
    for i in range(n):
        best_solution, best_fitness_list = PSO_algorithm(G, dist_matrix, EV_data, CS_data, model_parameters,\
                                        region_to_capacity_demand, node_to_region, installed_cs = installed_cs)
        best_fitness_lists.append(best_fitness_list)
    # Visualization
    plot_models_fitness(best_fitness_lists, model_parameters)
    visualize_solution(best_solution, G, installed_cs_list)
    return best_solution

# %%
PSO_model(city_data, EV_data, CS_data, model_parameters, n = 4)
# Out:
# C:\Users\tetia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\shapely\linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# C:\Users\tetia\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\shapely\linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# C:\Users\tetia\AppData\Local\Temp\ipykernel_29560\822576114.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_with_grid["density"] = map_with_grid["population"] / map_with_grid.geometry.area
# Iteration 1 / 100
# Best Fitness = 49373343.564122684
# Iteration 2 / 100
# Best Fitness = 41612758.31116499
# Iteration 3 / 100
# Best Fitness = 41612758.31116499
# Iteration 4 / 100
# Best Fitness = 36239071.5011551
# Iteration 5 / 100
# Best Fitness = 36239071.5011551
# Iteration 6 / 100
# Best Fitness = 33876067.76683268
# Iteration 7 / 100
# Best Fitness = 33389442.75665933
# Iteration 8 / 100
# Best Fitness = 32267262.78717887
# Iteration 9 / 100
# Best Fitness = 31501472.674656935
# Iteration 10 / 100
# Best Fitness = 29684237.38674695
# Iteration 11 / 100
# Best Fitness = 29684237.38674695
# Iteration 12 / 100
# Best Fitness = 28948813.638667382
# Iteration 13 / 100
# Best Fitness = 28884824.49259954
# Iteration 14 / 100
# Best Fitness = 28140593.46082676
# Iteration 15 / 100
# Best Fitness = 28112940.70759594
# Iteration 16 / 100
# Best Fitness = 27829053.80399137
# Iteration 17 / 100
# Best Fitness = 27829053.80399137
# Iteration 18 / 100
# Best Fitness = 27516237.158109576
# Iteration 19 / 100
# Best Fitness = 27462824.665567208
# Iteration 20 / 100
# Best Fitness = 27348468.35059487
# Iteration 21 / 100
# Best Fitness = 27242824.91682143
# Iteration 22 / 100
# Best Fitness = 27242824.91682143
# Iteration 23 / 100
# Best Fitness = 27222824.968679737
# Iteration 24 / 100
# Best Fitness = 27128468.637390886
# Iteration 25 / 100
# Best Fitness = 27108468.64836288
# Iteration 26 / 100
# Best Fitness = 27108468.64836288
# Iteration 27 / 100
# Best Fitness = 27108468.64836288
# Iteration 28 / 100
# Best Fitness = 27108468.64836288
# Iteration 29 / 100
# Best Fitness = 27108468.64836288
# Iteration 30 / 100
# Best Fitness = 27108468.64836288
# Iteration 31 / 100
# Best Fitness = 27108468.64836288
# Iteration 32 / 100
# Best Fitness = 27108468.64836288
# Iteration 33 / 100
# Best Fitness = 27108468.64836288
# Iteration 34 / 100
# Best Fitness = 27108468.64836288
# Iteration 35 / 100
# Best Fitness = 27108468.64836288
# Iteration 36 / 100
# Best Fitness = 27108468.64836288
# Iteration 37 / 100
# Best Fitness = 27108468.64836288
# Iteration 38 / 100
# Best Fitness = 27108468.64836288
# Iteration 39 / 100
# Best Fitness = 27108468.64836288
# Iteration 40 / 100
# Best Fitness = 27108468.64836288
# Iteration 41 / 100
# Best Fitness = 27108468.64836288
# Iteration 42 / 100
# Best Fitness = 27108468.64836288
# Iteration 43 / 100
# Best Fitness = 27108468.64836288
# Iteration 44 / 100
# Best Fitness = 27108468.64836288
# Iteration 45 / 100
# Best Fitness = 27108468.64836288
# Iteration 46 / 100
# Best Fitness = 27108468.64836288
# Iteration 47 / 100
# Best Fitness = 27108468.64836288
# Iteration 48 / 100
# Best Fitness = 27108468.64836288
# Iteration 49 / 100
# Best Fitness = 27108468.64836288
# Iteration 50 / 100
# Best Fitness = 27108468.64836288
# Iteration 51 / 100
# Best Fitness = 27108468.64836288
# Iteration 52 / 100
# Best Fitness = 27108468.64836288
# Iteration 53 / 100
# Best Fitness = 27108468.64836288
# Iteration 54 / 100
# Best Fitness = 27108468.64836288
# Iteration 55 / 100
# Best Fitness = 27108468.64836288
# Iteration 56 / 100
# Best Fitness = 27108468.64836288
# Iteration 57 / 100
# Best Fitness = 27108468.64836288
# Iteration 58 / 100
# Best Fitness = 27108468.64836288
# Iteration 59 / 100
# Best Fitness = 27108468.64836288
# Iteration 60 / 100
# Best Fitness = 27108468.64836288
# Iteration 61 / 100
# Best Fitness = 27108468.64836288
# Iteration 62 / 100
# Best Fitness = 27108468.64836288
# Iteration 63 / 100
# Best Fitness = 27108468.64836288
# Iteration 64 / 100
# Best Fitness = 27108468.64836288
# Iteration 65 / 100
# Best Fitness = 27108468.64836288
# Iteration 66 / 100
# Best Fitness = 27108468.64836288
# Iteration 67 / 100
# Best Fitness = 27108468.64836288
# Iteration 68 / 100
# Best Fitness = 27108468.64836288
# Iteration 69 / 100
# Best Fitness = 27108468.64836288
# Iteration 70 / 100
# Best Fitness = 27108468.64836288
# Iteration 71 / 100
# Best Fitness = 27108468.64836288
# Iteration 72 / 100
# Best Fitness = 27108468.64836288
# Iteration 73 / 100
# Best Fitness = 27108468.64836288
# Iteration 74 / 100
# Best Fitness = 27108468.64836288
# Iteration 75 / 100
# Best Fitness = 27108468.64836288
# Iteration 76 / 100
# Best Fitness = 27108468.64836288
# Iteration 77 / 100
# Best Fitness = 27108468.64836288
# Iteration 78 / 100
# Best Fitness = 27108468.64836288
# Iteration 79 / 100
# Best Fitness = 27108468.64836288
# Iteration 80 / 100
# Best Fitness = 27108468.64836288
# Iteration 81 / 100
# Best Fitness = 27108468.64836288
# Iteration 82 / 100
# Best Fitness = 27108468.64836288
# Iteration 83 / 100
# Best Fitness = 27108468.64836288
# Iteration 84 / 100
# Best Fitness = 27108468.64836288
# Iteration 85 / 100
# Best Fitness = 27108468.64836288
# Iteration 86 / 100
# Best Fitness = 27108468.64836288
# Iteration 87 / 100
# Best Fitness = 27108468.64836288
# Iteration 88 / 100
# Best Fitness = 27108468.64836288
# Iteration 89 / 100
# Best Fitness = 27108468.64836288
# Iteration 90 / 100
# Best Fitness = 27108468.64836288
# Iteration 91 / 100
# Best Fitness = 27108468.64836288
# Iteration 92 / 100
# Best Fitness = 27108468.64836288
# Iteration 93 / 100
# Best Fitness = 27108468.64836288
# Iteration 94 / 100
# Best Fitness = 27108468.64836288
# Iteration 95 / 100
# Best Fitness = 27108468.64836288
# Iteration 96 / 100
# Best Fitness = 27108468.64836288
# Iteration 97 / 100
# Best Fitness = 27108468.64836288
# Iteration 98 / 100
# Best Fitness = 27108468.64836288
# Iteration 99 / 100
# Best Fitness = 27108468.64836288
# Iteration 100 / 100
# Best Fitness = 27108468.64836288
# Iteration 1 / 100
# Best Fitness = 49043636.86139172
# Iteration 2 / 100
# Best Fitness = 44894345.19623957
# Iteration 3 / 100
# Best Fitness = 42864638.966841854
# Iteration 4 / 100
# Best Fitness = 40270691.558536924
# Iteration 5 / 100
# Best Fitness = 40045174.84786071
# Iteration 6 / 100
# Best Fitness = 35968709.11454001
# Iteration 7 / 100
# Best Fitness = 35968709.11454001
# Iteration 8 / 100
# Best Fitness = 33856399.20681827
# Iteration 9 / 100
# Best Fitness = 33856399.20681827
# Iteration 10 / 100
# Best Fitness = 32457217.496850207
# Iteration 11 / 100
# Best Fitness = 31212377.078965206
# Iteration 12 / 100
# Best Fitness = 29633101.6835242
# Iteration 13 / 100
# Best Fitness = 29496364.500252284
# Iteration 14 / 100
# Best Fitness = 28826364.608665768
# Iteration 15 / 100
# Best Fitness = 28283241.11494801
# Iteration 16 / 100
# Best Fitness = 26634938.052413214
# Iteration 17 / 100
# Best Fitness = 26634938.052413214
# Iteration 18 / 100
# Best Fitness = 26140279.24108597
# Iteration 19 / 100
# Best Fitness = 26140279.24108597
# Iteration 20 / 100
# Best Fitness = 26068279.241705913
# Iteration 21 / 100
# Best Fitness = 25946279.243314624
# Iteration 22 / 100
# Best Fitness = 25868279.25232783
# Iteration 23 / 100
# Best Fitness = 25796279.254790895
# Iteration 24 / 100
# Best Fitness = 25796279.254790895
# Iteration 25 / 100
# Best Fitness = 25796279.254790895
# Iteration 26 / 100
# Best Fitness = 25796279.254790895
# Iteration 27 / 100
# Best Fitness = 25796279.254790895
# Iteration 28 / 100
# Best Fitness = 25796279.254790895
# Iteration 29 / 100
# Best Fitness = 25796279.254790895
# Iteration 30 / 100
# Best Fitness = 25796279.254790895
# Iteration 31 / 100
# Best Fitness = 25796279.254790895
# Iteration 32 / 100
# Best Fitness = 25796279.254790895
# Iteration 33 / 100
# Best Fitness = 25796279.254790895
# Iteration 34 / 100
# Best Fitness = 25796279.254790895
# Iteration 35 / 100
# Best Fitness = 25796279.254790895
# Iteration 36 / 100
# Best Fitness = 25796279.254790895
# Iteration 37 / 100
# Best Fitness = 25796279.254790895
# Iteration 38 / 100
# Best Fitness = 25796279.254790895
# Iteration 39 / 100
# Best Fitness = 25796279.254790895
# Iteration 40 / 100
# Best Fitness = 25796279.254790895
# Iteration 41 / 100
# Best Fitness = 25796279.254790895
# Iteration 42 / 100
# Best Fitness = 25796279.254790895
# Iteration 43 / 100
# Best Fitness = 25796279.254790895
# Iteration 44 / 100
# Best Fitness = 25796279.254790895
# Iteration 45 / 100
# Best Fitness = 25796279.254790895
# Iteration 46 / 100
# Best Fitness = 25796279.254790895
# Iteration 47 / 100
# Best Fitness = 25796279.254790895
# Iteration 48 / 100
# Best Fitness = 25796279.254790895
# Iteration 49 / 100
# Best Fitness = 25796279.254790895
# Iteration 50 / 100
# Best Fitness = 25796279.254790895
# Iteration 51 / 100
# Best Fitness = 25796279.254790895
# Iteration 52 / 100
# Best Fitness = 25796279.254790895
# Iteration 53 / 100
# Best Fitness = 25796279.254790895
# Iteration 54 / 100
# Best Fitness = 25796279.254790895
# Iteration 55 / 100
# Best Fitness = 25796279.254790895
# Iteration 56 / 100
# Best Fitness = 25796279.254790895
# Iteration 57 / 100
# Best Fitness = 25796279.254790895
# Iteration 58 / 100
# Best Fitness = 25796279.254790895
# Iteration 59 / 100
# Best Fitness = 25796279.254790895
# Iteration 60 / 100
# Best Fitness = 25796279.254790895
# Iteration 61 / 100
# Best Fitness = 25796279.254790895
# Iteration 62 / 100
# Best Fitness = 25796279.254790895
# Iteration 63 / 100
# Best Fitness = 25796279.254790895
# Iteration 64 / 100
# Best Fitness = 25796279.254790895
# Iteration 65 / 100
# Best Fitness = 25796279.254790895
# Iteration 66 / 100
# Best Fitness = 25796279.254790895
# Iteration 67 / 100
# Best Fitness = 25796279.254790895
# Iteration 68 / 100
# Best Fitness = 25796279.254790895
# Iteration 69 / 100
# Best Fitness = 25796279.254790895
# Iteration 70 / 100
# Best Fitness = 25796279.254790895
# Iteration 71 / 100
# Best Fitness = 25796279.254790895
# Iteration 72 / 100
# Best Fitness = 25796279.254790895
# Iteration 73 / 100
# Best Fitness = 25796279.254790895
# Iteration 74 / 100
# Best Fitness = 25796279.254790895
# Iteration 75 / 100
# Best Fitness = 25796279.254790895
# Iteration 76 / 100
# Best Fitness = 25796279.254790895
# Iteration 77 / 100
# Best Fitness = 25796279.254790895
# Iteration 78 / 100
# Best Fitness = 25796279.254790895
# Iteration 79 / 100
# Best Fitness = 25796279.254790895
# Iteration 80 / 100
# Best Fitness = 25796279.254790895
# Iteration 81 / 100
# Best Fitness = 25796279.254790895
# Iteration 82 / 100
# Best Fitness = 25796279.254790895
# Iteration 83 / 100
# Best Fitness = 25796279.254790895
# Iteration 84 / 100
# Best Fitness = 25796279.254790895
# Iteration 85 / 100
# Best Fitness = 25796279.254790895
# Iteration 86 / 100
# Best Fitness = 25796279.254790895
# Iteration 87 / 100
# Best Fitness = 25796279.254790895
# Iteration 88 / 100
# Best Fitness = 25796279.254790895
# Iteration 89 / 100
# Best Fitness = 25796279.254790895
# Iteration 90 / 100
# Best Fitness = 25796279.254790895
# Iteration 91 / 100
# Best Fitness = 25796279.254790895
# Iteration 92 / 100
# Best Fitness = 25796279.254790895
# Iteration 93 / 100
# Best Fitness = 25796279.254790895
# Iteration 94 / 100
# Best Fitness = 25796279.254790895
# Iteration 95 / 100
# Best Fitness = 25796279.254790895
# Iteration 96 / 100
# Best Fitness = 25796279.254790895
# Iteration 97 / 100
# Best Fitness = 25796279.254790895
# Iteration 98 / 100
# Best Fitness = 25796279.254790895
# Iteration 99 / 100
# Best Fitness = 25796279.254790895
# Iteration 100 / 100
# Best Fitness = 25796279.254790895
# Iteration 1 / 100
# Best Fitness = 40106033.3793706
# Iteration 2 / 100
# Best Fitness = 35465563.76618165
# Iteration 3 / 100
# Best Fitness = 34352043.25139083
# Iteration 4 / 100
# Best Fitness = 32717292.284954857
# Iteration 5 / 100
# Best Fitness = 32652997.72042132
# Iteration 6 / 100
# Best Fitness = 30132903.66840464
# Iteration 7 / 100
# Best Fitness = 29766827.045241427
# Iteration 8 / 100
# Best Fitness = 25949644.902157687
# Iteration 9 / 100
# Best Fitness = 25949644.902157687
# Iteration 10 / 100
# Best Fitness = 25949644.902157687
# Iteration 11 / 100
# Best Fitness = 25452953.869421467
# Iteration 12 / 100
# Best Fitness = 23950313.911489543
# Iteration 13 / 100
# Best Fitness = 23317177.289819732
# Iteration 14 / 100
# Best Fitness = 23184260.722908024
# Iteration 15 / 100
# Best Fitness = 22921386.252492797
# Iteration 16 / 100
# Best Fitness = 22581374.868974946
# Iteration 17 / 100
# Best Fitness = 21724881.139155097
# Iteration 18 / 100
# Best Fitness = 21658004.340150487
# Iteration 19 / 100
# Best Fitness = 21176444.331373774
# Iteration 20 / 100
# Best Fitness = 20909375.370777786
# Iteration 21 / 100
# Best Fitness = 20659375.343230825
# Iteration 22 / 100
# Best Fitness = 20609375.348286394
# Iteration 23 / 100
# Best Fitness = 20431375.42480568
# Iteration 24 / 100
# Best Fitness = 20431375.403407805
# Iteration 25 / 100
# Best Fitness = 20359375.42737157
# Iteration 26 / 100
# Best Fitness = 20309375.433699578
# Iteration 27 / 100
# Best Fitness = 20289375.434305906
# Iteration 28 / 100
# Best Fitness = 20289375.434305906
# Iteration 29 / 100
# Best Fitness = 20289375.434305906
# Iteration 30 / 100
# Best Fitness = 20289375.434305906
# Iteration 31 / 100
# Best Fitness = 20289375.434305906
# Iteration 32 / 100
# Best Fitness = 20289375.434305906
# Iteration 33 / 100
# Best Fitness = 20289375.434305906
# Iteration 34 / 100
# Best Fitness = 20289375.434305906
# Iteration 35 / 100
# Best Fitness = 20289375.434305906
# Iteration 36 / 100
# Best Fitness = 20289375.434305906
# Iteration 37 / 100
# Best Fitness = 20289375.434305906
# Iteration 38 / 100
# Best Fitness = 20289375.434305906
# Iteration 39 / 100
# Best Fitness = 20289375.434305906
# Iteration 40 / 100
# Best Fitness = 20289375.434305906
# Iteration 41 / 100
# Best Fitness = 20289375.434305906
# Iteration 42 / 100
# Best Fitness = 20289375.434305906
# Iteration 43 / 100
# Best Fitness = 20289375.434305906
# Iteration 44 / 100
# Best Fitness = 20289375.434305906
# Iteration 45 / 100
# Best Fitness = 20289375.434305906
# Iteration 46 / 100
# Best Fitness = 20289375.434305906
# Iteration 47 / 100
# Best Fitness = 20289375.434305906
# Iteration 48 / 100
# Best Fitness = 20289375.434305906
# Iteration 49 / 100
# Best Fitness = 20289375.434305906
# Iteration 50 / 100
# Best Fitness = 20289375.434305906
# Iteration 51 / 100
# Best Fitness = 20289375.434305906
# Iteration 52 / 100
# Best Fitness = 20289375.434305906
# Iteration 53 / 100
# Best Fitness = 20289375.434305906
# Iteration 54 / 100
# Best Fitness = 20289375.434305906
# Iteration 55 / 100
# Best Fitness = 20289375.434305906
# Iteration 56 / 100
# Best Fitness = 20289375.434305906
# Iteration 57 / 100
# Best Fitness = 20289375.434305906
# Iteration 58 / 100
# Best Fitness = 20289375.434305906
# Iteration 59 / 100
# Best Fitness = 20289375.434305906
# Iteration 60 / 100
# Best Fitness = 20289375.434305906
# Iteration 61 / 100
# Best Fitness = 20289375.434305906
# Iteration 62 / 100
# Best Fitness = 20289375.434305906
# Iteration 63 / 100
# Best Fitness = 20289375.434305906
# Iteration 64 / 100
# Best Fitness = 20289375.434305906
# Iteration 65 / 100
# Best Fitness = 20289375.434305906
# Iteration 66 / 100
# Best Fitness = 20289375.434305906
# Iteration 67 / 100
# Best Fitness = 20289375.434305906
# Iteration 68 / 100
# Best Fitness = 20289375.434305906
# Iteration 69 / 100
# Best Fitness = 20289375.434305906
# Iteration 70 / 100
# Best Fitness = 20289375.434305906
# Iteration 71 / 100
# Best Fitness = 20289375.434305906
# Iteration 72 / 100
# Best Fitness = 20289375.434305906
# Iteration 73 / 100
# Best Fitness = 20289375.434305906
# Iteration 74 / 100
# Best Fitness = 20289375.434305906
# Iteration 75 / 100
# Best Fitness = 20289375.434305906
# Iteration 76 / 100
# Best Fitness = 20289375.434305906
# Iteration 77 / 100
# Best Fitness = 20289375.434305906
# Iteration 78 / 100
# Best Fitness = 20289375.434305906
# Iteration 79 / 100
# Best Fitness = 20289375.434305906
# Iteration 80 / 100
# Best Fitness = 20289375.434305906
# Iteration 81 / 100
# Best Fitness = 20289375.434305906
# Iteration 82 / 100
# Best Fitness = 20289375.434305906
# Iteration 83 / 100
# Best Fitness = 20289375.434305906
# Iteration 84 / 100
# Best Fitness = 20289375.434305906
# Iteration 85 / 100
# Best Fitness = 20289375.434305906
# Iteration 86 / 100
# Best Fitness = 20289375.434305906
# Iteration 87 / 100
# Best Fitness = 20289375.434305906
# Iteration 88 / 100
# Best Fitness = 20289375.434305906
# Iteration 89 / 100
# Best Fitness = 20289375.434305906
# Iteration 90 / 100
# Best Fitness = 20289375.434305906
# Iteration 91 / 100
# Best Fitness = 20289375.434305906
# Iteration 92 / 100
# Best Fitness = 20289375.434305906
# Iteration 93 / 100
# Best Fitness = 20289375.434305906
# Iteration 94 / 100
# Best Fitness = 20289375.434305906
# Iteration 95 / 100
# Best Fitness = 20289375.434305906
# Iteration 96 / 100
# Best Fitness = 20289375.434305906
# Iteration 97 / 100
# Best Fitness = 20289375.434305906
# Iteration 98 / 100
# Best Fitness = 20289375.434305906
# Iteration 99 / 100
# Best Fitness = 20289375.434305906
# Iteration 100 / 100
# Best Fitness = 20289375.434305906
# Iteration 1 / 100
# Best Fitness = 43291048.867263764
# Iteration 2 / 100
# Best Fitness = 43291048.867263764
# Iteration 3 / 100
# Best Fitness = 41729704.91850948
# Iteration 4 / 100
# Best Fitness = 39435575.34576672
# Iteration 5 / 100
# Best Fitness = 39073367.317649715
# Iteration 6 / 100
# Best Fitness = 38133800.97669983
# Iteration 7 / 100
# Best Fitness = 35407076.94694811
# Iteration 8 / 100
# Best Fitness = 34898921.06749056
# Iteration 9 / 100
# Best Fitness = 33744935.093565136
# Iteration 10 / 100
# Best Fitness = 33744935.093565136
# Iteration 11 / 100
# Best Fitness = 32070255.472063594
# Iteration 12 / 100
# Best Fitness = 30311557.00897998
# Iteration 13 / 100
# Best Fitness = 30204336.004476592
# Iteration 14 / 100
# Best Fitness = 29922231.888459224
# Iteration 15 / 100
# Best Fitness = 28967325.88907829
# Iteration 16 / 100
# Best Fitness = 28967325.88907829
# Iteration 17 / 100
# Best Fitness = 28967325.88907829
# Iteration 18 / 100
# Best Fitness = 28917325.892569713
# Iteration 19 / 100
# Best Fitness = 28689199.003775194
# Iteration 20 / 100
# Best Fitness = 28689199.003775194
# Iteration 21 / 100
# Best Fitness = 28527279.472667336
# Iteration 22 / 100
# Best Fitness = 28521510.636579517
# Iteration 23 / 100
# Best Fitness = 28171510.68642865
# Iteration 24 / 100
# Best Fitness = 28171510.68642865
# Iteration 25 / 100
# Best Fitness = 28049510.737364095
# Iteration 26 / 100
# Best Fitness = 28049510.737364095
# Iteration 27 / 100
# Best Fitness = 28049510.737364095
# Iteration 28 / 100
# Best Fitness = 28049510.737364095
# Iteration 29 / 100
# Best Fitness = 28049510.737364095
# Iteration 30 / 100
# Best Fitness = 28049510.737364095
# Iteration 31 / 100
# Best Fitness = 28049510.737364095
# Iteration 32 / 100
# Best Fitness = 28049510.737364095
# Iteration 33 / 100
# Best Fitness = 28049510.737364095
# Iteration 34 / 100
# Best Fitness = 28049510.737364095
# Iteration 35 / 100
# Best Fitness = 28049510.737364095
# Iteration 36 / 100
# Best Fitness = 28049510.737364095
# Iteration 37 / 100
# Best Fitness = 28049510.737364095
# Iteration 38 / 100
# Best Fitness = 28049510.737364095
# Iteration 39 / 100
# Best Fitness = 28049510.737364095
# Iteration 40 / 100
# Best Fitness = 28049510.737364095
# Iteration 41 / 100
# Best Fitness = 28049510.737364095
# Iteration 42 / 100
# Best Fitness = 28049510.737364095
# Iteration 43 / 100
# Best Fitness = 28049510.737364095
# Iteration 44 / 100
# Best Fitness = 28049510.737364095
# Iteration 45 / 100
# Best Fitness = 28049510.737364095
# Iteration 46 / 100
# Best Fitness = 28049510.737364095
# Iteration 47 / 100
# Best Fitness = 28049510.737364095
# Iteration 48 / 100
# Best Fitness = 28049510.737364095
# Iteration 49 / 100
# Best Fitness = 28049510.737364095
# Iteration 50 / 100
# Best Fitness = 28049510.737364095
# Iteration 51 / 100
# Best Fitness = 28049510.737364095
# Iteration 52 / 100
# Best Fitness = 28049510.737364095
# Iteration 53 / 100
# Best Fitness = 28049510.737364095
# Iteration 54 / 100
# Best Fitness = 28049510.737364095
# Iteration 55 / 100
# Best Fitness = 28049510.737364095
# Iteration 56 / 100
# Best Fitness = 28049510.737364095
# Iteration 57 / 100
# Best Fitness = 28049510.737364095
# Iteration 58 / 100
# Best Fitness = 28049510.737364095
# Iteration 59 / 100
# Best Fitness = 28049510.737364095
# Iteration 60 / 100
# Best Fitness = 28049510.737364095
# Iteration 61 / 100
# Best Fitness = 28049510.737364095
# Iteration 62 / 100
# Best Fitness = 28049510.737364095
# Iteration 63 / 100
# Best Fitness = 28049510.737364095
# Iteration 64 / 100
# Best Fitness = 28049510.737364095
# Iteration 65 / 100
# Best Fitness = 28049510.737364095
# Iteration 66 / 100
# Best Fitness = 28049510.737364095
# Iteration 67 / 100
# Best Fitness = 28049510.737364095
# Iteration 68 / 100
# Best Fitness = 28049510.737364095
# Iteration 69 / 100
# Best Fitness = 28049510.737364095
# Iteration 70 / 100
# Best Fitness = 28049510.737364095
# Iteration 71 / 100
# Best Fitness = 28049510.737364095
# Iteration 72 / 100
# Best Fitness = 28049510.737364095
# Iteration 73 / 100
# Best Fitness = 28049510.737364095
# Iteration 74 / 100
# Best Fitness = 28049510.737364095
# Iteration 75 / 100
# Best Fitness = 28049510.737364095
# Iteration 76 / 100
# Best Fitness = 28049510.737364095
# Iteration 77 / 100
# Best Fitness = 28049510.737364095
# Iteration 78 / 100
# Best Fitness = 28049510.737364095
# Iteration 79 / 100
# Best Fitness = 28049510.737364095
# Iteration 80 / 100
# Best Fitness = 28049510.737364095
# Iteration 81 / 100
# Best Fitness = 28049510.737364095
# Iteration 82 / 100
# Best Fitness = 28049510.737364095
# Iteration 83 / 100
# Best Fitness = 28049510.737364095
# Iteration 84 / 100
# Best Fitness = 28049510.737364095
# Iteration 85 / 100
# Best Fitness = 28049510.737364095
# Iteration 86 / 100
# Best Fitness = 28049510.737364095
# Iteration 87 / 100
# Best Fitness = 28049510.737364095
# Iteration 88 / 100
# Best Fitness = 28049510.737364095
# Iteration 89 / 100
# Best Fitness = 28049510.737364095
# Iteration 90 / 100
# Best Fitness = 28049510.737364095
# Iteration 91 / 100
# Best Fitness = 28049510.737364095
# Iteration 92 / 100
# Best Fitness = 28049510.737364095
# Iteration 93 / 100
# Best Fitness = 28049510.737364095
# Iteration 94 / 100
# Best Fitness = 28049510.737364095
# Iteration 95 / 100
# Best Fitness = 28049510.737364095
# Iteration 96 / 100
# Best Fitness = 28049510.737364095
# Iteration 97 / 100
# Best Fitness = 28049510.737364095
# Iteration 98 / 100
# Best Fitness = 28049510.737364095
# Iteration 99 / 100
# Best Fitness = 28049510.737364095
# Iteration 100 / 100
# Best Fitness = 28049510.737364095
# {(268681366, 'Level_2 7.4kW'): 1,
#  (528898890, 'Level_3 120kW'): 1,
#  (1652719430, 'Level_2 50kW'): 2,
#  (1758121241, 'Level_3 60kW'): 1,
#  (1728998938, 'Level_2 7.4kW'): 4,
#  (9375777303, 'Level_2 7.4kW'): 3,
#  (1682438430, 'Level_2 50kW'): 1,
#  (387998129, 'Level_2 50kW'): 2,
#  (1952323954, 'Level_3 160kW'): 2,
#  (387872853, 'Level_3 160kW'): 2,
#  (374094917, 'Level_3 160kW'): 1,
#  (1942565943, 'Level_2 22kW'): 1,
#  (1045894019, 'Level_2 22kW'): 1,
#  (477387311, 'Level_2 7.4kW'): 1,
#  (1845131417, 'Level_2 50kW'): 1,
#  (2071413478, 'Level_3 120kW'): 1,
#  (1674985568, 'Level_3 120kW'): 2,
#  (1811633208, 'Level_3 60kW'): 2,
#  (476664020, 'Level_2 50kW'): 1,
#  (476675500, 'Level_2 50kW'): 1,
#  (1636898568, 'Level_2 22kW'): 1,
#  (451848464, 'Level_2 7.4kW'): 2,
#  (4266863370, 'Level_3 160kW'): 1,
#  (262068943, 'Level_3 60kW'): 1,
#  (476667472, 'Level_2 50kW'): 1,
#  (475621851, 'Level_3 160kW'): 2,
#  (1641064048, 'Level_3 60kW'): 1,
#  (1637092014, 'Level_2 7.4kW'): 2,
#  (1919234568, 'Level_2 50kW'): 1,
#  (1642037114, 'Level_3 60kW'): 1,
#  (1760701057, 'Level_2 22kW'): 1,
#  (1632821514, 'Level_3 60kW'): 1,
#  (1763224204, 'Level_3 120kW'): 1,
#  (3181301673, 'Level_3 160kW'): 2,
#  (374445753, 'Level_2 50kW'): 1,
#  (266710455, 'Level_3 120kW'): 1,
#  (1682438433, 'Level_2 22kW'): 1,
#  (374460780, 'Level_2 50kW'): 1,
#  (4764585844, 'Level_3 60kW'): 1,
#  (393696234, 'Level_2 50kW'): 1,
#  (262066703, 'Level_3 60kW'): 1,
#  (5617152897, 'Level_2 7.4kW'): 1,
#  (386687264, 'Level_2 22kW'): 2,
#  (12078877085, 'Level_2 50kW'): 1,
#  (262066923, 'Level_2 22kW'): 1,
#  (1627576286, 'Level_3 60kW'): 1,
#  (7579983585, 'Level_3 120kW'): 1,
#  (267158866, 'Level_2 50kW'): 1,
#  (6425291769, 'Level_3 160kW'): 1,
#  (451847572, 'Level_2 7.4kW'): 1,
#  (6910361830, 'Level_2 7.4kW'): 2,
#  (374098680, 'Level_3 60kW'): 1,
#  (1765932763, 'Level_3 60kW'): 1,
#  (6334244311, 'Level_2 50kW'): 1,
#  (763095494, 'Level_2 22kW'): 1,
#  (1835868378, 'Level_2 22kW'): 1,
#  (11093697103, 'Level_2 50kW'): 1,
#  (259732668, 'Level_3 60kW'): 1,
#  (476665439, 'Level_3 60kW'): 1,
#  (2090107250, 'Level_2 50kW'): 1,
#  (1568277019, 'Level_2 22kW'): 1,
#  (7467701606, 'Level_3 160kW'): 1,
#  (340241479, 'Level_2 22kW'): 1,
#  (1597599271, 'Level_3 60kW'): 1,
#  (1809814162, 'Level_2 7.4kW'): 1,
#  (1638973567, 'Level_3 160kW'): 1,
#  (7692739635, 'Level_2 22kW'): 1,
#  (1636996371, 'Level_2 50kW'): 1,
#  (1279771689, 'Level_3 60kW'): 1,
#  (528898736, 'Level_3 120kW'): 1,
#  (1886593539, 'Level_3 60kW'): 1,
#  (750018876, 'Level_2 22kW'): 1,
#  (254857901, 'Level_2 7.4kW'): 1,
#  (2166646102, 'Level_3 160kW'): 1,
#  (356264609, 'Level_3 60kW'): 1,
#  (373162398, 'Level_3 160kW'): 1,
#  (395015201, 'Level_2 50kW'): 1,
#  (30508647, 'Level_3 60kW'): 1,
#  (1945684404, 'Level_2 22kW'): 1,
#  (1876518019, 'Level_2 22kW'): 1,
#  (1915918206, 'Level_3 160kW'): 1,
#  (2096822897, 'Level_3 60kW'): 1,
#  (1886668707, 'Level_2 22kW'): 1}
