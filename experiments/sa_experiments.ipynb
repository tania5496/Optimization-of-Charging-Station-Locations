# %% [markdown]
# # Importing libraries

# %%
# %pip install osmnx
# %pip install rasterio
# %pip install rasterstats
# %pip install contextily
# %pip install geopandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: osmnx in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.9.4)
# Requirement already satisfied: requests<2.33,>=2.27 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: networkx<3.4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (3.2.1)
# Requirement already satisfied: geopandas<0.15,>=0.12 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (0.14.4)
# Requirement already satisfied: shapely<2.1,>=2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.0.6)
# Requirement already satisfied: numpy<1.27,>=1.20 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas<2.3,>=1.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from osmnx) (2.2.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (1.10.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: packaging in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas<0.15,>=0.12->osmnx) (24.0)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (2024.2.2)
# Requirement already satisfied: click~=8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (7.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click~=8.0->fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (0.4.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas<2.3,>=1.1->osmnx) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=1.1->osmnx) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests<2.33,>=2.27->osmnx) (3.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: rasterio in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.4.2)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: pyparsing in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (3.1.2)
# Requirement already satisfied: click>=4.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: numpy>=1.24 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio) (7.1.0)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->rasterio) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: rasterstats in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.20.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: simplejson in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (3.20.1)
# Requirement already satisfied: numpy>=1.9 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.26.4)
# Requirement already satisfied: cligj>=0.4 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (0.7.2)
# Requirement already satisfied: click>7.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (8.1.7)
# Requirement already satisfied: rasterio>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.4.2)
# Requirement already satisfied: shapely in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (2.0.6)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (2.4.0)
# Requirement already satisfied: fiona in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterstats) (1.10.1)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>7.1->rasterstats) (0.4.6)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (2024.2.2)
# Requirement already satisfied: pyparsing in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (3.1.2)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (24.2.0)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (7.1.0)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio>=1.0->rasterstats) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->rasterio>=1.0->rasterstats) (3.18.1)
# Requirement already satisfied: contextily in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.6.2)
# Requirement already satisfied: matplotlib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (3.9.2)
# Requirement already satisfied: mercantile in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: xyzservices in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2024.9.0)
# Requirement already satisfied: joblib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.3.2)
# Requirement already satisfied: requests in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2.31.0)
# Requirement already satisfied: pillow in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (10.2.0)
# Requirement already satisfied: rasterio in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (1.4.2)
# Requirement already satisfied: geopy in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (6.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (4.50.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (24.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->contextily) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Requirement already satisfied: click>=3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (7.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: affine in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: click-plugins in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: attrs in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from rasterio->contextily) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->contextily) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: geopandas in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.14.4)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (1.10.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (2.2.1)
# Requirement already satisfied: packaging in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from geopandas) (24.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (24.2.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: click~=8.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: certifi in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: importlib-metadata in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from fiona>=1.8.21->geopandas) (7.1.0)
# Requirement already satisfied: colorama in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\tetia\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import networkx as nx
import numpy as np
import pandas as pd
import random
from shapely.geometry import box
import contextily as ctx
import rasterio
import geopy.distance
from scipy.spatial import cKDTree
from rasterstats import zonal_stats
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
import math
import yaml
import pickle
import time
from scipy.sparse.csgraph import floyd_warshall

# %% [markdown]
# # Data

# %% [markdown]
# ## Configs

# %%
with open("configs/params.yaml", "r") as f:
    config = yaml.safe_load(f)
    params = config

# %% [markdown]
# ## City graph

# %%
def create_graph_network(city_params):
    G = ox.graph_from_place(city_params["name"], network_type = city_params["graph_type"])
    G.to_undirected()
    return G

# %%
G = ox.graph_from_place(params["city"]["name"], network_type="drive")

# %%
ox.plot_graph(G, node_size=5)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Division into sectors

# %%
def division_into_secors(city_params):
    city_boundary = ox.geocode_to_gdf(city_params["name"])

    xmin, ymin, xmax, ymax = city_boundary.total_bounds
    grid_size = 0.0125

    grid_cells = []
    for x in np.arange(xmin, xmax, grid_size):
        for y in np.arange(ymin, ymax, grid_size):
            grid_cells.append(box(x, y, x + grid_size, y + grid_size))

    grid = gpd.GeoDataFrame(geometry=grid_cells, crs=city_boundary.crs)
    map_with_grid = gpd.clip(grid, city_boundary)

    return map_with_grid, city_boundary

# %% [markdown]
# Assigning graph nodes to a grid cell (region)

# %%
def nodes_to_region(G, map_with_grid):
    nodes_gdf, edges_gdf = ox.graph_to_gdfs(G, nodes=True, edges=True)
    nodes_gdf = nodes_gdf.set_geometry(nodes_gdf.geometry)

    nodes_in_grid = gpd.sjoin(nodes_gdf, map_with_grid, how="left", predicate="within")
    nodes_in_grid = nodes_in_grid.reset_index()

    # Handling nodes that are not assigned to any grid cell. Creating node to region dictionary and region to nodes dictiionary
    assigned_nodes = nodes_in_grid.dropna(subset=["index_right"]) 
    missing_nodes = nodes_in_grid[nodes_in_grid["index_right"].isna()]

    tree = cKDTree(assigned_nodes[["x", "y"]].values)
    _, nearest_idx = tree.query(missing_nodes[["x", "y"]].values)

    nodes_in_grid.loc[nodes_in_grid["index_right"].isna(), "index_right"] = assigned_nodes.iloc[nearest_idx]["index_right"].values
    nodes_in_grid["index_right"] = nodes_in_grid["index_right"].astype(int)

    # region -> list of nodes
    region_to_nodes = nodes_in_grid.groupby(nodes_in_grid.index_right)["osmid"].apply(list).to_dict()
    # node -> region DI
    node_to_region = nodes_in_grid.set_index("osmid")["index_right"].to_dict()
    regions = [region for region in region_to_nodes]

    return regions, region_to_nodes, node_to_region

# %% [markdown]
# ## Calculating population for each region

# %% [markdown]
# Population for each region

# %%
def population_estimation(regions, map_with_grid, city_params):
    
    # Population count for each sector
    raster_file_population = city_params["raster_file_population"]
    with rasterio.open(raster_file_population) as data:
        affine = data.transform
        array = data.read(1)
    stats = zonal_stats(map_with_grid, raster_file_population, stats=["sum"], affine=affine)
    map_with_grid["population"] = [s["sum"] if s["sum"] is not None else 0 for s in stats]
    map_with_grid = map_with_grid.reset_index()

    # Creating dictionary: region -> population
    region_to_populatoin = dict()
    for grid_cell in range(len(map_with_grid)):
        region_id = map_with_grid.iloc[grid_cell]["index"]
        if region_id in regions:
            population = map_with_grid.iloc[grid_cell]["population"]
            region_to_populatoin[region_id] = population
    
    return region_to_populatoin

# %% [markdown]
# ## Distance matrix

# %%
def calculate_distamnce_matrix(G):
    nodes = list(G.nodes)
    n = len(nodes)
    node_index = {node: idx for idx, node in enumerate(nodes)}

    # Creating adjacency matrix
    D = np.full((n, n), np.inf)

    for u, v, data in G.edges(data=True):
        length = data.get("length", np.inf)
        i, j = node_index[u], node_index[v]
        D[i, j] = length
        D[j, i] = length
    np.fill_diagonal(D, 0)

    # Using optimized Floyd-Warshall
    D = floyd_warshall(D, directed=False)
    np.save("distance_matrix_lviv.npy", D)
    return D

# %%
def distance_matrix(G, city_params):
    if city_params["distance_matrix"]:
        return np.load(city_params["distance_matrix"])
    return calculate_distamnce_matrix(G)

# %% [markdown]
# ## Substations

# %%
def find_substations(city_name):
    substations = ox.features_from_place(city_name, tags={"power": "substation"})
    substations = substations[['geometry']].reset_index()
    return substations

# %%
def calculate_distance_to_substation(G, substations):
    dist_to_substation = dict()
    for node in G.nodes():
        node_lat, node_lon = G.nodes[node]['y'], G.nodes[node]['x']
        distances = []
        for _, row in substations.iterrows():
            if row.geometry.geom_type == "Point":
                substation_lat, substation_lon = row.geometry.y, row.geometry.x
                distance_m = geopy.distance.geodesic((node_lat, node_lon), (substation_lat, substation_lon)).m
                distances.append(distance_m)
        dist_to_substation[node] = min(distances)
    return dist_to_substation

# %% [markdown]
# # Demand simulation

# %% [markdown]
# ## Data Preperation

# %%
def create_cs_dataframe(solution, station_params):
    # Merge installed station and solution station data
    station_node_list, capacity_list, station_ports_list  = [], [], []

    for (station_node, station_type), station_ports in solution.items():
        capacity = station_params["types"][station_type]["capacity"]

        station_node_list.append(station_node)
        capacity_list.append(capacity)
        station_ports_list.append(station_ports)

    # Create station dataframes
    charging_station_df = pd.DataFrame({
        "cs_id": range(len(station_node_list)),
        "node": station_node_list,
        "capacity": capacity_list,
        "num_of_ports": station_ports_list,
    })
    return charging_station_df

# %%
def create_cs_occupation_dataframe(charging_station_df, simulation_hours):
    cs_occupation_df = pd.DataFrame(columns=["cs_id", "capacity", "port", "hour", "occupation_time"])
    
    for _, row in charging_station_df.iterrows():
        cs_id = row["cs_id"]
        capacity = row["capacity"]
        number_of_ports = int(row["num_of_ports"])

        # Creating rows for each port and hour
        for port in range(1, number_of_ports + 1):
            for hour in range(simulation_hours):
                cs_occupation_df.loc[len(cs_occupation_df)] = {"cs_id": cs_id, "capacity": capacity, "port": port, "hour": hour, "occupation_time": 0.0}

    cs_occupation_df["cs_id"] = cs_occupation_df["cs_id"].astype(int)
    return cs_occupation_df

# %% [markdown]
# ## EV generation

# %%
def generate_route(ev, nodes):
    locations = []
    departure_times = []

    # Fron home
    home_location = ev["home_location"]
    morning_commute_hour = ev["commute_hours"]["morning"]
    
    # Route destinations
    number_of_destinations = random.choices([1, 2, 3], weights = [0.6, 0.3, 0.1], k=1)[0] # Generating number of destinations that are not home
    
    locations.append(home_location) # Home location (start point)
    random_locations = random.choices(nodes, k = number_of_destinations) # Work and other locations
    for location in random_locations:
        while location == home_location:
                location = random.choice(nodes)
        locations.append(location)
    locations.append(home_location) # Home location (end point)

    # Route times
    trip_time = {
        "random morning trip": range(0, ev["commute_hours"]["morning"]),
        "random noon trip": range(ev["commute_hours"]["morning"], ev["commute_hours"]["evening"]),
        "random evening trip": range(ev["commute_hours"]["evening"], 24)
    }
    
    departure_times.append(morning_commute_hour) # Departure to work

    if number_of_destinations > 1:
        for i in range(number_of_destinations-1):
            ranom_trip_type = random.choice(["random morning trip", "random noon trip", "random evening trip"])
            random_trip_time = random.choice(trip_time[ranom_trip_type])
            departure_times.append(random_trip_time)

    departure_times.append(ev["commute_hours"]["evening"]) # Departure from work
    departure_times.sort()

    parking_periods = []
    for i in range(number_of_destinations + 2): # +2 since the route starts and ends at home
        if i == 0:
            parking_periods.append([0, departure_times[i]-1])
        elif i == number_of_destinations + 1:
            parking_periods.append([departure_times[i-1], 23])
        else:
            parking_periods.append([departure_times[i-1], departure_times[i]-1])
    return locations, parking_periods

# %%
def generate_EVs(regions, region_to_population, region_to_nodes, nodes, params):
    EVs = []
    ev_id = 0

    for region in regions:
        ev_num = int(region_to_population[region] * params["ev"]["ev_per_capita"])

        potential_home_locations = region_to_nodes[region]
        if len(potential_home_locations) == 0:
            break
        ev_home_locations = random.choices(potential_home_locations, k = ev_num)
        for i in range(ev_num):
            battery_capacity = params["ev"]["battery_capacity"]
            initial_soc_range = params["simulation"]["initial_soc_range"]
            charging_threshold = params["simulation"]["charging_threshold"]
            target_charge = params["simulation"]["target_charge"]
            morning_commute_hours = params["simulation"]["commute_hours"]["morning"]
            evening_commute_hours = params["simulation"]["commute_hours"]["evening"]

            ev = {
                    "ev_id": ev_id,
                    "home_location": ev_home_locations[i],
                    "previous_location": ev_home_locations[i],
                    "battery_capacity": random.uniform(battery_capacity[0], battery_capacity[1]),
                    "current_charge": None,  # Will be assigned below
                    "charging_threshold": random.uniform(charging_threshold[0], charging_threshold[1]),  # When to start charging
                    "target_charge": random.uniform(target_charge[0], target_charge[1]),  # Target charge level
                    "commute_hours": {
                        "morning": random.randint(morning_commute_hours[0], morning_commute_hours[1]),  # Morning commute hour (6-9 AM)
                        "evening": random.randint(evening_commute_hours[0], evening_commute_hours[1])  # Evening commute hour (4-7 PM)
                    },
                    "destinations": None,  # Will be assigned below
                    "parking_periods": None  # Will be assigned below
            }
            
            # Assigning current state of charge
            ev["current_charge"] = ev["battery_capacity"] * random.uniform(initial_soc_range[0], initial_soc_range[1])

            # Assigning route (destinations + departure_times)
            destinations, parking_periods = generate_route(ev, nodes)
            ev["destinations"] = destinations
            ev["parking_periods"] = parking_periods
            EVs.append(ev)
            ev_id +=1
    return EVs

# %% [markdown]
# ## EV charging

# %%
def needs_charge(ev):
    return (ev["current_charge"] < ev["battery_capacity"]*ev["charging_threshold"])

# %%
def nearest_cs_search(charging_station_df, current_location, dist_matrix, nodes_id):
    nearest_cs = charging_station_df.copy()

    nearest_cs["distance"] = nearest_cs["node"].apply(lambda x: dist_matrix[nodes_id[current_location], nodes_id[x]])
    nearest_cs = nearest_cs.sort_values(by = ["distance", "capacity"], ascending=[True, False])
    return nearest_cs[nearest_cs["distance"] < float("inf")]

# %%
def charge_ev(nearest_cs_df, charging_session_df, cs_occupation_df, hour, ev, params):
    # Calculating needed energy
    energy_needed = ev["battery_capacity"] * ev["target_charge"] - ev["current_charge"]
    total_energy_needed = energy_needed/(1-params["charging_stations"]["energy_loss"])
    
    # Calculating departure time (from charging station to next location)
    for j in range(len(ev["parking_periods"])):
        parking_period_start, parking_period_end = ev["parking_periods"][j]
        if hour in range(parking_period_start, parking_period_end + 1):
            departure_time = parking_period_end + 1

    # Searching for a nearest charging station
    while True:
        if len(nearest_cs_df) == 0:
            print("No charhing station is reachable")
            return charging_session_df, cs_occupation_df, ev

        for i in range(len(nearest_cs_df)):
            charging_station_data = nearest_cs_df.iloc[i]
            cs_node = charging_station_data["node"]
            cs_id = charging_station_data["cs_id"]
            cs_capacity = charging_station_data["capacity"]
            num_of_ports = int(charging_station_data["num_of_ports"])
            distance = charging_station_data["distance"]
            # Searching for a free port
            for port in range(1, num_of_ports + 1):
                port_occupation_data = cs_occupation_df[(cs_occupation_df["cs_id"]==cs_id) & (cs_occupation_df["hour"]==hour)&(cs_occupation_df["port"]==port)]
                port_occupation_time = port_occupation_data["occupation_time"].iloc[0]
                if port_occupation_time < 60:
                    break
            if port_occupation_time < 60: # To exit the first For loop
                break

        # If at the current hour each port is occupied for 60 minutes
        # then it is necessary to search for a free port in the next hour, if the day hasn't ended
        if port_occupation_time != 60:
            break
        else:
            if hour + 1 < 24 and hour + 1 < departure_time:
                hour +=1
            else:
                return charging_session_df, cs_occupation_df, ev
        
    # Calculating charging time
    charging_time_minutes = (total_energy_needed/cs_capacity)*60
    # EV charges until it is time for the next trip or until it is charged
    charging_time_minutes = min(charging_time_minutes, max(0, (departure_time - hour)*60 - port_occupation_time))

    # Update charging station occupation dataframe
    if port_occupation_time + charging_time_minutes <=60:
        cs_occupation_df.loc[(cs_occupation_df["cs_id"] == cs_id) & (cs_occupation_df["hour"] == hour) & (cs_occupation_df["port"] == port),\
                              "occupation_time"] = port_occupation_time + charging_time_minutes
        charging_end_hour = hour
    else:
        cs_occupation_df.loc[(cs_occupation_df["cs_id"] == cs_id) & (cs_occupation_df["hour"] == hour) & (cs_occupation_df["port"] == port),\
                              "occupation_time"] = 60
        charging_time_left = charging_time_minutes + port_occupation_time - 60
        next_hour = hour + 1
        while charging_time_left > 60 and next_hour < 24:
            cs_occupation_df.loc[(cs_occupation_df["cs_id"] == cs_id) & (cs_occupation_df["hour"] == next_hour) & (cs_occupation_df["port"] == port),\
                              "occupation_time"] = 60
            charging_time_left -= 60
            next_hour +=1
        if next_hour < 24:
            cs_occupation_df.loc[(cs_occupation_df["cs_id"] == cs_id) & (cs_occupation_df["hour"] == next_hour) & (cs_occupation_df["port"] == port),\
                              "occupation_time"] = charging_time_left
        charging_end_hour = min(23, next_hour)

    # Add new session
    new_session = {
        "cs_id": cs_id,
        "node": cs_node,
        "capacity": cs_capacity,
        "port": port,
        "charging_start_hour": hour,
        "charging_end_hour": charging_end_hour,
        "session_duration": charging_time_minutes,
        "ev_id": ev["ev_id"],
        "distance_from_ev": distance,
        "energy_used": cs_capacity*(charging_time_minutes/60)
    }
        
    charging_session_df.loc[len(charging_session_df)] = new_session
    charging_session_df["cs_id"] = charging_session_df["cs_id"].astype(int)
    # Update EV data
    ev["current_charge"] = ev["current_charge"] + cs_capacity*(charging_time_minutes/60)
    ev["previous_location"] = cs_node

    return charging_session_df, cs_occupation_df, ev

# %% [markdown]
# ## Demand Simulation

# %%
def simulate_charging_demand(solution, params, region_to_population, node_to_region, region_to_nodes, dist_matrix, nodes_id):
    """
    A simple simulation model for EV charging demand over a 24-hour period.
    
    Parameters:
    -----------
    simulation_hours : int
        Number of hours to simulate (typically 24)
    avg_daily_miles : float
        Average miles driven per day per EV
    kwh_per_mile : float
        Average energy consumption per mile (kWh)
    avg_battery_capacity : float
        Average EV battery capacity in kWh
    home_charging_probability : float
        Probability that an EV will charge at home overnight
    
    Returns:
    --------
    DataFrame with hourly charging demand per node
    """
    random.seed(12)
    regions = list(region_to_population.keys())
    nodes = list(node_to_region.keys())
    simulation_hours = params["simulation"]["simulation_hours"]

    charging_station_df = create_cs_dataframe(solution, params["charging_stations"])

    charging_session_df = pd.DataFrame(columns = ["cs_id", "node", "capacity", "port", "charging_start_hour", \
                                          "charging_end_hour", "session_duration", "ev_id", "distance_from_ev", "energy_used"])
    charging_session_df["cs_id"] = charging_session_df["cs_id"].astype(int)
    charging_session_df["node"] = charging_session_df["node"].astype(int)

    cs_occupation_df = create_cs_occupation_dataframe(charging_station_df, simulation_hours)

    # For each region initialize ev
    EVs = generate_EVs(regions, region_to_population, region_to_nodes, nodes, params)

    avg_consumption_per_km = params["ev"]["avg_consumption_per_km"] #Wh/km

    # Simulate each hour
    for hour in range(simulation_hours):

        # For each EV
        for i in range(len(EVs)):
            ev = EVs[i]
            
            previous_location = ev["previous_location"]
            # Update location and state of charge
            for j in range(len(ev["parking_periods"])):
                parking_period_start, parking_period_end = ev["parking_periods"][j]
                if hour in range(parking_period_start, parking_period_end + 1):
                    current_location = ev["destinations"][j]
                    break
            if previous_location != current_location:
                distance = dist_matrix[nodes_id[previous_location], nodes_id[current_location]]
                energy_used = distance * (avg_consumption_per_km/1000)
                ev["current_charge"] -= energy_used

            # Charge if needed
            if needs_charge(ev):
                nearest_cs_df = nearest_cs_search(charging_station_df, current_location, dist_matrix, nodes_id)
                charging_session_df, cs_occupation_df, ev = charge_ev(nearest_cs_df, charging_session_df, cs_occupation_df, hour, ev, params)

            ev["previous_location"] = current_location
    
    return cs_occupation_df, charging_session_df

# %% [markdown]
# # Fitness Evaluation

# %% [markdown]
# ### 1) CS cost evaluation

# %% [markdown]
# Total CS cost:\
# $cs\_cost = \sum^N_{i=1}\sum_{n \in cs\_type} cost_{n,i}*X_{n,i}$

# %%
def cs_cost_penalty(solution, station_params):
    total_cost = 0
    for charging_station in solution:
        cs_type = charging_station[1]
        cost = station_params["types"][cs_type]["cost"]
        number_of_ports = solution[charging_station]
        total_cost += cost*number_of_ports
    return total_cost

# %% [markdown]
# ### 2) Average charging time per 1kWh evaluation

# %%
def avg_time_per_kWh(charging_session_data):
    return sum(charging_session_data["session_duration"])/(sum(charging_session_data["energy_used"])/1000)

# %% [markdown]
# ### 3) Average distance to charging station evaluation

# %%
def average_distance_to_cs(charging_session_data):
    return charging_session_data["distance_from_ev"].mean()

# %% [markdown]
# ### 4) Grid loss

# %%
def total_grid_loss(solution, distance_to_substations):
    total_distance = 0
    for station in solution:
        cs_node = station[0]
        total_distance += distance_to_substations[cs_node]
    return total_distance

# %% [markdown]
# ### Evaluation function

# %% [markdown]
# $evaluation = \alpha*cs\_cost + \beta*avg\_time\_per\_kWh + \gamma*avg\_distance + \delta*grid\_loss$

# %%
def evaluate_fitness(solution, params, dist_matrix, region_to_population, node_to_region, region_to_nodes, nodes_id, distance_to_substations):
    alpha = params["evaluation_weights"]["alpha"]
    beta = params["evaluation_weights"]["beta"]
    gamma = params["evaluation_weights"]["gamma"]
    delta = params["evaluation_weights"]["delta"]

    cs_occupation_df, charging_session_data = simulate_charging_demand(solution, params, region_to_population, node_to_region, region_to_nodes,
                                dist_matrix, nodes_id)

    cs_cost = cs_cost_penalty(solution, params["charging_stations"])
    avg_charging_time_kWh = avg_time_per_kWh(charging_session_data)
    avg_distance= average_distance_to_cs(charging_session_data)
    grid_loss = total_grid_loss(solution, distance_to_substations)

    fitness = alpha*cs_cost + beta*avg_charging_time_kWh + gamma*avg_distance + delta*grid_loss
    return fitness, alpha*cs_cost, beta*avg_charging_time_kWh, gamma*avg_distance, delta*grid_loss

# %% [markdown]
# # Simulated Annealing Algorithm

# %% [markdown]
# **The form in which the solution is presented:**\
# $x\ =\ \{$ \
# $\ \ \ \ (i, 'station\_type'): n$ \
# $\}$
#
# Where\
# $i$ - node_id,\
# $n$ - number of stations (of this type) in the node $i$

# %% [markdown]
# ## Initialization

# %% [markdown]
# - 1 solution
# - 5-100 random stations for each solution
# - random cs type

# %%
def initialize_solution(nodes, station_types):
    solution = {}

    for node in random.sample(nodes, k=random.randint(10, 100)):
        cs_type = random.choice(station_types)
        cs_number = random.choices([1,2,3,4], [0.3, 0.4, 0.2, 0.1])[0]
        solution[(node, cs_type)] = cs_number
    return solution

# %% [markdown]
# ## Generate new solution

# %%
def add_random_station(solution, nodes, cs_types, max_ports_per_node):
    new_solution = solution.copy()

    # Calculating total number of cs ports in each node
    total_node_ports = {cs_node: 0 for cs_node, cs_type in new_solution}
    for station in new_solution:
        total_node_ports[station[0]] = total_node_ports[station[0]] + new_solution[station]
        
    num_of_stations = random.choices([1, 2, 3, 4, 5, 6], [0.05, 0.1, 0.15, 0.2, 0.25, 0.25])[0]
    for i in range(num_of_stations):

        # Generate random node, type 
        random_node = random.choice(nodes)
        cs_type = random.choice(cs_types)
        while random_node in total_node_ports.keys() and total_node_ports[random_node] == max_ports_per_node:
            random_node = random.choice(nodes)

        # Generate random number of ports taking into account number of existing stations in the node
        if random_node in total_node_ports.keys():
            num_of_ports = random.choice(range(0, max_ports_per_node - total_node_ports[random_node])) + 1
        else:
            num_of_ports = random.choice(range(0, max_ports_per_node)) + 1

        # Generate random number of ports taking into account number of existing stations in the node
        if (random_node, cs_type) in new_solution:
            new_solution[(random_node, cs_type)] = new_solution[(random_node, cs_type)] + num_of_ports
        else:
            new_solution[(random_node, cs_type)] = num_of_ports

        # Update num_cs_ports
        if random_node in total_node_ports.keys():
            total_node_ports[random_node] = total_node_ports[random_node] + num_of_ports
        else: 
            total_node_ports[random_node] = num_of_ports
    return new_solution

# %%
def remove_random_station(solution):
    new_solution = solution.copy()

    num_of_stations = random.choices([1, 2, 3, 4, 5, 6], [0.05, 0.1, 0.15, 0.2, 0.25, 0.25], k = 1)[0]
    num_of_stations = min(num_of_stations, len(list(new_solution.keys())))

    for i in range(num_of_stations):
        random_station = random.choice(list(new_solution.keys()))
        num_of_ports_remove = random.choice(range(1, new_solution[random_station] + 1)) 

        if num_of_ports_remove < new_solution[random_station]:
            new_solution[random_station] = new_solution[random_station] - num_of_ports_remove
        else:
            new_solution.pop(random_station)
    return new_solution

# %%
def change_station_type(solution, cs_types, max_ports_per_node):
    new_solution = solution.copy()
    num_of_stations = random.choices([1, 2, 3, 4], [0.4, 0.3, 0.2, 0.1])[0]

    for i in range(num_of_stations):
        cs_node, cs_type = random.choice([station for station in new_solution])
        new_cs_types_list = cs_types.copy()
        new_cs_types_list.remove(cs_type)

        new_cs_type = random.choice(new_cs_types_list)
        if (cs_node, new_cs_type) in new_solution:
            new_solution[(cs_node, new_cs_type)] = min(max_ports_per_node, \
                                                       new_solution[(cs_node, cs_type)] + new_solution[(cs_node, new_cs_type)])
        else:
            new_solution[(cs_node, new_cs_type)] = new_solution[(cs_node, cs_type)]

        new_solution.pop((cs_node, cs_type))
    
    return new_solution

# %%
def generate_new_solution(solution, nodes, station_params):
    rng = random.Random()
    cs_types = station_params["types_list"]
    max_ports_per_node = station_params["max_ports_per_node"]

    action = rng.choice(["add", "remove", "change_type"])
    print(action)
    if action == "add":
        new_solution = add_random_station(solution, nodes, cs_types, max_ports_per_node)
    elif action == "remove":
        new_solution = remove_random_station(solution)
    else:
        new_solution = change_station_type(solution, cs_types, max_ports_per_node)

    return new_solution

# %% [markdown]
# ## Simulated Annealing Algorithm

# %%
def SA_algorithm(G, dist_matrix, params, region_to_population, node_to_region, region_to_nodes, distance_to_substations):
    
    sa_params = params["simulated_annealing"]
    station_params = params["charging_stations"]

    nodes = list(G.nodes)
    nodes_id = {nodes[i]: i for i in range(len(nodes))}

    cs_types = station_params["types_list"]

    current_solution = initialize_solution(nodes, cs_types)
    best_solution = current_solution

    current_fitness, fitness_cost, fitness_charging_time, fitness_avg_distance, fitness_grid_loss = evaluate_fitness(current_solution, params, dist_matrix,\
                                    region_to_population, node_to_region, region_to_nodes, nodes_id, distance_to_substations)
    best_fitness = current_fitness
    best_fitness_list = [[current_fitness, fitness_cost, fitness_charging_time, fitness_avg_distance, fitness_grid_loss]]

    
    T = sa_params["initial_temperature"]
    cooling_rate = sa_params["cooling_rate"]
    iterations = sa_params["iterations"]
    bad_attempts_limit = sa_params["bad_attempts_limit"]
    testing_worse_solution = False
    for iteration in range(iterations):
        print("Iteration", iteration + 1, "/", iterations)

        new_solution = generate_new_solution(current_solution, nodes, station_params)
        new_fitness, new_fitness_cost, new_fitness_charging_time, new_fitness_avg_distance, new_fitness_grid_loss = evaluate_fitness(new_solution, params, dist_matrix, region_to_population, node_to_region,
                                        region_to_nodes, nodes_id, distance_to_substations)
        delta_fitness = new_fitness - current_fitness
        # print("delta_fitness: ", round(delta_fitness, 1))
        # print("probability: ", math.exp(-delta_fitness / T))

        if delta_fitness < 0 or (random.random() < math.exp(-delta_fitness / T)):
            current_solution = new_solution
            current_fitness = new_fitness
            if delta_fitness > 0:
                testing_worse_solution = True
                bad_attemmpts = bad_attempts_limit
            else:
                testing_worse_solution = False

            if current_fitness < best_fitness:
                best_solution = current_solution
                best_fitness = current_fitness
                best_fitness_list.append([new_fitness, new_fitness_cost, new_fitness_charging_time, new_fitness_avg_distance, new_fitness_grid_loss])
            else:
                best_fitness_list.append(best_fitness_list[-1]) # when best solution hasn't changed
        else:
            best_fitness_list.append(best_fitness_list[-1]) # when best solution hasn't changed
            if testing_worse_solution:
                bad_attemmpts -=1
        if testing_worse_solution and bad_attemmpts == 0:
            current_solution = best_solution
            current_fitness = best_fitness
            testing_worse_solution = False

        T *= cooling_rate

    return best_solution, best_fitness_list

# %% [markdown]
# ## Visualization

# %%
def visualize_solution(solution, G):
    cs_lists_by_type = dict()
    for charging_station in solution:
        cs_node = charging_station[0]
        cs_type = charging_station[1]
        if cs_type in list(cs_lists_by_type.keys()):
            cs_lists_by_type[cs_type].append(cs_node)
        else:
            cs_lists_by_type[cs_type] = [cs_node]

    pos = {node: (data['x'], data['y']) for node, data in G.nodes(data=True)}
    G_undirected = G.to_undirected()
    G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))
    fig, ax = plt.subplots(figsize=(12, 9), facecolor="black")


    nx.draw(G_undirected, pos, node_size=2, with_labels=False, node_color="darkgray", edge_color="darkgray", ax=ax)

    unique_cs_types = list(cs_lists_by_type.keys())
    color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))
                 for i, cs_type in enumerate(unique_cs_types)}

    # Drawing charging station nodes with different colors based on their type
    for cs_type, nodes in cs_lists_by_type.items():
        nx.draw_networkx_nodes(
            G_undirected,
            pos,
            nodelist=nodes,
            node_size=20,
            node_color=[color_map[cs_type]] * len(nodes),
            label=f"{cs_type} Stations",
            ax=ax
        )

    legend = plt.legend(scatterpoints=1, frameon=True, loc="upper right", facecolor="white", edgecolor="darkgray", bbox_to_anchor=(1.5, 1))
    for text in legend.get_texts():
        text.set_color("black")

    plt.title("Graph with Stations", color="darkgrey")
    ax.axis("off")

    plt.tight_layout()
    plt.show()

# %%
def plot_total_fitness(best_fitness_list):
    plt.figure(figsize=(15, 10))
    fitness = [iteration[0] for  iteration in best_fitness_list]
    n = len(fitness)
    plt.plot(range(n), fitness, label = "Total evaluation")
    plt.xlabel('Iteration')
    plt.ylabel('Best fitness')
    plt.title(f'Total Fitness of the best solution for each iteration for SAA model')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def plot_models_fitness(fitness_lists, parameters):
    plt.figure(figsize=(15, 10))

    fitness = [iteration[0] for  iteration in fitness_lists]
    fitness_cost = [iteration[1] for  iteration in fitness_lists]
    fitness_charging_time = [iteration[2] for  iteration in fitness_lists]
    fitness_avg_distance = [iteration[3] for  iteration in fitness_lists]
    fitness_grid_loss = [iteration[4] for  iteration in fitness_lists]
    n = len(fitness)
    plt.plot(range(n), fitness, label = "Total evaluation")
    plt.plot(range(n), fitness_cost, label = f"Cost evaluation, weight = {parameters['alpha']}")
    plt.plot(range(n), fitness_charging_time, label = f"Average charging time per kWh evaluation, weight = {parameters['beta']}")
    plt.plot(range(n), fitness_avg_distance, label = f"Average distance evaluation, weight = {parameters['gamma']}")
    plt.plot(range(n), fitness_grid_loss, label = f"Grid loss evaluation, weight = {parameters['delta']}")

    plt.xlabel('Iteration')
    plt.ylabel('Best fitness')
    plt.title(f'Fitness values of the best solution for each iteration for SA')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Simulated Annealing model

# %%
def run_sa(base_config_file, exp_name, exp_config_file = None):
    with open(base_config_file, "r") as f:
        params = yaml.safe_load(f)
    
    if exp_config_file:
        with open(exp_config_file, "r") as f:
            exp_params = yaml.safe_load(f)
        params.update(exp_params)

    city_params = params["city"]

    # Graph
    G = create_graph_network(city_params)

    # Calculating distance matrix
    dist_matrix = distance_matrix(G, city_params)

    # Calculating distance from nodes to substations
    substations = find_substations(city_params["name"])
    distance_to_substations = calculate_distance_to_substation(G, substations)

    # Division into sectors + demand estimation
    map_with_grid, city_boundary = division_into_secors(city_params)
    regions, region_to_nodes, node_to_region = nodes_to_region(G, map_with_grid)
    region_to_population = population_estimation(regions, map_with_grid, city_params)

    # SA
    start_time = time.time()
    best_solution, best_fitness_list = SA_algorithm(G, dist_matrix, params, region_to_population, 
                                                    node_to_region, region_to_nodes, distance_to_substations)
    runtime = time.time() - start_time
    result = {
        "algorithm": "SA",
        "fitness_history": best_fitness_list,
        "runtime": runtime,
        "solution": best_solution
    }
    with open(exp_name, 'wb') as f:
    # with open('exp_sa_0.pkl', 'wb') as f:
        pickle.dump(result, f)

    # Visualization
    # plot_models_fitness(best_fitness_list, params["evaluation_weights"])
    # plot_total_fitness(best_fitness_list)
    # visualize_solution(best_solution, G)

# %% [markdown]
# # Experiments

# %% [markdown]
# ## Experiment 0

# %% [markdown]
# - base parameters

# %%
run_sa("configs/params.yaml", "exp_sa_0.pkl", exp_config_file = None)

# %%
with open("exp_sa_0.pkl", "rb") as f:
    exp_result = pickle.load(f)
exp_result["runtime"]
# Out:
# 1704.601571559906

# %%
plot_models_fitness(exp_result["fitness_history"], params["evaluation_weights"])
plot_total_fitness(exp_result["fitness_history"])
visualize_solution(exp_result["solution"], G)
# Out:
# C:\Users\tetia\AppData\Local\Temp\ipykernel_27360\777376565.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))

# %% [markdown]
# ## Experiment 1

# %% [markdown]
# - base parameters
# - iterations = 3000

# %%
run_sa("configs/params.yaml", "exp_sa_1.pkl", exp_config_file = "configs/experiments/exp_sa_1.yaml")
# Out:
# Iteration 1 / 3000
# add
# Iteration 2 / 3000
# add
# Iteration 3 / 3000
# change_type
# Iteration 4 / 3000
# add
# Iteration 5 / 3000
# add
# Iteration 6 / 3000
# change_type
# Iteration 7 / 3000
# add
# Iteration 8 / 3000
# change_type
# Iteration 9 / 3000
# change_type
# Iteration 10 / 3000
# remove
# Iteration 11 / 3000
# change_type
# Iteration 12 / 3000
# add
# Iteration 13 / 3000
# change_type
# Iteration 14 / 3000
# add
# Iteration 15 / 3000
# remove
# Iteration 16 / 3000
# remove
# Iteration 17 / 3000
# remove
# Iteration 18 / 3000
# change_type
# Iteration 19 / 3000
# change_type
# Iteration 20 / 3000
# add
# Iteration 21 / 3000
# add
# Iteration 22 / 3000
# change_type
# Iteration 23 / 3000
# add
# Iteration 24 / 3000
# remove
# Iteration 25 / 3000
# add
# Iteration 26 / 3000
# change_type
# Iteration 27 / 3000
# change_type
# Iteration 28 / 3000
# add
# Iteration 29 / 3000
# change_type
# Iteration 30 / 3000
# change_type
# Iteration 31 / 3000
# change_type
# Iteration 32 / 3000
# add
# Iteration 33 / 3000
# add
# Iteration 34 / 3000
# change_type
# Iteration 35 / 3000
# change_type
# Iteration 36 / 3000
# remove
# Iteration 37 / 3000
# add
# Iteration 38 / 3000
# change_type
# Iteration 39 / 3000
# add
# Iteration 40 / 3000
# add
# Iteration 41 / 3000
# change_type
# Iteration 42 / 3000
# add
# Iteration 43 / 3000
# remove
# Iteration 44 / 3000
# remove
# Iteration 45 / 3000
# add
# Iteration 46 / 3000
# add
# Iteration 47 / 3000
# change_type
# Iteration 48 / 3000
# add
# Iteration 49 / 3000
# remove
# Iteration 50 / 3000
# change_type
# Iteration 51 / 3000
# change_type
# Iteration 52 / 3000
# change_type
# Iteration 53 / 3000
# add
# Iteration 54 / 3000
# add
# Iteration 55 / 3000
# remove
# Iteration 56 / 3000
# add
# Iteration 57 / 3000
# change_type
# Iteration 58 / 3000
# add
# Iteration 59 / 3000
# remove
# Iteration 60 / 3000
# remove
# Iteration 61 / 3000
# change_type
# Iteration 62 / 3000
# remove
# Iteration 63 / 3000
# add
# Iteration 64 / 3000
# change_type
# Iteration 65 / 3000
# change_type
# Iteration 66 / 3000
# remove
# Iteration 67 / 3000
# remove
# Iteration 68 / 3000
# remove
# Iteration 69 / 3000
# remove
# Iteration 70 / 3000
# add
# Iteration 71 / 3000
# add
# Iteration 72 / 3000
# remove
# Iteration 73 / 3000
# remove
# Iteration 74 / 3000
# add
# Iteration 75 / 3000
# change_type
# Iteration 76 / 3000
# change_type
# Iteration 77 / 3000
# change_type
# Iteration 78 / 3000
# add
# Iteration 79 / 3000
# remove
# Iteration 80 / 3000
# remove
# Iteration 81 / 3000
# change_type
# Iteration 82 / 3000
# change_type
# Iteration 83 / 3000
# change_type
# Iteration 84 / 3000
# add
# Iteration 85 / 3000
# change_type
# Iteration 86 / 3000
# remove
# Iteration 87 / 3000
# change_type
# Iteration 88 / 3000
# add
# Iteration 89 / 3000
# remove
# Iteration 90 / 3000
# remove
# Iteration 91 / 3000
# remove
# Iteration 92 / 3000
# change_type
# Iteration 93 / 3000
# change_type
# Iteration 94 / 3000
# remove
# Iteration 95 / 3000
# remove
# Iteration 96 / 3000
# add
# Iteration 97 / 3000
# remove
# Iteration 98 / 3000
# remove
# Iteration 99 / 3000
# add
# Iteration 100 / 3000
# change_type
# Iteration 101 / 3000
# change_type
# Iteration 102 / 3000
# change_type
# Iteration 103 / 3000
# change_type
# Iteration 104 / 3000
# add
# Iteration 105 / 3000
# remove
# Iteration 106 / 3000
# remove
# Iteration 107 / 3000
# change_type
# Iteration 108 / 3000
# change_type
# Iteration 109 / 3000
# remove
# Iteration 110 / 3000
# remove
# Iteration 111 / 3000
# add
# Iteration 112 / 3000
# add
# Iteration 113 / 3000
# change_type
# Iteration 114 / 3000
# add
# Iteration 115 / 3000
# remove
# Iteration 116 / 3000
# add
# Iteration 117 / 3000
# change_type
# Iteration 118 / 3000
# add
# Iteration 119 / 3000
# remove
# Iteration 120 / 3000
# add
# Iteration 121 / 3000
# change_type
# Iteration 122 / 3000
# remove
# Iteration 123 / 3000
# add
# Iteration 124 / 3000
# add
# Iteration 125 / 3000
# change_type
# Iteration 126 / 3000
# remove
# Iteration 127 / 3000
# change_type
# Iteration 128 / 3000
# change_type
# Iteration 129 / 3000
# change_type
# Iteration 130 / 3000
# remove
# Iteration 131 / 3000
# add
# Iteration 132 / 3000
# change_type
# Iteration 133 / 3000
# add
# Iteration 134 / 3000
# change_type
# Iteration 135 / 3000
# change_type
# Iteration 136 / 3000
# remove
# Iteration 137 / 3000
# change_type
# Iteration 138 / 3000
# change_type
# Iteration 139 / 3000
# change_type
# Iteration 140 / 3000
# remove
# Iteration 141 / 3000
# remove
# Iteration 142 / 3000
# remove
# Iteration 143 / 3000
# remove
# Iteration 144 / 3000
# change_type
# Iteration 145 / 3000
# remove
# Iteration 146 / 3000
# remove
# Iteration 147 / 3000
# remove
# Iteration 148 / 3000
# remove
# Iteration 149 / 3000
# add
# Iteration 150 / 3000
# add
# Iteration 151 / 3000
# remove
# Iteration 152 / 3000
# change_type
# Iteration 153 / 3000
# add
# Iteration 154 / 3000
# change_type
# Iteration 155 / 3000
# add
# Iteration 156 / 3000
# change_type
# Iteration 157 / 3000
# change_type
# Iteration 158 / 3000
# remove
# Iteration 159 / 3000
# change_type
# Iteration 160 / 3000
# change_type
# Iteration 161 / 3000
# remove
# Iteration 162 / 3000
# add
# Iteration 163 / 3000
# add
# Iteration 164 / 3000
# change_type
# Iteration 165 / 3000
# remove
# Iteration 166 / 3000
# change_type
# Iteration 167 / 3000
# remove
# Iteration 168 / 3000
# change_type
# Iteration 169 / 3000
# add
# Iteration 170 / 3000
# add
# Iteration 171 / 3000
# change_type
# Iteration 172 / 3000
# remove
# Iteration 173 / 3000
# change_type
# Iteration 174 / 3000
# add
# Iteration 175 / 3000
# add
# Iteration 176 / 3000
# change_type
# Iteration 177 / 3000
# change_type
# Iteration 178 / 3000
# change_type
# Iteration 179 / 3000
# change_type
# Iteration 180 / 3000
# change_type
# Iteration 181 / 3000
# remove
# Iteration 182 / 3000
# add
# Iteration 183 / 3000
# add
# Iteration 184 / 3000
# change_type
# Iteration 185 / 3000
# add
# Iteration 186 / 3000
# remove
# Iteration 187 / 3000
# change_type
# Iteration 188 / 3000
# remove
# Iteration 189 / 3000
# add
# Iteration 190 / 3000
# change_type
# Iteration 191 / 3000
# change_type
# Iteration 192 / 3000
# change_type
# Iteration 193 / 3000
# remove
# Iteration 194 / 3000
# remove
# Iteration 195 / 3000
# change_type
# Iteration 196 / 3000
# add
# Iteration 197 / 3000
# change_type
# Iteration 198 / 3000
# add
# Iteration 199 / 3000
# add
# Iteration 200 / 3000
# add
# Iteration 201 / 3000
# add
# Iteration 202 / 3000
# add
# Iteration 203 / 3000
# add
# Iteration 204 / 3000
# add
# Iteration 205 / 3000
# change_type
# Iteration 206 / 3000
# remove
# Iteration 207 / 3000
# remove
# Iteration 208 / 3000
# add
# Iteration 209 / 3000
# change_type
# Iteration 210 / 3000
# add
# Iteration 211 / 3000
# remove
# Iteration 212 / 3000
# remove
# Iteration 213 / 3000
# remove
# Iteration 214 / 3000
# change_type
# Iteration 215 / 3000
# change_type
# Iteration 216 / 3000
# change_type
# Iteration 217 / 3000
# remove
# Iteration 218 / 3000
# add
# Iteration 219 / 3000
# add
# Iteration 220 / 3000
# add
# Iteration 221 / 3000
# add
# Iteration 222 / 3000
# add
# Iteration 223 / 3000
# remove
# Iteration 224 / 3000
# change_type
# Iteration 225 / 3000
# remove
# Iteration 226 / 3000
# change_type
# Iteration 227 / 3000
# add
# Iteration 228 / 3000
# add
# Iteration 229 / 3000
# change_type
# Iteration 230 / 3000
# add
# Iteration 231 / 3000
# change_type
# Iteration 232 / 3000
# change_type
# Iteration 233 / 3000
# change_type
# Iteration 234 / 3000
# remove
# Iteration 235 / 3000
# add
# Iteration 236 / 3000
# change_type
# Iteration 237 / 3000
# remove
# Iteration 238 / 3000
# add
# Iteration 239 / 3000
# change_type
# Iteration 240 / 3000
# remove
# Iteration 241 / 3000
# remove
# Iteration 242 / 3000
# change_type
# Iteration 243 / 3000
# change_type
# Iteration 244 / 3000
# remove
# Iteration 245 / 3000
# remove
# Iteration 246 / 3000
# add
# Iteration 247 / 3000
# remove
# Iteration 248 / 3000
# remove
# Iteration 249 / 3000
# change_type
# Iteration 250 / 3000
# remove
# Iteration 251 / 3000
# remove
# Iteration 252 / 3000
# add
# Iteration 253 / 3000
# add
# Iteration 254 / 3000
# add
# Iteration 255 / 3000
# change_type
# Iteration 256 / 3000
# remove
# Iteration 257 / 3000
# change_type
# Iteration 258 / 3000
# change_type
# Iteration 259 / 3000
# change_type
# Iteration 260 / 3000
# change_type
# Iteration 261 / 3000
# remove
# Iteration 262 / 3000
# remove
# Iteration 263 / 3000
# change_type
# Iteration 264 / 3000
# change_type
# Iteration 265 / 3000
# change_type
# Iteration 266 / 3000
# change_type
# Iteration 267 / 3000
# add
# Iteration 268 / 3000
# change_type
# Iteration 269 / 3000
# remove
# Iteration 270 / 3000
# remove
# Iteration 271 / 3000
# change_type
# Iteration 272 / 3000
# remove
# Iteration 273 / 3000
# add
# Iteration 274 / 3000
# change_type
# Iteration 275 / 3000
# remove
# Iteration 276 / 3000
# add
# Iteration 277 / 3000
# add
# Iteration 278 / 3000
# add
# Iteration 279 / 3000
# remove
# Iteration 280 / 3000
# change_type
# Iteration 281 / 3000
# change_type
# Iteration 282 / 3000
# remove
# Iteration 283 / 3000
# remove
# Iteration 284 / 3000
# add
# Iteration 285 / 3000
# remove
# Iteration 286 / 3000
# add
# Iteration 287 / 3000
# add
# Iteration 288 / 3000
# change_type
# Iteration 289 / 3000
# change_type
# Iteration 290 / 3000
# remove
# Iteration 291 / 3000
# add
# Iteration 292 / 3000
# remove
# Iteration 293 / 3000
# add
# Iteration 294 / 3000
# change_type
# Iteration 295 / 3000
# change_type
# Iteration 296 / 3000
# remove
# Iteration 297 / 3000
# change_type
# Iteration 298 / 3000
# change_type
# Iteration 299 / 3000
# change_type
# Iteration 300 / 3000
# change_type
# Iteration 301 / 3000
# add
# Iteration 302 / 3000
# change_type
# Iteration 303 / 3000
# add
# Iteration 304 / 3000
# remove
# Iteration 305 / 3000
# add
# Iteration 306 / 3000
# change_type
# Iteration 307 / 3000
# remove
# Iteration 308 / 3000
# remove
# Iteration 309 / 3000
# remove
# Iteration 310 / 3000
# remove
# Iteration 311 / 3000
# add
# Iteration 312 / 3000
# remove
# Iteration 313 / 3000
# add
# Iteration 314 / 3000
# add
# Iteration 315 / 3000
# remove
# Iteration 316 / 3000
# change_type
# Iteration 317 / 3000
# add
# Iteration 318 / 3000
# change_type
# Iteration 319 / 3000
# remove
# Iteration 320 / 3000
# change_type
# Iteration 321 / 3000
# add
# Iteration 322 / 3000
# add
# Iteration 323 / 3000
# remove
# Iteration 324 / 3000
# add
# Iteration 325 / 3000
# change_type
# Iteration 326 / 3000
# add
# Iteration 327 / 3000
# remove
# Iteration 328 / 3000
# add
# Iteration 329 / 3000
# change_type
# Iteration 330 / 3000
# change_type
# Iteration 331 / 3000
# add
# Iteration 332 / 3000
# add
# Iteration 333 / 3000
# change_type
# Iteration 334 / 3000
# change_type
# Iteration 335 / 3000
# change_type
# Iteration 336 / 3000
# add
# Iteration 337 / 3000
# remove
# Iteration 338 / 3000
# remove
# Iteration 339 / 3000
# add
# Iteration 340 / 3000
# add
# Iteration 341 / 3000
# add
# Iteration 342 / 3000
# change_type
# Iteration 343 / 3000
# remove
# Iteration 344 / 3000
# change_type
# Iteration 345 / 3000
# add
# Iteration 346 / 3000
# remove
# Iteration 347 / 3000
# remove
# Iteration 348 / 3000
# remove
# Iteration 349 / 3000
# add
# Iteration 350 / 3000
# remove
# Iteration 351 / 3000
# change_type
# Iteration 352 / 3000
# add
# Iteration 353 / 3000
# change_type
# Iteration 354 / 3000
# remove
# Iteration 355 / 3000
# change_type
# Iteration 356 / 3000
# remove
# Iteration 357 / 3000
# remove
# Iteration 358 / 3000
# remove
# Iteration 359 / 3000
# add
# Iteration 360 / 3000
# add
# Iteration 361 / 3000
# remove
# Iteration 362 / 3000
# add
# Iteration 363 / 3000
# change_type
# Iteration 364 / 3000
# remove
# Iteration 365 / 3000
# change_type
# Iteration 366 / 3000
# change_type
# Iteration 367 / 3000
# change_type
# Iteration 368 / 3000
# add
# Iteration 369 / 3000
# change_type
# Iteration 370 / 3000
# change_type
# Iteration 371 / 3000
# add
# Iteration 372 / 3000
# change_type
# Iteration 373 / 3000
# remove
# Iteration 374 / 3000
# remove
# Iteration 375 / 3000
# change_type
# Iteration 376 / 3000
# remove
# Iteration 377 / 3000
# add
# Iteration 378 / 3000
# change_type
# Iteration 379 / 3000
# remove
# Iteration 380 / 3000
# change_type
# Iteration 381 / 3000
# add
# Iteration 382 / 3000
# add
# Iteration 383 / 3000
# change_type
# Iteration 384 / 3000
# change_type
# Iteration 385 / 3000
# add
# Iteration 386 / 3000
# add
# Iteration 387 / 3000
# add
# Iteration 388 / 3000
# remove
# Iteration 389 / 3000
# add
# Iteration 390 / 3000
# change_type
# Iteration 391 / 3000
# add
# Iteration 392 / 3000
# add
# Iteration 393 / 3000
# change_type
# Iteration 394 / 3000
# change_type
# Iteration 395 / 3000
# remove
# Iteration 396 / 3000
# change_type
# Iteration 397 / 3000
# remove
# Iteration 398 / 3000
# change_type
# Iteration 399 / 3000
# change_type
# Iteration 400 / 3000
# change_type
# Iteration 401 / 3000
# add
# Iteration 402 / 3000
# add
# Iteration 403 / 3000
# change_type
# Iteration 404 / 3000
# change_type
# Iteration 405 / 3000
# add
# Iteration 406 / 3000
# change_type
# Iteration 407 / 3000
# change_type
# Iteration 408 / 3000
# change_type
# Iteration 409 / 3000
# remove
# Iteration 410 / 3000
# remove
# Iteration 411 / 3000
# change_type
# Iteration 412 / 3000
# add
# Iteration 413 / 3000
# remove
# Iteration 414 / 3000
# add
# Iteration 415 / 3000
# change_type
# Iteration 416 / 3000
# change_type
# Iteration 417 / 3000
# add
# Iteration 418 / 3000
# remove
# Iteration 419 / 3000
# remove
# Iteration 420 / 3000
# remove
# Iteration 421 / 3000
# add
# Iteration 422 / 3000
# remove
# Iteration 423 / 3000
# remove
# Iteration 424 / 3000
# change_type
# Iteration 425 / 3000
# remove
# Iteration 426 / 3000
# add
# Iteration 427 / 3000
# remove
# Iteration 428 / 3000
# change_type
# Iteration 429 / 3000
# remove
# Iteration 430 / 3000
# add
# Iteration 431 / 3000
# change_type
# Iteration 432 / 3000
# add
# Iteration 433 / 3000
# change_type
# Iteration 434 / 3000
# add
# Iteration 435 / 3000
# add
# Iteration 436 / 3000
# remove
# Iteration 437 / 3000
# add
# Iteration 438 / 3000
# change_type
# Iteration 439 / 3000
# remove
# Iteration 440 / 3000
# add
# Iteration 441 / 3000
# change_type
# Iteration 442 / 3000
# change_type
# Iteration 443 / 3000
# change_type
# Iteration 444 / 3000
# remove
# Iteration 445 / 3000
# add
# Iteration 446 / 3000
# change_type
# Iteration 447 / 3000
# change_type
# Iteration 448 / 3000
# add
# Iteration 449 / 3000
# remove
# Iteration 450 / 3000
# add
# Iteration 451 / 3000
# add
# Iteration 452 / 3000
# remove
# Iteration 453 / 3000
# remove
# Iteration 454 / 3000
# remove
# Iteration 455 / 3000
# remove
# Iteration 456 / 3000
# add
# Iteration 457 / 3000
# change_type
# Iteration 458 / 3000
# add
# Iteration 459 / 3000
# add
# Iteration 460 / 3000
# add
# Iteration 461 / 3000
# add
# Iteration 462 / 3000
# change_type
# Iteration 463 / 3000
# change_type
# Iteration 464 / 3000
# add
# Iteration 465 / 3000
# change_type
# Iteration 466 / 3000
# add
# Iteration 467 / 3000
# add
# Iteration 468 / 3000
# change_type
# Iteration 469 / 3000
# add
# Iteration 470 / 3000
# add
# Iteration 471 / 3000
# change_type
# Iteration 472 / 3000
# change_type
# Iteration 473 / 3000
# change_type
# Iteration 474 / 3000
# add
# Iteration 475 / 3000
# remove
# Iteration 476 / 3000
# remove
# Iteration 477 / 3000
# add
# Iteration 478 / 3000
# remove
# Iteration 479 / 3000
# add
# Iteration 480 / 3000
# change_type
# Iteration 481 / 3000
# change_type
# Iteration 482 / 3000
# add
# Iteration 483 / 3000
# remove
# Iteration 484 / 3000
# remove
# Iteration 485 / 3000
# change_type
# Iteration 486 / 3000
# change_type
# Iteration 487 / 3000
# change_type
# Iteration 488 / 3000
# add
# Iteration 489 / 3000
# add
# Iteration 490 / 3000
# change_type
# Iteration 491 / 3000
# add
# Iteration 492 / 3000
# change_type
# Iteration 493 / 3000
# add
# Iteration 494 / 3000
# change_type
# Iteration 495 / 3000
# add
# Iteration 496 / 3000
# remove
# Iteration 497 / 3000
# add
# Iteration 498 / 3000
# add
# Iteration 499 / 3000
# remove
# Iteration 500 / 3000
# remove
# Iteration 501 / 3000
# remove
# Iteration 502 / 3000
# add
# Iteration 503 / 3000
# add
# Iteration 504 / 3000
# remove
# Iteration 505 / 3000
# remove
# Iteration 506 / 3000
# change_type
# Iteration 507 / 3000
# add
# Iteration 508 / 3000
# remove
# Iteration 509 / 3000
# change_type
# Iteration 510 / 3000
# add
# Iteration 511 / 3000
# remove
# Iteration 512 / 3000
# add
# Iteration 513 / 3000
# remove
# Iteration 514 / 3000
# remove
# Iteration 515 / 3000
# add
# Iteration 516 / 3000
# add
# Iteration 517 / 3000
# change_type
# Iteration 518 / 3000
# add
# Iteration 519 / 3000
# remove
# Iteration 520 / 3000
# change_type
# Iteration 521 / 3000
# add
# Iteration 522 / 3000
# add
# Iteration 523 / 3000
# remove
# Iteration 524 / 3000
# remove
# Iteration 525 / 3000
# add
# Iteration 526 / 3000
# change_type
# Iteration 527 / 3000
# add
# Iteration 528 / 3000
# remove
# Iteration 529 / 3000
# add
# Iteration 530 / 3000
# change_type
# Iteration 531 / 3000
# change_type
# Iteration 532 / 3000
# add
# Iteration 533 / 3000
# change_type
# Iteration 534 / 3000
# add
# Iteration 535 / 3000
# remove
# Iteration 536 / 3000
# remove
# Iteration 537 / 3000
# change_type
# Iteration 538 / 3000
# remove
# Iteration 539 / 3000
# remove
# Iteration 540 / 3000
# change_type
# Iteration 541 / 3000
# change_type
# Iteration 542 / 3000
# remove
# Iteration 543 / 3000
# add
# Iteration 544 / 3000
# remove
# Iteration 545 / 3000
# remove
# Iteration 546 / 3000
# remove
# Iteration 547 / 3000
# change_type
# Iteration 548 / 3000
# remove
# Iteration 549 / 3000
# remove
# Iteration 550 / 3000
# change_type
# Iteration 551 / 3000
# add
# Iteration 552 / 3000
# remove
# Iteration 553 / 3000
# add
# Iteration 554 / 3000
# remove
# Iteration 555 / 3000
# add
# Iteration 556 / 3000
# add
# Iteration 557 / 3000
# add
# Iteration 558 / 3000
# change_type
# Iteration 559 / 3000
# add
# Iteration 560 / 3000
# add
# Iteration 561 / 3000
# remove
# Iteration 562 / 3000
# remove
# Iteration 563 / 3000
# change_type
# Iteration 564 / 3000
# add
# Iteration 565 / 3000
# add
# Iteration 566 / 3000
# remove
# Iteration 567 / 3000
# change_type
# Iteration 568 / 3000
# remove
# Iteration 569 / 3000
# change_type
# Iteration 570 / 3000
# add
# Iteration 571 / 3000
# remove
# Iteration 572 / 3000
# change_type
# Iteration 573 / 3000
# add
# Iteration 574 / 3000
# remove
# Iteration 575 / 3000
# change_type
# Iteration 576 / 3000
# remove
# Iteration 577 / 3000
# remove
# Iteration 578 / 3000
# change_type
# Iteration 579 / 3000
# remove
# Iteration 580 / 3000
# add
# Iteration 581 / 3000
# remove
# Iteration 582 / 3000
# change_type
# Iteration 583 / 3000
# change_type
# Iteration 584 / 3000
# change_type
# Iteration 585 / 3000
# add
# Iteration 586 / 3000
# remove
# Iteration 587 / 3000
# add
# Iteration 588 / 3000
# add
# Iteration 589 / 3000
# change_type
# Iteration 590 / 3000
# add
# Iteration 591 / 3000
# remove
# Iteration 592 / 3000
# remove
# Iteration 593 / 3000
# add
# Iteration 594 / 3000
# add
# Iteration 595 / 3000
# add
# Iteration 596 / 3000
# remove
# Iteration 597 / 3000
# remove
# Iteration 598 / 3000
# remove
# Iteration 599 / 3000
# remove
# Iteration 600 / 3000
# change_type
# Iteration 601 / 3000
# change_type
# Iteration 602 / 3000
# change_type
# Iteration 603 / 3000
# remove
# Iteration 604 / 3000
# add
# Iteration 605 / 3000
# remove
# Iteration 606 / 3000
# remove
# Iteration 607 / 3000
# add
# Iteration 608 / 3000
# change_type
# Iteration 609 / 3000
# remove
# Iteration 610 / 3000
# add
# Iteration 611 / 3000
# remove
# Iteration 612 / 3000
# remove
# Iteration 613 / 3000
# remove
# Iteration 614 / 3000
# add
# Iteration 615 / 3000
# add
# Iteration 616 / 3000
# change_type
# Iteration 617 / 3000
# remove
# Iteration 618 / 3000
# remove
# Iteration 619 / 3000
# remove
# Iteration 620 / 3000
# add
# Iteration 621 / 3000
# add
# Iteration 622 / 3000
# remove
# Iteration 623 / 3000
# remove
# Iteration 624 / 3000
# change_type
# Iteration 625 / 3000
# remove
# Iteration 626 / 3000
# add
# Iteration 627 / 3000
# remove
# Iteration 628 / 3000
# change_type
# Iteration 629 / 3000
# change_type
# Iteration 630 / 3000
# add
# Iteration 631 / 3000
# remove
# Iteration 632 / 3000
# remove
# Iteration 633 / 3000
# remove
# Iteration 634 / 3000
# change_type
# Iteration 635 / 3000
# add
# Iteration 636 / 3000
# remove
# Iteration 637 / 3000
# change_type
# Iteration 638 / 3000
# change_type
# Iteration 639 / 3000
# add
# Iteration 640 / 3000
# add
# Iteration 641 / 3000
# remove
# Iteration 642 / 3000
# remove
# Iteration 643 / 3000
# change_type
# Iteration 644 / 3000
# change_type
# Iteration 645 / 3000
# remove
# Iteration 646 / 3000
# change_type
# Iteration 647 / 3000
# add
# Iteration 648 / 3000
# change_type
# Iteration 649 / 3000
# change_type
# Iteration 650 / 3000
# remove
# Iteration 651 / 3000
# change_type
# Iteration 652 / 3000
# change_type
# Iteration 653 / 3000
# remove
# Iteration 654 / 3000
# change_type
# Iteration 655 / 3000
# remove
# Iteration 656 / 3000
# add
# Iteration 657 / 3000
# add
# Iteration 658 / 3000
# remove
# Iteration 659 / 3000
# add
# Iteration 660 / 3000
# add
# Iteration 661 / 3000
# add
# Iteration 662 / 3000
# change_type
# Iteration 663 / 3000
# add
# Iteration 664 / 3000
# add
# Iteration 665 / 3000
# add
# Iteration 666 / 3000
# add
# Iteration 667 / 3000
# remove
# Iteration 668 / 3000
# remove
# Iteration 669 / 3000
# change_type
# Iteration 670 / 3000
# change_type
# Iteration 671 / 3000
# change_type
# Iteration 672 / 3000
# remove
# Iteration 673 / 3000
# change_type
# Iteration 674 / 3000
# add
# Iteration 675 / 3000
# remove
# Iteration 676 / 3000
# change_type
# Iteration 677 / 3000
# change_type
# Iteration 678 / 3000
# add
# Iteration 679 / 3000
# add
# Iteration 680 / 3000
# add
# Iteration 681 / 3000
# remove
# Iteration 682 / 3000
# change_type
# Iteration 683 / 3000
# remove
# Iteration 684 / 3000
# remove
# Iteration 685 / 3000
# add
# Iteration 686 / 3000
# change_type
# Iteration 687 / 3000
# add
# Iteration 688 / 3000
# change_type
# Iteration 689 / 3000
# add
# Iteration 690 / 3000
# remove
# Iteration 691 / 3000
# change_type
# Iteration 692 / 3000
# change_type
# Iteration 693 / 3000
# remove
# Iteration 694 / 3000
# add
# Iteration 695 / 3000
# add
# Iteration 696 / 3000
# change_type
# Iteration 697 / 3000
# change_type
# Iteration 698 / 3000
# remove
# Iteration 699 / 3000
# change_type
# Iteration 700 / 3000
# remove
# Iteration 701 / 3000
# remove
# Iteration 702 / 3000
# add
# Iteration 703 / 3000
# add
# Iteration 704 / 3000
# add
# Iteration 705 / 3000
# remove
# Iteration 706 / 3000
# remove
# Iteration 707 / 3000
# remove
# Iteration 708 / 3000
# remove
# Iteration 709 / 3000
# add
# Iteration 710 / 3000
# remove
# Iteration 711 / 3000
# remove
# Iteration 712 / 3000
# remove
# Iteration 713 / 3000
# add
# Iteration 714 / 3000
# change_type
# Iteration 715 / 3000
# change_type
# Iteration 716 / 3000
# change_type
# Iteration 717 / 3000
# add
# Iteration 718 / 3000
# remove
# Iteration 719 / 3000
# remove
# Iteration 720 / 3000
# change_type
# Iteration 721 / 3000
# add
# Iteration 722 / 3000
# change_type
# Iteration 723 / 3000
# add
# Iteration 724 / 3000
# add
# Iteration 725 / 3000
# add
# Iteration 726 / 3000
# remove
# Iteration 727 / 3000
# add
# Iteration 728 / 3000
# remove
# Iteration 729 / 3000
# add
# Iteration 730 / 3000
# change_type
# Iteration 731 / 3000
# change_type
# Iteration 732 / 3000
# change_type
# Iteration 733 / 3000
# remove
# Iteration 734 / 3000
# remove
# Iteration 735 / 3000
# remove
# Iteration 736 / 3000
# remove
# Iteration 737 / 3000
# change_type
# Iteration 738 / 3000
# change_type
# Iteration 739 / 3000
# change_type
# Iteration 740 / 3000
# change_type
# Iteration 741 / 3000
# change_type
# Iteration 742 / 3000
# remove
# Iteration 743 / 3000
# remove
# Iteration 744 / 3000
# add
# Iteration 745 / 3000
# add
# Iteration 746 / 3000
# remove
# Iteration 747 / 3000
# add
# Iteration 748 / 3000
# change_type
# Iteration 749 / 3000
# add
# Iteration 750 / 3000
# add
# Iteration 751 / 3000
# add
# Iteration 752 / 3000
# remove
# Iteration 753 / 3000
# remove
# Iteration 754 / 3000
# remove
# Iteration 755 / 3000
# change_type
# Iteration 756 / 3000
# remove
# Iteration 757 / 3000
# change_type
# Iteration 758 / 3000
# change_type
# Iteration 759 / 3000
# remove
# Iteration 760 / 3000
# change_type
# Iteration 761 / 3000
# change_type
# Iteration 762 / 3000
# add
# Iteration 763 / 3000
# add
# Iteration 764 / 3000
# change_type
# Iteration 765 / 3000
# remove
# Iteration 766 / 3000
# remove
# Iteration 767 / 3000
# remove
# Iteration 768 / 3000
# add
# Iteration 769 / 3000
# add
# Iteration 770 / 3000
# add
# Iteration 771 / 3000
# add
# Iteration 772 / 3000
# change_type
# Iteration 773 / 3000
# remove
# Iteration 774 / 3000
# change_type
# Iteration 775 / 3000
# add
# Iteration 776 / 3000
# remove
# Iteration 777 / 3000
# add
# Iteration 778 / 3000
# change_type
# Iteration 779 / 3000
# remove
# Iteration 780 / 3000
# remove
# Iteration 781 / 3000
# add
# Iteration 782 / 3000
# remove
# Iteration 783 / 3000
# change_type
# Iteration 784 / 3000
# remove
# Iteration 785 / 3000
# change_type
# Iteration 786 / 3000
# change_type
# Iteration 787 / 3000
# add
# Iteration 788 / 3000
# add
# Iteration 789 / 3000
# change_type
# Iteration 790 / 3000
# change_type
# Iteration 791 / 3000
# remove
# Iteration 792 / 3000
# change_type
# Iteration 793 / 3000
# change_type
# Iteration 794 / 3000
# remove
# Iteration 795 / 3000
# remove
# Iteration 796 / 3000
# change_type
# Iteration 797 / 3000
# add
# Iteration 798 / 3000
# add
# Iteration 799 / 3000
# remove
# Iteration 800 / 3000
# add
# Iteration 801 / 3000
# remove
# Iteration 802 / 3000
# change_type
# Iteration 803 / 3000
# remove
# Iteration 804 / 3000
# remove
# Iteration 805 / 3000
# add
# Iteration 806 / 3000
# remove
# Iteration 807 / 3000
# add
# Iteration 808 / 3000
# add
# Iteration 809 / 3000
# change_type
# Iteration 810 / 3000
# add
# Iteration 811 / 3000
# remove
# Iteration 812 / 3000
# remove
# Iteration 813 / 3000
# remove
# Iteration 814 / 3000
# remove
# Iteration 815 / 3000
# change_type
# Iteration 816 / 3000
# add
# Iteration 817 / 3000
# remove
# Iteration 818 / 3000
# change_type
# Iteration 819 / 3000
# remove
# Iteration 820 / 3000
# change_type
# Iteration 821 / 3000
# add
# Iteration 822 / 3000
# remove
# Iteration 823 / 3000
# remove
# Iteration 824 / 3000
# change_type
# Iteration 825 / 3000
# change_type
# Iteration 826 / 3000
# add
# Iteration 827 / 3000
# change_type
# Iteration 828 / 3000
# change_type
# Iteration 829 / 3000
# change_type
# Iteration 830 / 3000
# change_type
# Iteration 831 / 3000
# change_type
# Iteration 832 / 3000
# change_type
# Iteration 833 / 3000
# change_type
# Iteration 834 / 3000
# change_type
# Iteration 835 / 3000
# change_type
# Iteration 836 / 3000
# change_type
# Iteration 837 / 3000
# remove
# Iteration 838 / 3000
# remove
# Iteration 839 / 3000
# remove
# Iteration 840 / 3000
# add
# Iteration 841 / 3000
# change_type
# Iteration 842 / 3000
# remove
# Iteration 843 / 3000
# change_type
# Iteration 844 / 3000
# change_type
# Iteration 845 / 3000
# add
# Iteration 846 / 3000
# change_type
# Iteration 847 / 3000
# remove
# Iteration 848 / 3000
# add
# Iteration 849 / 3000
# change_type
# Iteration 850 / 3000
# add
# Iteration 851 / 3000
# change_type
# Iteration 852 / 3000
# add
# Iteration 853 / 3000
# remove
# Iteration 854 / 3000
# remove
# Iteration 855 / 3000
# remove
# Iteration 856 / 3000
# change_type
# Iteration 857 / 3000
# remove
# Iteration 858 / 3000
# add
# Iteration 859 / 3000
# change_type
# Iteration 860 / 3000
# add
# Iteration 861 / 3000
# add
# Iteration 862 / 3000
# remove
# Iteration 863 / 3000
# add
# Iteration 864 / 3000
# change_type
# Iteration 865 / 3000
# add
# Iteration 866 / 3000
# remove
# Iteration 867 / 3000
# add
# Iteration 868 / 3000
# change_type
# Iteration 869 / 3000
# add
# Iteration 870 / 3000
# remove
# Iteration 871 / 3000
# add
# Iteration 872 / 3000
# add
# Iteration 873 / 3000
# add
# Iteration 874 / 3000
# change_type
# Iteration 875 / 3000
# add
# Iteration 876 / 3000
# add
# Iteration 877 / 3000
# change_type
# Iteration 878 / 3000
# change_type
# Iteration 879 / 3000
# add
# Iteration 880 / 3000
# change_type
# Iteration 881 / 3000
# change_type
# Iteration 882 / 3000
# change_type
# Iteration 883 / 3000
# change_type
# Iteration 884 / 3000
# add
# Iteration 885 / 3000
# change_type
# Iteration 886 / 3000
# remove
# Iteration 887 / 3000
# change_type
# Iteration 888 / 3000
# change_type
# Iteration 889 / 3000
# change_type
# Iteration 890 / 3000
# remove
# Iteration 891 / 3000
# remove
# Iteration 892 / 3000
# remove
# Iteration 893 / 3000
# remove
# Iteration 894 / 3000
# add
# Iteration 895 / 3000
# add
# Iteration 896 / 3000
# remove
# Iteration 897 / 3000
# remove
# Iteration 898 / 3000
# add
# Iteration 899 / 3000
# add
# Iteration 900 / 3000
# change_type
# Iteration 901 / 3000
# remove
# Iteration 902 / 3000
# change_type
# Iteration 903 / 3000
# add
# Iteration 904 / 3000
# remove
# Iteration 905 / 3000
# add
# Iteration 906 / 3000
# add
# Iteration 907 / 3000
# remove
# Iteration 908 / 3000
# add
# Iteration 909 / 3000
# add
# Iteration 910 / 3000
# add
# Iteration 911 / 3000
# remove
# Iteration 912 / 3000
# change_type
# Iteration 913 / 3000
# change_type
# Iteration 914 / 3000
# change_type
# Iteration 915 / 3000
# add
# Iteration 916 / 3000
# change_type
# Iteration 917 / 3000
# add
# Iteration 918 / 3000
# remove
# Iteration 919 / 3000
# remove
# Iteration 920 / 3000
# add
# Iteration 921 / 3000
# add
# Iteration 922 / 3000
# change_type
# Iteration 923 / 3000
# add
# Iteration 924 / 3000
# add
# Iteration 925 / 3000
# add
# Iteration 926 / 3000
# add
# Iteration 927 / 3000
# change_type
# Iteration 928 / 3000
# remove
# Iteration 929 / 3000
# remove
# Iteration 930 / 3000
# add
# Iteration 931 / 3000
# add
# Iteration 932 / 3000
# change_type
# Iteration 933 / 3000
# remove
# Iteration 934 / 3000
# change_type
# Iteration 935 / 3000
# add
# Iteration 936 / 3000
# add
# Iteration 937 / 3000
# add
# Iteration 938 / 3000
# remove
# Iteration 939 / 3000
# add
# Iteration 940 / 3000
# change_type
# Iteration 941 / 3000
# remove
# Iteration 942 / 3000
# remove
# Iteration 943 / 3000
# add
# Iteration 944 / 3000
# remove
# Iteration 945 / 3000
# change_type
# Iteration 946 / 3000
# add
# Iteration 947 / 3000
# change_type
# Iteration 948 / 3000
# add
# Iteration 949 / 3000
# add
# Iteration 950 / 3000
# change_type
# Iteration 951 / 3000
# add
# Iteration 952 / 3000
# change_type
# Iteration 953 / 3000
# change_type
# Iteration 954 / 3000
# add
# Iteration 955 / 3000
# remove
# Iteration 956 / 3000
# change_type
# Iteration 957 / 3000
# change_type
# Iteration 958 / 3000
# change_type
# Iteration 959 / 3000
# remove
# Iteration 960 / 3000
# change_type
# Iteration 961 / 3000
# change_type
# Iteration 962 / 3000
# remove
# Iteration 963 / 3000
# remove
# Iteration 964 / 3000
# remove
# Iteration 965 / 3000
# add
# Iteration 966 / 3000
# remove
# Iteration 967 / 3000
# change_type
# Iteration 968 / 3000
# add
# Iteration 969 / 3000
# change_type
# Iteration 970 / 3000
# change_type
# Iteration 971 / 3000
# remove
# Iteration 972 / 3000
# change_type
# Iteration 973 / 3000
# add
# Iteration 974 / 3000
# remove
# Iteration 975 / 3000
# change_type
# Iteration 976 / 3000
# add
# Iteration 977 / 3000
# remove
# Iteration 978 / 3000
# change_type
# Iteration 979 / 3000
# change_type
# Iteration 980 / 3000
# add
# Iteration 981 / 3000
# change_type
# Iteration 982 / 3000
# add
# Iteration 983 / 3000
# remove
# Iteration 984 / 3000
# change_type
# Iteration 985 / 3000
# add
# Iteration 986 / 3000
# add
# Iteration 987 / 3000
# remove
# Iteration 988 / 3000
# remove
# Iteration 989 / 3000
# remove
# Iteration 990 / 3000
# add
# Iteration 991 / 3000
# add
# Iteration 992 / 3000
# add
# Iteration 993 / 3000
# add
# Iteration 994 / 3000
# add
# Iteration 995 / 3000
# change_type
# Iteration 996 / 3000
# change_type
# Iteration 997 / 3000
# change_type
# Iteration 998 / 3000
# add
# Iteration 999 / 3000
# change_type
# Iteration 1000 / 3000
# remove
# Iteration 1001 / 3000
# add
# Iteration 1002 / 3000
# add
# Iteration 1003 / 3000
# change_type
# Iteration 1004 / 3000
# remove
# Iteration 1005 / 3000
# change_type
# Iteration 1006 / 3000
# remove
# Iteration 1007 / 3000
# remove
# Iteration 1008 / 3000
# change_type
# Iteration 1009 / 3000
# change_type
# Iteration 1010 / 3000
# remove
# Iteration 1011 / 3000
# add
# Iteration 1012 / 3000
# remove
# Iteration 1013 / 3000
# change_type
# Iteration 1014 / 3000
# add
# Iteration 1015 / 3000
# change_type
# Iteration 1016 / 3000
# change_type
# Iteration 1017 / 3000
# remove
# Iteration 1018 / 3000
# change_type
# Iteration 1019 / 3000
# add
# Iteration 1020 / 3000
# remove
# Iteration 1021 / 3000
# add
# Iteration 1022 / 3000
# add
# Iteration 1023 / 3000
# change_type
# Iteration 1024 / 3000
# change_type
# Iteration 1025 / 3000
# change_type
# Iteration 1026 / 3000
# change_type
# Iteration 1027 / 3000
# change_type
# Iteration 1028 / 3000
# remove
# Iteration 1029 / 3000
# remove
# Iteration 1030 / 3000
# add
# Iteration 1031 / 3000
# add
# Iteration 1032 / 3000
# add
# Iteration 1033 / 3000
# add
# Iteration 1034 / 3000
# change_type
# Iteration 1035 / 3000
# change_type
# Iteration 1036 / 3000
# add
# Iteration 1037 / 3000
# change_type
# Iteration 1038 / 3000
# add
# Iteration 1039 / 3000
# change_type
# Iteration 1040 / 3000
# change_type
# Iteration 1041 / 3000
# change_type
# Iteration 1042 / 3000
# change_type
# Iteration 1043 / 3000
# add
# Iteration 1044 / 3000
# remove
# Iteration 1045 / 3000
# change_type
# Iteration 1046 / 3000
# change_type
# Iteration 1047 / 3000
# remove
# Iteration 1048 / 3000
# add
# Iteration 1049 / 3000
# add
# Iteration 1050 / 3000
# remove
# Iteration 1051 / 3000
# remove
# Iteration 1052 / 3000
# remove
# Iteration 1053 / 3000
# remove
# Iteration 1054 / 3000
# remove
# Iteration 1055 / 3000
# change_type
# Iteration 1056 / 3000
# add
# Iteration 1057 / 3000
# change_type
# Iteration 1058 / 3000
# change_type
# Iteration 1059 / 3000
# remove
# Iteration 1060 / 3000
# remove
# Iteration 1061 / 3000
# remove
# Iteration 1062 / 3000
# add
# Iteration 1063 / 3000
# remove
# Iteration 1064 / 3000
# change_type
# Iteration 1065 / 3000
# add
# Iteration 1066 / 3000
# change_type
# Iteration 1067 / 3000
# change_type
# Iteration 1068 / 3000
# add
# Iteration 1069 / 3000
# add
# Iteration 1070 / 3000
# change_type
# Iteration 1071 / 3000
# remove
# Iteration 1072 / 3000
# remove
# Iteration 1073 / 3000
# add
# Iteration 1074 / 3000
# remove
# Iteration 1075 / 3000
# change_type
# Iteration 1076 / 3000
# remove
# Iteration 1077 / 3000
# add
# Iteration 1078 / 3000
# change_type
# Iteration 1079 / 3000
# change_type
# Iteration 1080 / 3000
# remove
# Iteration 1081 / 3000
# change_type
# Iteration 1082 / 3000
# remove
# Iteration 1083 / 3000
# add
# Iteration 1084 / 3000
# change_type
# Iteration 1085 / 3000
# remove
# Iteration 1086 / 3000
# change_type
# Iteration 1087 / 3000
# change_type
# Iteration 1088 / 3000
# remove
# Iteration 1089 / 3000
# add
# Iteration 1090 / 3000
# add
# Iteration 1091 / 3000
# change_type
# Iteration 1092 / 3000
# change_type
# Iteration 1093 / 3000
# change_type
# Iteration 1094 / 3000
# change_type
# Iteration 1095 / 3000
# add
# Iteration 1096 / 3000
# add
# Iteration 1097 / 3000
# remove
# Iteration 1098 / 3000
# remove
# Iteration 1099 / 3000
# remove
# Iteration 1100 / 3000
# add
# Iteration 1101 / 3000
# remove
# Iteration 1102 / 3000
# remove
# Iteration 1103 / 3000
# add
# Iteration 1104 / 3000
# remove
# Iteration 1105 / 3000
# remove
# Iteration 1106 / 3000
# add
# Iteration 1107 / 3000
# remove
# Iteration 1108 / 3000
# add
# Iteration 1109 / 3000
# remove
# Iteration 1110 / 3000
# add
# Iteration 1111 / 3000
# remove
# Iteration 1112 / 3000
# add
# Iteration 1113 / 3000
# add
# Iteration 1114 / 3000
# remove
# Iteration 1115 / 3000
# change_type
# Iteration 1116 / 3000
# remove
# Iteration 1117 / 3000
# add
# Iteration 1118 / 3000
# change_type
# Iteration 1119 / 3000
# change_type
# Iteration 1120 / 3000
# remove
# Iteration 1121 / 3000
# change_type
# Iteration 1122 / 3000
# change_type
# Iteration 1123 / 3000
# remove
# Iteration 1124 / 3000
# remove
# Iteration 1125 / 3000
# change_type
# Iteration 1126 / 3000
# add
# Iteration 1127 / 3000
# remove
# Iteration 1128 / 3000
# remove
# Iteration 1129 / 3000
# remove
# Iteration 1130 / 3000
# remove
# Iteration 1131 / 3000
# change_type
# Iteration 1132 / 3000
# change_type
# Iteration 1133 / 3000
# add
# Iteration 1134 / 3000
# change_type
# Iteration 1135 / 3000
# add
# Iteration 1136 / 3000
# add
# Iteration 1137 / 3000
# remove
# Iteration 1138 / 3000
# remove
# Iteration 1139 / 3000
# change_type
# Iteration 1140 / 3000
# add
# Iteration 1141 / 3000
# remove
# Iteration 1142 / 3000
# remove
# Iteration 1143 / 3000
# add
# Iteration 1144 / 3000
# change_type
# Iteration 1145 / 3000
# change_type
# Iteration 1146 / 3000
# add
# Iteration 1147 / 3000
# change_type
# Iteration 1148 / 3000
# change_type
# Iteration 1149 / 3000
# change_type
# Iteration 1150 / 3000
# add
# Iteration 1151 / 3000
# remove
# Iteration 1152 / 3000
# add
# Iteration 1153 / 3000
# add
# Iteration 1154 / 3000
# change_type
# Iteration 1155 / 3000
# remove
# Iteration 1156 / 3000
# remove
# Iteration 1157 / 3000
# change_type
# Iteration 1158 / 3000
# remove
# Iteration 1159 / 3000
# add
# Iteration 1160 / 3000
# change_type
# Iteration 1161 / 3000
# remove
# Iteration 1162 / 3000
# add
# Iteration 1163 / 3000
# change_type
# Iteration 1164 / 3000
# remove
# Iteration 1165 / 3000
# add
# Iteration 1166 / 3000
# add
# Iteration 1167 / 3000
# add
# Iteration 1168 / 3000
# add
# Iteration 1169 / 3000
# remove
# Iteration 1170 / 3000
# change_type
# Iteration 1171 / 3000
# add
# Iteration 1172 / 3000
# add
# Iteration 1173 / 3000
# remove
# Iteration 1174 / 3000
# add
# Iteration 1175 / 3000
# remove
# Iteration 1176 / 3000
# change_type
# Iteration 1177 / 3000
# change_type
# Iteration 1178 / 3000
# add
# Iteration 1179 / 3000
# change_type
# Iteration 1180 / 3000
# change_type
# Iteration 1181 / 3000
# add
# Iteration 1182 / 3000
# remove
# Iteration 1183 / 3000
# remove
# Iteration 1184 / 3000
# remove
# Iteration 1185 / 3000
# remove
# Iteration 1186 / 3000
# change_type
# Iteration 1187 / 3000
# change_type
# Iteration 1188 / 3000
# add
# Iteration 1189 / 3000
# change_type
# Iteration 1190 / 3000
# remove
# Iteration 1191 / 3000
# change_type
# Iteration 1192 / 3000
# change_type
# Iteration 1193 / 3000
# remove
# Iteration 1194 / 3000
# remove
# Iteration 1195 / 3000
# remove
# Iteration 1196 / 3000
# change_type
# Iteration 1197 / 3000
# remove
# Iteration 1198 / 3000
# add
# Iteration 1199 / 3000
# remove
# Iteration 1200 / 3000
# remove
# Iteration 1201 / 3000
# remove
# Iteration 1202 / 3000
# change_type
# Iteration 1203 / 3000
# change_type
# Iteration 1204 / 3000
# add
# Iteration 1205 / 3000
# add
# Iteration 1206 / 3000
# remove
# Iteration 1207 / 3000
# change_type
# Iteration 1208 / 3000
# remove
# Iteration 1209 / 3000
# change_type
# Iteration 1210 / 3000
# change_type
# Iteration 1211 / 3000
# remove
# Iteration 1212 / 3000
# remove
# Iteration 1213 / 3000
# add
# Iteration 1214 / 3000
# add
# Iteration 1215 / 3000
# change_type
# Iteration 1216 / 3000
# add
# Iteration 1217 / 3000
# add
# Iteration 1218 / 3000
# remove
# Iteration 1219 / 3000
# change_type
# Iteration 1220 / 3000
# remove
# Iteration 1221 / 3000
# remove
# Iteration 1222 / 3000
# add
# Iteration 1223 / 3000
# add
# Iteration 1224 / 3000
# add
# Iteration 1225 / 3000
# add
# Iteration 1226 / 3000
# add
# Iteration 1227 / 3000
# add
# Iteration 1228 / 3000
# add
# Iteration 1229 / 3000
# remove
# Iteration 1230 / 3000
# remove
# Iteration 1231 / 3000
# change_type
# Iteration 1232 / 3000
# add
# Iteration 1233 / 3000
# remove
# Iteration 1234 / 3000
# add
# Iteration 1235 / 3000
# add
# Iteration 1236 / 3000
# change_type
# Iteration 1237 / 3000
# remove
# Iteration 1238 / 3000
# remove
# Iteration 1239 / 3000
# change_type
# Iteration 1240 / 3000
# change_type
# Iteration 1241 / 3000
# add
# Iteration 1242 / 3000
# change_type
# Iteration 1243 / 3000
# remove
# Iteration 1244 / 3000
# change_type
# Iteration 1245 / 3000
# change_type
# Iteration 1246 / 3000
# change_type
# Iteration 1247 / 3000
# change_type
# Iteration 1248 / 3000
# change_type
# Iteration 1249 / 3000
# add
# Iteration 1250 / 3000
# change_type
# Iteration 1251 / 3000
# change_type
# Iteration 1252 / 3000
# add
# Iteration 1253 / 3000
# add
# Iteration 1254 / 3000
# add
# Iteration 1255 / 3000
# change_type
# Iteration 1256 / 3000
# add
# Iteration 1257 / 3000
# change_type
# Iteration 1258 / 3000
# add
# Iteration 1259 / 3000
# change_type
# Iteration 1260 / 3000
# add
# Iteration 1261 / 3000
# change_type
# Iteration 1262 / 3000
# change_type
# Iteration 1263 / 3000
# add
# Iteration 1264 / 3000
# change_type
# Iteration 1265 / 3000
# add
# Iteration 1266 / 3000
# add
# Iteration 1267 / 3000
# add
# Iteration 1268 / 3000
# add
# Iteration 1269 / 3000
# remove
# Iteration 1270 / 3000
# add
# Iteration 1271 / 3000
# add
# Iteration 1272 / 3000
# remove
# Iteration 1273 / 3000
# add
# Iteration 1274 / 3000
# change_type
# Iteration 1275 / 3000
# remove
# Iteration 1276 / 3000
# change_type
# Iteration 1277 / 3000
# remove
# Iteration 1278 / 3000
# add
# Iteration 1279 / 3000
# change_type
# Iteration 1280 / 3000
# remove
# Iteration 1281 / 3000
# add
# Iteration 1282 / 3000
# add
# Iteration 1283 / 3000
# change_type
# Iteration 1284 / 3000
# add
# Iteration 1285 / 3000
# change_type
# Iteration 1286 / 3000
# change_type
# Iteration 1287 / 3000
# change_type
# Iteration 1288 / 3000
# add
# Iteration 1289 / 3000
# add
# Iteration 1290 / 3000
# add
# Iteration 1291 / 3000
# add
# Iteration 1292 / 3000
# add
# Iteration 1293 / 3000
# remove
# Iteration 1294 / 3000
# change_type
# Iteration 1295 / 3000
# change_type
# Iteration 1296 / 3000
# change_type
# Iteration 1297 / 3000
# add
# Iteration 1298 / 3000
# remove
# Iteration 1299 / 3000
# change_type
# Iteration 1300 / 3000
# change_type
# Iteration 1301 / 3000
# add
# Iteration 1302 / 3000
# add
# Iteration 1303 / 3000
# add
# Iteration 1304 / 3000
# add
# Iteration 1305 / 3000
# add
# Iteration 1306 / 3000
# add
# Iteration 1307 / 3000
# change_type
# Iteration 1308 / 3000
# remove
# Iteration 1309 / 3000
# change_type
# Iteration 1310 / 3000
# remove
# Iteration 1311 / 3000
# remove
# Iteration 1312 / 3000
# add
# Iteration 1313 / 3000
# add
# Iteration 1314 / 3000
# change_type
# Iteration 1315 / 3000
# remove
# Iteration 1316 / 3000
# change_type
# Iteration 1317 / 3000
# change_type
# Iteration 1318 / 3000
# remove
# Iteration 1319 / 3000
# add
# Iteration 1320 / 3000
# add
# Iteration 1321 / 3000
# add
# Iteration 1322 / 3000
# change_type
# Iteration 1323 / 3000
# remove
# Iteration 1324 / 3000
# remove
# Iteration 1325 / 3000
# remove
# Iteration 1326 / 3000
# add
# Iteration 1327 / 3000
# change_type
# Iteration 1328 / 3000
# change_type
# Iteration 1329 / 3000
# change_type
# Iteration 1330 / 3000
# remove
# Iteration 1331 / 3000
# add
# Iteration 1332 / 3000
# add
# Iteration 1333 / 3000
# remove
# Iteration 1334 / 3000
# change_type
# Iteration 1335 / 3000
# add
# Iteration 1336 / 3000
# add
# Iteration 1337 / 3000
# add
# Iteration 1338 / 3000
# add
# Iteration 1339 / 3000
# add
# Iteration 1340 / 3000
# remove
# Iteration 1341 / 3000
# add
# Iteration 1342 / 3000
# remove
# Iteration 1343 / 3000
# change_type
# Iteration 1344 / 3000
# remove
# Iteration 1345 / 3000
# change_type
# Iteration 1346 / 3000
# add
# Iteration 1347 / 3000
# remove
# Iteration 1348 / 3000
# add
# Iteration 1349 / 3000
# remove
# Iteration 1350 / 3000
# add
# Iteration 1351 / 3000
# add
# Iteration 1352 / 3000
# change_type
# Iteration 1353 / 3000
# remove
# Iteration 1354 / 3000
# change_type
# Iteration 1355 / 3000
# remove
# Iteration 1356 / 3000
# remove
# Iteration 1357 / 3000
# remove
# Iteration 1358 / 3000
# change_type
# Iteration 1359 / 3000
# remove
# Iteration 1360 / 3000
# add
# Iteration 1361 / 3000
# add
# Iteration 1362 / 3000
# change_type
# Iteration 1363 / 3000
# change_type
# Iteration 1364 / 3000
# remove
# Iteration 1365 / 3000
# change_type
# Iteration 1366 / 3000
# change_type
# Iteration 1367 / 3000
# change_type
# Iteration 1368 / 3000
# add
# Iteration 1369 / 3000
# add
# Iteration 1370 / 3000
# remove
# Iteration 1371 / 3000
# remove
# Iteration 1372 / 3000
# remove
# Iteration 1373 / 3000
# add
# Iteration 1374 / 3000
# change_type
# Iteration 1375 / 3000
# add
# Iteration 1376 / 3000
# remove
# Iteration 1377 / 3000
# add
# Iteration 1378 / 3000
# add
# Iteration 1379 / 3000
# change_type
# Iteration 1380 / 3000
# add
# Iteration 1381 / 3000
# change_type
# Iteration 1382 / 3000
# add
# Iteration 1383 / 3000
# add
# Iteration 1384 / 3000
# change_type
# Iteration 1385 / 3000
# change_type
# Iteration 1386 / 3000
# remove
# Iteration 1387 / 3000
# add
# Iteration 1388 / 3000
# remove
# Iteration 1389 / 3000
# remove
# Iteration 1390 / 3000
# change_type
# Iteration 1391 / 3000
# add
# Iteration 1392 / 3000
# change_type
# Iteration 1393 / 3000
# add
# Iteration 1394 / 3000
# change_type
# Iteration 1395 / 3000
# add
# Iteration 1396 / 3000
# remove
# Iteration 1397 / 3000
# change_type
# Iteration 1398 / 3000
# change_type
# Iteration 1399 / 3000
# change_type
# Iteration 1400 / 3000
# add
# Iteration 1401 / 3000
# change_type
# Iteration 1402 / 3000
# remove
# Iteration 1403 / 3000
# add
# Iteration 1404 / 3000
# add
# Iteration 1405 / 3000
# change_type
# Iteration 1406 / 3000
# change_type
# Iteration 1407 / 3000
# add
# Iteration 1408 / 3000
# add
# Iteration 1409 / 3000
# remove
# Iteration 1410 / 3000
# add
# Iteration 1411 / 3000
# change_type
# Iteration 1412 / 3000
# change_type
# Iteration 1413 / 3000
# change_type
# Iteration 1414 / 3000
# add
# Iteration 1415 / 3000
# change_type
# Iteration 1416 / 3000
# remove
# Iteration 1417 / 3000
# change_type
# Iteration 1418 / 3000
# remove
# Iteration 1419 / 3000
# change_type
# Iteration 1420 / 3000
# remove
# Iteration 1421 / 3000
# change_type
# Iteration 1422 / 3000
# remove
# Iteration 1423 / 3000
# add
# Iteration 1424 / 3000
# remove
# Iteration 1425 / 3000
# remove
# Iteration 1426 / 3000
# change_type
# Iteration 1427 / 3000
# remove
# Iteration 1428 / 3000
# add
# Iteration 1429 / 3000
# change_type
# Iteration 1430 / 3000
# add
# Iteration 1431 / 3000
# add
# Iteration 1432 / 3000
# remove
# Iteration 1433 / 3000
# add
# Iteration 1434 / 3000
# add
# Iteration 1435 / 3000
# change_type
# Iteration 1436 / 3000
# remove
# Iteration 1437 / 3000
# change_type
# Iteration 1438 / 3000
# change_type
# Iteration 1439 / 3000
# change_type
# Iteration 1440 / 3000
# change_type
# Iteration 1441 / 3000
# add
# Iteration 1442 / 3000
# change_type
# Iteration 1443 / 3000
# add
# Iteration 1444 / 3000
# change_type
# Iteration 1445 / 3000
# change_type
# Iteration 1446 / 3000
# change_type
# Iteration 1447 / 3000
# add
# Iteration 1448 / 3000
# add
# Iteration 1449 / 3000
# add
# Iteration 1450 / 3000
# remove
# Iteration 1451 / 3000
# add
# Iteration 1452 / 3000
# change_type
# Iteration 1453 / 3000
# change_type
# Iteration 1454 / 3000
# add
# Iteration 1455 / 3000
# remove
# Iteration 1456 / 3000
# change_type
# Iteration 1457 / 3000
# remove
# Iteration 1458 / 3000
# change_type
# Iteration 1459 / 3000
# remove
# Iteration 1460 / 3000
# remove
# Iteration 1461 / 3000
# add
# Iteration 1462 / 3000
# add
# Iteration 1463 / 3000
# remove
# Iteration 1464 / 3000
# change_type
# Iteration 1465 / 3000
# change_type
# Iteration 1466 / 3000
# add
# Iteration 1467 / 3000
# change_type
# Iteration 1468 / 3000
# change_type
# Iteration 1469 / 3000
# add
# Iteration 1470 / 3000
# remove
# Iteration 1471 / 3000
# add
# Iteration 1472 / 3000
# remove
# Iteration 1473 / 3000
# add
# Iteration 1474 / 3000
# change_type
# Iteration 1475 / 3000
# change_type
# Iteration 1476 / 3000
# change_type
# Iteration 1477 / 3000
# change_type
# Iteration 1478 / 3000
# add
# Iteration 1479 / 3000
# remove
# Iteration 1480 / 3000
# remove
# Iteration 1481 / 3000
# change_type
# Iteration 1482 / 3000
# remove
# Iteration 1483 / 3000
# add
# Iteration 1484 / 3000
# remove
# Iteration 1485 / 3000
# add
# Iteration 1486 / 3000
# remove
# Iteration 1487 / 3000
# remove
# Iteration 1488 / 3000
# remove
# Iteration 1489 / 3000
# add
# Iteration 1490 / 3000
# change_type
# Iteration 1491 / 3000
# change_type
# Iteration 1492 / 3000
# remove
# Iteration 1493 / 3000
# remove
# Iteration 1494 / 3000
# add
# Iteration 1495 / 3000
# add
# Iteration 1496 / 3000
# remove
# Iteration 1497 / 3000
# change_type
# Iteration 1498 / 3000
# add
# Iteration 1499 / 3000
# remove
# Iteration 1500 / 3000
# add
# Iteration 1501 / 3000
# remove
# Iteration 1502 / 3000
# add
# Iteration 1503 / 3000
# remove
# Iteration 1504 / 3000
# change_type
# Iteration 1505 / 3000
# add
# Iteration 1506 / 3000
# change_type
# Iteration 1507 / 3000
# remove
# Iteration 1508 / 3000
# change_type
# Iteration 1509 / 3000
# remove
# Iteration 1510 / 3000
# add
# Iteration 1511 / 3000
# add
# Iteration 1512 / 3000
# change_type
# Iteration 1513 / 3000
# add
# Iteration 1514 / 3000
# change_type
# Iteration 1515 / 3000
# remove
# Iteration 1516 / 3000
# change_type
# Iteration 1517 / 3000
# change_type
# Iteration 1518 / 3000
# change_type
# Iteration 1519 / 3000
# change_type
# Iteration 1520 / 3000
# change_type
# Iteration 1521 / 3000
# change_type
# Iteration 1522 / 3000
# remove
# Iteration 1523 / 3000
# change_type
# Iteration 1524 / 3000
# change_type
# Iteration 1525 / 3000
# remove
# Iteration 1526 / 3000
# remove
# Iteration 1527 / 3000
# add
# Iteration 1528 / 3000
# add
# Iteration 1529 / 3000
# remove
# Iteration 1530 / 3000
# remove
# Iteration 1531 / 3000
# remove
# Iteration 1532 / 3000
# remove
# Iteration 1533 / 3000
# remove
# Iteration 1534 / 3000
# add
# Iteration 1535 / 3000
# remove
# Iteration 1536 / 3000
# add
# Iteration 1537 / 3000
# add
# Iteration 1538 / 3000
# change_type
# Iteration 1539 / 3000
# remove
# Iteration 1540 / 3000
# change_type
# Iteration 1541 / 3000
# change_type
# Iteration 1542 / 3000
# change_type
# Iteration 1543 / 3000
# remove
# Iteration 1544 / 3000
# remove
# Iteration 1545 / 3000
# change_type
# Iteration 1546 / 3000
# remove
# Iteration 1547 / 3000
# change_type
# Iteration 1548 / 3000
# remove
# Iteration 1549 / 3000
# change_type
# Iteration 1550 / 3000
# remove
# Iteration 1551 / 3000
# remove
# Iteration 1552 / 3000
# change_type
# Iteration 1553 / 3000
# change_type
# Iteration 1554 / 3000
# add
# Iteration 1555 / 3000
# remove
# Iteration 1556 / 3000
# remove
# Iteration 1557 / 3000
# change_type
# Iteration 1558 / 3000
# add
# Iteration 1559 / 3000
# remove
# Iteration 1560 / 3000
# add
# Iteration 1561 / 3000
# remove
# Iteration 1562 / 3000
# remove
# Iteration 1563 / 3000
# remove
# Iteration 1564 / 3000
# add
# Iteration 1565 / 3000
# remove
# Iteration 1566 / 3000
# change_type
# Iteration 1567 / 3000
# change_type
# Iteration 1568 / 3000
# remove
# Iteration 1569 / 3000
# change_type
# Iteration 1570 / 3000
# remove
# Iteration 1571 / 3000
# add
# Iteration 1572 / 3000
# change_type
# Iteration 1573 / 3000
# add
# Iteration 1574 / 3000
# change_type
# Iteration 1575 / 3000
# add
# Iteration 1576 / 3000
# remove
# Iteration 1577 / 3000
# remove
# Iteration 1578 / 3000
# change_type
# Iteration 1579 / 3000
# add
# Iteration 1580 / 3000
# change_type
# Iteration 1581 / 3000
# change_type
# Iteration 1582 / 3000
# remove
# Iteration 1583 / 3000
# change_type
# Iteration 1584 / 3000
# remove
# Iteration 1585 / 3000
# change_type
# Iteration 1586 / 3000
# add
# Iteration 1587 / 3000
# change_type
# Iteration 1588 / 3000
# change_type
# Iteration 1589 / 3000
# add
# Iteration 1590 / 3000
# change_type
# Iteration 1591 / 3000
# remove
# Iteration 1592 / 3000
# add
# Iteration 1593 / 3000
# add
# Iteration 1594 / 3000
# remove
# Iteration 1595 / 3000
# remove
# Iteration 1596 / 3000
# change_type
# Iteration 1597 / 3000
# add
# Iteration 1598 / 3000
# remove
# Iteration 1599 / 3000
# add
# Iteration 1600 / 3000
# add
# Iteration 1601 / 3000
# add
# Iteration 1602 / 3000
# add
# Iteration 1603 / 3000
# add
# Iteration 1604 / 3000
# add
# Iteration 1605 / 3000
# change_type
# Iteration 1606 / 3000
# remove
# Iteration 1607 / 3000
# add
# Iteration 1608 / 3000
# remove
# Iteration 1609 / 3000
# add
# Iteration 1610 / 3000
# remove
# Iteration 1611 / 3000
# add
# Iteration 1612 / 3000
# change_type
# Iteration 1613 / 3000
# add
# Iteration 1614 / 3000
# remove
# Iteration 1615 / 3000
# change_type
# Iteration 1616 / 3000
# add
# Iteration 1617 / 3000
# remove
# Iteration 1618 / 3000
# add
# Iteration 1619 / 3000
# remove
# Iteration 1620 / 3000
# remove
# Iteration 1621 / 3000
# remove
# Iteration 1622 / 3000
# add
# Iteration 1623 / 3000
# remove
# Iteration 1624 / 3000
# change_type
# Iteration 1625 / 3000
# remove
# Iteration 1626 / 3000
# change_type
# Iteration 1627 / 3000
# remove
# Iteration 1628 / 3000
# add
# Iteration 1629 / 3000
# change_type
# Iteration 1630 / 3000
# remove
# Iteration 1631 / 3000
# remove
# Iteration 1632 / 3000
# remove
# Iteration 1633 / 3000
# change_type
# Iteration 1634 / 3000
# add
# Iteration 1635 / 3000
# remove
# Iteration 1636 / 3000
# remove
# Iteration 1637 / 3000
# change_type
# Iteration 1638 / 3000
# change_type
# Iteration 1639 / 3000
# change_type
# Iteration 1640 / 3000
# add
# Iteration 1641 / 3000
# remove
# Iteration 1642 / 3000
# remove
# Iteration 1643 / 3000
# add
# Iteration 1644 / 3000
# remove
# Iteration 1645 / 3000
# add
# Iteration 1646 / 3000
# add
# Iteration 1647 / 3000
# remove
# Iteration 1648 / 3000
# remove
# Iteration 1649 / 3000
# remove
# Iteration 1650 / 3000
# add
# Iteration 1651 / 3000
# change_type
# Iteration 1652 / 3000
# add
# ...
# change_type
# Iteration 2465 / 3000
# add
# Iteration 2466 / 3000
# change_type
# Iteration 2467 / 3000
# change_type
# Iteration 2468 / 3000
# add
# Iteration 2469 / 3000
# add
# Iteration 2470 / 3000
# add
# Iteration 2471 / 3000
# remove
# Iteration 2472 / 3000
# change_type
# Iteration 2473 / 3000
# remove
# Iteration 2474 / 3000
# change_type
# Iteration 2475 / 3000
# change_type
# Iteration 2476 / 3000
# remove
# Iteration 2477 / 3000
# add
# Iteration 2478 / 3000
# remove
# Iteration 2479 / 3000
# change_type
# Iteration 2480 / 3000
# remove
# Iteration 2481 / 3000
# change_type
# Iteration 2482 / 3000
# change_type
# Iteration 2483 / 3000
# remove
# Iteration 2484 / 3000
# change_type
# Iteration 2485 / 3000
# change_type
# Iteration 2486 / 3000
# change_type
# Iteration 2487 / 3000
# change_type
# Iteration 2488 / 3000
# remove
# Iteration 2489 / 3000
# change_type
# Iteration 2490 / 3000
# add
# Iteration 2491 / 3000
# remove
# Iteration 2492 / 3000
# change_type
# Iteration 2493 / 3000
# remove
# Iteration 2494 / 3000
# add
# Iteration 2495 / 3000
# remove
# Iteration 2496 / 3000
# change_type
# Iteration 2497 / 3000
# add
# Iteration 2498 / 3000
# add
# Iteration 2499 / 3000
# add
# Iteration 2500 / 3000
# add
# Iteration 2501 / 3000
# change_type
# Iteration 2502 / 3000
# change_type
# Iteration 2503 / 3000
# remove
# Iteration 2504 / 3000
# remove
# Iteration 2505 / 3000
# change_type
# Iteration 2506 / 3000
# add
# Iteration 2507 / 3000
# add
# Iteration 2508 / 3000
# change_type
# Iteration 2509 / 3000
# add
# Iteration 2510 / 3000
# add
# Iteration 2511 / 3000
# remove
# Iteration 2512 / 3000
# remove
# Iteration 2513 / 3000
# change_type
# Iteration 2514 / 3000
# change_type
# Iteration 2515 / 3000
# change_type
# Iteration 2516 / 3000
# add
# Iteration 2517 / 3000
# change_type
# Iteration 2518 / 3000
# add
# Iteration 2519 / 3000
# add
# Iteration 2520 / 3000
# remove
# Iteration 2521 / 3000
# add
# Iteration 2522 / 3000
# remove
# Iteration 2523 / 3000
# add
# Iteration 2524 / 3000
# remove
# Iteration 2525 / 3000
# change_type
# Iteration 2526 / 3000
# add
# Iteration 2527 / 3000
# change_type
# Iteration 2528 / 3000
# change_type
# Iteration 2529 / 3000
# change_type
# Iteration 2530 / 3000
# add
# Iteration 2531 / 3000
# remove
# Iteration 2532 / 3000
# remove
# Iteration 2533 / 3000
# add
# Iteration 2534 / 3000
# add
# Iteration 2535 / 3000
# remove
# Iteration 2536 / 3000
# add
# Iteration 2537 / 3000
# change_type
# Iteration 2538 / 3000
# change_type
# Iteration 2539 / 3000
# add
# Iteration 2540 / 3000
# remove
# Iteration 2541 / 3000
# remove
# Iteration 2542 / 3000
# remove
# Iteration 2543 / 3000
# add
# Iteration 2544 / 3000
# change_type
# Iteration 2545 / 3000
# add
# Iteration 2546 / 3000
# remove
# Iteration 2547 / 3000
# remove
# Iteration 2548 / 3000
# change_type
# Iteration 2549 / 3000
# add
# Iteration 2550 / 3000
# change_type
# Iteration 2551 / 3000
# add
# Iteration 2552 / 3000
# remove
# Iteration 2553 / 3000
# remove
# Iteration 2554 / 3000
# add
# Iteration 2555 / 3000
# add
# Iteration 2556 / 3000
# add
# Iteration 2557 / 3000
# remove
# Iteration 2558 / 3000
# change_type
# Iteration 2559 / 3000
# change_type
# Iteration 2560 / 3000
# change_type
# Iteration 2561 / 3000
# change_type
# Iteration 2562 / 3000
# add
# Iteration 2563 / 3000
# remove
# Iteration 2564 / 3000
# change_type
# Iteration 2565 / 3000
# remove
# Iteration 2566 / 3000
# remove
# Iteration 2567 / 3000
# remove
# Iteration 2568 / 3000
# add
# Iteration 2569 / 3000
# add
# Iteration 2570 / 3000
# change_type
# Iteration 2571 / 3000
# change_type
# Iteration 2572 / 3000
# add
# Iteration 2573 / 3000
# change_type
# Iteration 2574 / 3000
# add
# Iteration 2575 / 3000
# change_type
# Iteration 2576 / 3000
# add
# Iteration 2577 / 3000
# change_type
# Iteration 2578 / 3000
# change_type
# Iteration 2579 / 3000
# change_type
# Iteration 2580 / 3000
# remove
# Iteration 2581 / 3000
# add
# Iteration 2582 / 3000
# add
# Iteration 2583 / 3000
# add
# Iteration 2584 / 3000
# remove
# Iteration 2585 / 3000
# add
# Iteration 2586 / 3000
# remove
# Iteration 2587 / 3000
# remove
# Iteration 2588 / 3000
# change_type
# Iteration 2589 / 3000
# add
# Iteration 2590 / 3000
# add
# Iteration 2591 / 3000
# change_type
# Iteration 2592 / 3000
# change_type
# Iteration 2593 / 3000
# remove
# Iteration 2594 / 3000
# remove
# Iteration 2595 / 3000
# remove
# Iteration 2596 / 3000
# add
# Iteration 2597 / 3000
# change_type
# Iteration 2598 / 3000
# remove
# Iteration 2599 / 3000
# change_type
# Iteration 2600 / 3000
# remove
# Iteration 2601 / 3000
# remove
# Iteration 2602 / 3000
# add
# Iteration 2603 / 3000
# add
# Iteration 2604 / 3000
# add
# Iteration 2605 / 3000
# add
# Iteration 2606 / 3000
# change_type
# Iteration 2607 / 3000
# change_type
# Iteration 2608 / 3000
# remove
# Iteration 2609 / 3000
# change_type
# Iteration 2610 / 3000
# remove
# Iteration 2611 / 3000
# remove
# Iteration 2612 / 3000
# add
# Iteration 2613 / 3000
# remove
# Iteration 2614 / 3000
# change_type
# Iteration 2615 / 3000
# add
# Iteration 2616 / 3000
# change_type
# Iteration 2617 / 3000
# change_type
# Iteration 2618 / 3000
# add
# Iteration 2619 / 3000
# change_type
# Iteration 2620 / 3000
# change_type
# Iteration 2621 / 3000
# remove
# Iteration 2622 / 3000
# remove
# Iteration 2623 / 3000
# add
# Iteration 2624 / 3000
# add
# Iteration 2625 / 3000
# add
# Iteration 2626 / 3000
# change_type
# Iteration 2627 / 3000
# remove
# Iteration 2628 / 3000
# remove
# Iteration 2629 / 3000
# add
# Iteration 2630 / 3000
# remove
# Iteration 2631 / 3000
# remove
# Iteration 2632 / 3000
# remove
# Iteration 2633 / 3000
# change_type
# Iteration 2634 / 3000
# add
# Iteration 2635 / 3000
# add
# Iteration 2636 / 3000
# remove
# Iteration 2637 / 3000
# remove
# Iteration 2638 / 3000
# change_type
# Iteration 2639 / 3000
# change_type
# Iteration 2640 / 3000
# change_type
# Iteration 2641 / 3000
# change_type
# Iteration 2642 / 3000
# change_type
# Iteration 2643 / 3000
# add
# Iteration 2644 / 3000
# change_type
# Iteration 2645 / 3000
# change_type
# Iteration 2646 / 3000
# remove
# Iteration 2647 / 3000
# change_type
# Iteration 2648 / 3000
# remove
# Iteration 2649 / 3000
# remove
# Iteration 2650 / 3000
# change_type
# Iteration 2651 / 3000
# add
# Iteration 2652 / 3000
# remove
# Iteration 2653 / 3000
# remove
# Iteration 2654 / 3000
# change_type
# Iteration 2655 / 3000
# add
# Iteration 2656 / 3000
# remove
# Iteration 2657 / 3000
# add
# Iteration 2658 / 3000
# change_type
# Iteration 2659 / 3000
# change_type
# Iteration 2660 / 3000
# remove
# Iteration 2661 / 3000
# add
# Iteration 2662 / 3000
# add
# Iteration 2663 / 3000
# remove
# Iteration 2664 / 3000
# add
# Iteration 2665 / 3000
# add
# Iteration 2666 / 3000
# remove
# Iteration 2667 / 3000
# remove
# Iteration 2668 / 3000
# remove
# Iteration 2669 / 3000
# change_type
# Iteration 2670 / 3000
# change_type
# Iteration 2671 / 3000
# add
# Iteration 2672 / 3000
# add
# Iteration 2673 / 3000
# change_type
# Iteration 2674 / 3000
# remove
# Iteration 2675 / 3000
# remove
# Iteration 2676 / 3000
# change_type
# Iteration 2677 / 3000
# add
# Iteration 2678 / 3000
# remove
# Iteration 2679 / 3000
# add
# Iteration 2680 / 3000
# remove
# Iteration 2681 / 3000
# remove
# Iteration 2682 / 3000
# add
# Iteration 2683 / 3000
# change_type
# Iteration 2684 / 3000
# remove
# Iteration 2685 / 3000
# add
# Iteration 2686 / 3000
# remove
# Iteration 2687 / 3000
# remove
# Iteration 2688 / 3000
# add
# Iteration 2689 / 3000
# change_type
# Iteration 2690 / 3000
# change_type
# Iteration 2691 / 3000
# add
# Iteration 2692 / 3000
# remove
# Iteration 2693 / 3000
# change_type
# Iteration 2694 / 3000
# remove
# Iteration 2695 / 3000
# add
# Iteration 2696 / 3000
# add
# Iteration 2697 / 3000
# change_type
# Iteration 2698 / 3000
# add
# Iteration 2699 / 3000
# change_type
# Iteration 2700 / 3000
# add
# Iteration 2701 / 3000
# change_type
# Iteration 2702 / 3000
# remove
# Iteration 2703 / 3000
# remove
# Iteration 2704 / 3000
# add
# Iteration 2705 / 3000
# change_type
# Iteration 2706 / 3000
# remove
# Iteration 2707 / 3000
# change_type
# Iteration 2708 / 3000
# remove
# Iteration 2709 / 3000
# change_type
# Iteration 2710 / 3000
# change_type
# Iteration 2711 / 3000
# change_type
# Iteration 2712 / 3000
# add
# Iteration 2713 / 3000
# remove
# Iteration 2714 / 3000
# change_type
# Iteration 2715 / 3000
# change_type
# Iteration 2716 / 3000
# add
# Iteration 2717 / 3000
# add
# Iteration 2718 / 3000
# add
# Iteration 2719 / 3000
# remove
# Iteration 2720 / 3000
# add
# Iteration 2721 / 3000
# add
# Iteration 2722 / 3000
# add
# Iteration 2723 / 3000
# add
# Iteration 2724 / 3000
# change_type
# Iteration 2725 / 3000
# change_type
# Iteration 2726 / 3000
# add
# Iteration 2727 / 3000
# add
# Iteration 2728 / 3000
# remove
# Iteration 2729 / 3000
# remove
# Iteration 2730 / 3000
# change_type
# Iteration 2731 / 3000
# add
# Iteration 2732 / 3000
# remove
# Iteration 2733 / 3000
# change_type
# Iteration 2734 / 3000
# add
# Iteration 2735 / 3000
# add
# Iteration 2736 / 3000
# change_type
# Iteration 2737 / 3000
# change_type
# Iteration 2738 / 3000
# add
# Iteration 2739 / 3000
# add
# Iteration 2740 / 3000
# add
# Iteration 2741 / 3000
# add
# Iteration 2742 / 3000
# change_type
# Iteration 2743 / 3000
# change_type
# Iteration 2744 / 3000
# remove
# Iteration 2745 / 3000
# change_type
# Iteration 2746 / 3000
# add
# Iteration 2747 / 3000
# remove
# Iteration 2748 / 3000
# change_type
# Iteration 2749 / 3000
# remove
# Iteration 2750 / 3000
# change_type
# Iteration 2751 / 3000
# change_type
# Iteration 2752 / 3000
# remove
# Iteration 2753 / 3000
# change_type
# Iteration 2754 / 3000
# add
# Iteration 2755 / 3000
# change_type
# Iteration 2756 / 3000
# add
# Iteration 2757 / 3000
# remove
# Iteration 2758 / 3000
# add
# Iteration 2759 / 3000
# change_type
# Iteration 2760 / 3000
# change_type
# Iteration 2761 / 3000
# remove
# Iteration 2762 / 3000
# change_type
# Iteration 2763 / 3000
# change_type
# Iteration 2764 / 3000
# add
# Iteration 2765 / 3000
# change_type
# Iteration 2766 / 3000
# add
# Iteration 2767 / 3000
# change_type
# Iteration 2768 / 3000
# change_type
# Iteration 2769 / 3000
# add
# Iteration 2770 / 3000
# remove
# Iteration 2771 / 3000
# remove
# Iteration 2772 / 3000
# add
# Iteration 2773 / 3000
# change_type
# Iteration 2774 / 3000
# remove
# Iteration 2775 / 3000
# add
# Iteration 2776 / 3000
# change_type
# Iteration 2777 / 3000
# change_type
# Iteration 2778 / 3000
# add
# Iteration 2779 / 3000
# remove
# Iteration 2780 / 3000
# change_type
# Iteration 2781 / 3000
# remove
# Iteration 2782 / 3000
# remove
# Iteration 2783 / 3000
# remove
# Iteration 2784 / 3000
# change_type
# Iteration 2785 / 3000
# add
# Iteration 2786 / 3000
# change_type
# Iteration 2787 / 3000
# add
# Iteration 2788 / 3000
# change_type
# Iteration 2789 / 3000
# remove
# Iteration 2790 / 3000
# add
# Iteration 2791 / 3000
# add
# Iteration 2792 / 3000
# change_type
# Iteration 2793 / 3000
# remove
# Iteration 2794 / 3000
# remove
# Iteration 2795 / 3000
# add
# Iteration 2796 / 3000
# remove
# Iteration 2797 / 3000
# remove
# Iteration 2798 / 3000
# remove
# Iteration 2799 / 3000
# add
# Iteration 2800 / 3000
# change_type
# Iteration 2801 / 3000
# change_type
# Iteration 2802 / 3000
# remove
# Iteration 2803 / 3000
# change_type
# Iteration 2804 / 3000
# remove
# Iteration 2805 / 3000
# change_type
# Iteration 2806 / 3000
# add
# Iteration 2807 / 3000
# add
# Iteration 2808 / 3000
# add
# Iteration 2809 / 3000
# change_type
# Iteration 2810 / 3000
# add
# Iteration 2811 / 3000
# remove
# Iteration 2812 / 3000
# change_type
# Iteration 2813 / 3000
# remove
# Iteration 2814 / 3000
# add
# Iteration 2815 / 3000
# add
# Iteration 2816 / 3000
# change_type
# Iteration 2817 / 3000
# change_type
# Iteration 2818 / 3000
# remove
# Iteration 2819 / 3000
# change_type
# Iteration 2820 / 3000
# remove
# Iteration 2821 / 3000
# add
# Iteration 2822 / 3000
# remove
# Iteration 2823 / 3000
# remove
# Iteration 2824 / 3000
# add
# Iteration 2825 / 3000
# remove
# Iteration 2826 / 3000
# change_type
# Iteration 2827 / 3000
# change_type
# Iteration 2828 / 3000
# change_type
# Iteration 2829 / 3000
# add
# Iteration 2830 / 3000
# change_type
# Iteration 2831 / 3000
# add
# Iteration 2832 / 3000
# add
# Iteration 2833 / 3000
# change_type
# Iteration 2834 / 3000
# change_type
# Iteration 2835 / 3000
# change_type
# Iteration 2836 / 3000
# change_type
# Iteration 2837 / 3000
# add
# Iteration 2838 / 3000
# add
# Iteration 2839 / 3000
# add
# Iteration 2840 / 3000
# add
# Iteration 2841 / 3000
# change_type
# Iteration 2842 / 3000
# change_type
# Iteration 2843 / 3000
# change_type
# Iteration 2844 / 3000
# add
# Iteration 2845 / 3000
# remove
# Iteration 2846 / 3000
# add
# Iteration 2847 / 3000
# remove
# Iteration 2848 / 3000
# change_type
# Iteration 2849 / 3000
# remove
# Iteration 2850 / 3000
# remove
# Iteration 2851 / 3000
# add
# Iteration 2852 / 3000
# remove
# Iteration 2853 / 3000
# add
# Iteration 2854 / 3000
# add
# Iteration 2855 / 3000
# change_type
# Iteration 2856 / 3000
# add
# Iteration 2857 / 3000
# remove
# Iteration 2858 / 3000
# add
# Iteration 2859 / 3000
# change_type
# Iteration 2860 / 3000
# change_type
# Iteration 2861 / 3000
# change_type
# Iteration 2862 / 3000
# remove
# Iteration 2863 / 3000
# remove
# Iteration 2864 / 3000
# change_type
# Iteration 2865 / 3000
# change_type
# Iteration 2866 / 3000
# remove
# Iteration 2867 / 3000
# remove
# Iteration 2868 / 3000
# change_type
# Iteration 2869 / 3000
# remove
# Iteration 2870 / 3000
# remove
# Iteration 2871 / 3000
# change_type
# Iteration 2872 / 3000
# remove
# Iteration 2873 / 3000
# change_type
# Iteration 2874 / 3000
# add
# Iteration 2875 / 3000
# remove
# Iteration 2876 / 3000
# remove
# Iteration 2877 / 3000
# change_type
# Iteration 2878 / 3000
# remove
# Iteration 2879 / 3000
# add
# Iteration 2880 / 3000
# add
# Iteration 2881 / 3000
# change_type
# Iteration 2882 / 3000
# change_type
# Iteration 2883 / 3000
# add
# Iteration 2884 / 3000
# remove
# Iteration 2885 / 3000
# add
# Iteration 2886 / 3000
# change_type
# Iteration 2887 / 3000
# add
# Iteration 2888 / 3000
# add
# Iteration 2889 / 3000
# change_type
# Iteration 2890 / 3000
# change_type
# Iteration 2891 / 3000
# change_type
# Iteration 2892 / 3000
# change_type
# Iteration 2893 / 3000
# remove
# Iteration 2894 / 3000
# remove
# Iteration 2895 / 3000
# add
# Iteration 2896 / 3000
# add
# Iteration 2897 / 3000
# change_type
# Iteration 2898 / 3000
# remove
# Iteration 2899 / 3000
# change_type
# Iteration 2900 / 3000
# remove
# Iteration 2901 / 3000
# add
# Iteration 2902 / 3000
# remove
# Iteration 2903 / 3000
# remove
# Iteration 2904 / 3000
# remove
# Iteration 2905 / 3000
# add
# Iteration 2906 / 3000
# add
# Iteration 2907 / 3000
# remove
# Iteration 2908 / 3000
# remove
# Iteration 2909 / 3000
# add
# Iteration 2910 / 3000
# change_type
# Iteration 2911 / 3000
# add
# Iteration 2912 / 3000
# add
# Iteration 2913 / 3000
# remove
# Iteration 2914 / 3000
# change_type
# Iteration 2915 / 3000
# remove
# Iteration 2916 / 3000
# change_type
# Iteration 2917 / 3000
# add
# Iteration 2918 / 3000
# change_type
# Iteration 2919 / 3000
# add
# Iteration 2920 / 3000
# remove
# Iteration 2921 / 3000
# remove
# Iteration 2922 / 3000
# remove
# Iteration 2923 / 3000
# add
# Iteration 2924 / 3000
# remove
# Iteration 2925 / 3000
# change_type
# Iteration 2926 / 3000
# change_type
# Iteration 2927 / 3000
# change_type
# Iteration 2928 / 3000
# change_type
# Iteration 2929 / 3000
# add
# Iteration 2930 / 3000
# change_type
# Iteration 2931 / 3000
# remove
# Iteration 2932 / 3000
# change_type
# Iteration 2933 / 3000
# add
# Iteration 2934 / 3000
# remove
# Iteration 2935 / 3000
# add
# Iteration 2936 / 3000
# add
# Iteration 2937 / 3000
# change_type
# Iteration 2938 / 3000
# add
# Iteration 2939 / 3000
# change_type
# Iteration 2940 / 3000
# add
# Iteration 2941 / 3000
# add
# Iteration 2942 / 3000
# remove
# Iteration 2943 / 3000
# change_type
# Iteration 2944 / 3000
# remove
# Iteration 2945 / 3000
# remove
# Iteration 2946 / 3000
# add
# Iteration 2947 / 3000
# change_type
# Iteration 2948 / 3000
# remove
# Iteration 2949 / 3000
# remove
# Iteration 2950 / 3000
# change_type
# Iteration 2951 / 3000
# remove
# Iteration 2952 / 3000
# remove
# Iteration 2953 / 3000
# change_type
# Iteration 2954 / 3000
# add
# Iteration 2955 / 3000
# add
# Iteration 2956 / 3000
# add
# Iteration 2957 / 3000
# add
# Iteration 2958 / 3000
# remove
# Iteration 2959 / 3000
# change_type
# Iteration 2960 / 3000
# change_type
# Iteration 2961 / 3000
# change_type
# Iteration 2962 / 3000
# remove
# Iteration 2963 / 3000
# add
# Iteration 2964 / 3000
# add
# Iteration 2965 / 3000
# add
# Iteration 2966 / 3000
# change_type
# Iteration 2967 / 3000
# change_type
# Iteration 2968 / 3000
# remove
# Iteration 2969 / 3000
# remove
# Iteration 2970 / 3000
# add
# Iteration 2971 / 3000
# add
# Iteration 2972 / 3000
# add
# Iteration 2973 / 3000
# add
# Iteration 2974 / 3000
# add
# Iteration 2975 / 3000
# change_type
# Iteration 2976 / 3000
# change_type
# Iteration 2977 / 3000
# change_type
# Iteration 2978 / 3000
# remove
# Iteration 2979 / 3000
# change_type
# Iteration 2980 / 3000
# remove
# Iteration 2981 / 3000
# remove
# Iteration 2982 / 3000
# change_type
# Iteration 2983 / 3000
# add
# Iteration 2984 / 3000
# change_type
# Iteration 2985 / 3000
# remove
# Iteration 2986 / 3000
# add
# Iteration 2987 / 3000
# remove
# Iteration 2988 / 3000
# change_type
# Iteration 2989 / 3000
# change_type
# Iteration 2990 / 3000
# remove
# Iteration 2991 / 3000
# change_type
# Iteration 2992 / 3000
# remove
# Iteration 2993 / 3000
# remove
# Iteration 2994 / 3000
# change_type
# Iteration 2995 / 3000
# remove
# Iteration 2996 / 3000
# remove
# Iteration 2997 / 3000
# change_type
# Iteration 2998 / 3000
# change_type
# Iteration 2999 / 3000
# remove
# Iteration 3000 / 3000
# add

# %%
with open("exp_sa_1.pkl", "rb") as f:
    exp_result1 = pickle.load(f)
exp_result1["runtime"]
# Out:
# 5126.974046945572

# %%
plot_models_fitness(exp_result1["fitness_history"], params["evaluation_weights"])
plot_total_fitness(exp_result1["fitness_history"])
visualize_solution(exp_result1["solution"], G)
# Out:
# C:\Users\tetia\AppData\Local\Temp\ipykernel_27360\777376565.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))

# %% [markdown]
# ## Experiment 2

# %% [markdown]
# - base parameters
# - bad_attempts_limit = 40\
# (maximum number of attempts to find a better neighbor for a worse solution before returning to the best solution)

# %%
run_sa("configs/params.yaml", "exp_sa_2.pkl", exp_config_file = "configs/experiments/exp_sa_2.yaml")

# %%
with open("exp_sa_2.pkl", "rb") as f:
    exp_result2 = pickle.load(f)
exp_result2["runtime"]
# Out:
# 2320.4079897403717

# %%
plot_models_fitness(exp_result2["fitness_history"], params["evaluation_weights"])
plot_total_fitness(exp_result2["fitness_history"])
visualize_solution(exp_result2["solution"], G)
# Out:
# C:\Users\tetia\AppData\Local\Temp\ipykernel_9184\2990666065.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))

# %% [markdown]
# ## Experiment 3

# %% [markdown]
# - cooling rate = 0.999

# %%
run_sa("configs/params.yaml", "exp_sa_3.pkl", exp_config_file = "configs/experiments/exp_sa_3.yaml")
# Out:
# Iteration 1 / 1500
# change_type
# Iteration 2 / 1500
# remove
# Iteration 3 / 1500
# add
# Iteration 4 / 1500
# change_type
# Iteration 5 / 1500
# change_type
# Iteration 6 / 1500
# remove
# Iteration 7 / 1500
# change_type
# Iteration 8 / 1500
# add
# Iteration 9 / 1500
# change_type
# Iteration 10 / 1500
# add
# Iteration 11 / 1500
# add
# Iteration 12 / 1500
# remove
# Iteration 13 / 1500
# remove
# Iteration 14 / 1500
# add
# Iteration 15 / 1500
# add
# Iteration 16 / 1500
# change_type
# Iteration 17 / 1500
# change_type
# Iteration 18 / 1500
# remove
# Iteration 19 / 1500
# add
# Iteration 20 / 1500
# remove
# Iteration 21 / 1500
# add
# Iteration 22 / 1500
# add
# Iteration 23 / 1500
# remove
# Iteration 24 / 1500
# change_type
# Iteration 25 / 1500
# remove
# Iteration 26 / 1500
# change_type
# Iteration 27 / 1500
# add
# Iteration 28 / 1500
# add
# Iteration 29 / 1500
# change_type
# Iteration 30 / 1500
# add
# Iteration 31 / 1500
# add
# Iteration 32 / 1500
# change_type
# Iteration 33 / 1500
# change_type
# Iteration 34 / 1500
# change_type
# Iteration 35 / 1500
# add
# Iteration 36 / 1500
# add
# Iteration 37 / 1500
# remove
# Iteration 38 / 1500
# remove
# Iteration 39 / 1500
# change_type
# Iteration 40 / 1500
# change_type
# Iteration 41 / 1500
# remove
# Iteration 42 / 1500
# change_type
# Iteration 43 / 1500
# add
# Iteration 44 / 1500
# change_type
# Iteration 45 / 1500
# add
# Iteration 46 / 1500
# change_type
# Iteration 47 / 1500
# change_type
# Iteration 48 / 1500
# add
# Iteration 49 / 1500
# change_type
# Iteration 50 / 1500
# add
# Iteration 51 / 1500
# change_type
# Iteration 52 / 1500
# change_type
# Iteration 53 / 1500
# change_type
# Iteration 54 / 1500
# remove
# Iteration 55 / 1500
# add
# Iteration 56 / 1500
# change_type
# Iteration 57 / 1500
# change_type
# Iteration 58 / 1500
# change_type
# Iteration 59 / 1500
# remove
# Iteration 60 / 1500
# change_type
# Iteration 61 / 1500
# remove
# Iteration 62 / 1500
# change_type
# Iteration 63 / 1500
# change_type
# Iteration 64 / 1500
# add
# Iteration 65 / 1500
# remove
# Iteration 66 / 1500
# add
# Iteration 67 / 1500
# change_type
# Iteration 68 / 1500
# add
# Iteration 69 / 1500
# remove
# Iteration 70 / 1500
# remove
# Iteration 71 / 1500
# add
# Iteration 72 / 1500
# change_type
# Iteration 73 / 1500
# remove
# Iteration 74 / 1500
# remove
# Iteration 75 / 1500
# remove
# Iteration 76 / 1500
# remove
# Iteration 77 / 1500
# change_type
# Iteration 78 / 1500
# remove
# Iteration 79 / 1500
# add
# Iteration 80 / 1500
# add
# Iteration 81 / 1500
# remove
# Iteration 82 / 1500
# add
# Iteration 83 / 1500
# remove
# Iteration 84 / 1500
# remove
# Iteration 85 / 1500
# change_type
# Iteration 86 / 1500
# remove
# Iteration 87 / 1500
# add
# Iteration 88 / 1500
# change_type
# Iteration 89 / 1500
# add
# Iteration 90 / 1500
# change_type
# Iteration 91 / 1500
# remove
# Iteration 92 / 1500
# remove
# Iteration 93 / 1500
# remove
# Iteration 94 / 1500
# change_type
# Iteration 95 / 1500
# remove
# Iteration 96 / 1500
# add
# Iteration 97 / 1500
# add
# Iteration 98 / 1500
# remove
# Iteration 99 / 1500
# remove
# Iteration 100 / 1500
# remove
# Iteration 101 / 1500
# add
# Iteration 102 / 1500
# add
# Iteration 103 / 1500
# remove
# Iteration 104 / 1500
# remove
# Iteration 105 / 1500
# remove
# Iteration 106 / 1500
# change_type
# Iteration 107 / 1500
# add
# Iteration 108 / 1500
# change_type
# Iteration 109 / 1500
# change_type
# Iteration 110 / 1500
# remove
# Iteration 111 / 1500
# remove
# Iteration 112 / 1500
# change_type
# Iteration 113 / 1500
# remove
# Iteration 114 / 1500
# change_type
# Iteration 115 / 1500
# change_type
# Iteration 116 / 1500
# remove
# Iteration 117 / 1500
# change_type
# Iteration 118 / 1500
# remove
# Iteration 119 / 1500
# add
# Iteration 120 / 1500
# add
# Iteration 121 / 1500
# change_type
# Iteration 122 / 1500
# change_type
# Iteration 123 / 1500
# remove
# Iteration 124 / 1500
# change_type
# Iteration 125 / 1500
# remove
# Iteration 126 / 1500
# remove
# Iteration 127 / 1500
# add
# Iteration 128 / 1500
# remove
# Iteration 129 / 1500
# remove
# Iteration 130 / 1500
# add
# Iteration 131 / 1500
# add
# Iteration 132 / 1500
# remove
# Iteration 133 / 1500
# change_type
# Iteration 134 / 1500
# add
# Iteration 135 / 1500
# add
# Iteration 136 / 1500
# remove
# Iteration 137 / 1500
# change_type
# Iteration 138 / 1500
# change_type
# Iteration 139 / 1500
# change_type
# Iteration 140 / 1500
# change_type
# Iteration 141 / 1500
# remove
# Iteration 142 / 1500
# remove
# Iteration 143 / 1500
# change_type
# Iteration 144 / 1500
# change_type
# Iteration 145 / 1500
# add
# Iteration 146 / 1500
# change_type
# Iteration 147 / 1500
# change_type
# Iteration 148 / 1500
# remove
# Iteration 149 / 1500
# remove
# Iteration 150 / 1500
# change_type
# Iteration 151 / 1500
# change_type
# Iteration 152 / 1500
# remove
# Iteration 153 / 1500
# change_type
# Iteration 154 / 1500
# change_type
# Iteration 155 / 1500
# change_type
# Iteration 156 / 1500
# change_type
# Iteration 157 / 1500
# add
# Iteration 158 / 1500
# remove
# Iteration 159 / 1500
# change_type
# Iteration 160 / 1500
# change_type
# Iteration 161 / 1500
# add
# Iteration 162 / 1500
# add
# Iteration 163 / 1500
# change_type
# Iteration 164 / 1500
# remove
# Iteration 165 / 1500
# add
# Iteration 166 / 1500
# remove
# Iteration 167 / 1500
# remove
# Iteration 168 / 1500
# remove
# Iteration 169 / 1500
# remove
# Iteration 170 / 1500
# add
# Iteration 171 / 1500
# add
# Iteration 172 / 1500
# remove
# Iteration 173 / 1500
# remove
# Iteration 174 / 1500
# add
# Iteration 175 / 1500
# remove
# Iteration 176 / 1500
# change_type
# Iteration 177 / 1500
# remove
# Iteration 178 / 1500
# add
# Iteration 179 / 1500
# add
# Iteration 180 / 1500
# add
# Iteration 181 / 1500
# change_type
# Iteration 182 / 1500
# remove
# Iteration 183 / 1500
# add
# Iteration 184 / 1500
# add
# Iteration 185 / 1500
# change_type
# Iteration 186 / 1500
# add
# Iteration 187 / 1500
# remove
# Iteration 188 / 1500
# remove
# Iteration 189 / 1500
# add
# Iteration 190 / 1500
# remove
# Iteration 191 / 1500
# change_type
# Iteration 192 / 1500
# change_type
# Iteration 193 / 1500
# add
# Iteration 194 / 1500
# change_type
# Iteration 195 / 1500
# remove
# Iteration 196 / 1500
# change_type
# Iteration 197 / 1500
# add
# Iteration 198 / 1500
# change_type
# Iteration 199 / 1500
# add
# Iteration 200 / 1500
# add
# Iteration 201 / 1500
# remove
# Iteration 202 / 1500
# remove
# Iteration 203 / 1500
# remove
# Iteration 204 / 1500
# remove
# Iteration 205 / 1500
# change_type
# Iteration 206 / 1500
# add
# Iteration 207 / 1500
# add
# Iteration 208 / 1500
# remove
# Iteration 209 / 1500
# change_type
# Iteration 210 / 1500
# remove
# Iteration 211 / 1500
# add
# Iteration 212 / 1500
# add
# Iteration 213 / 1500
# change_type
# Iteration 214 / 1500
# remove
# Iteration 215 / 1500
# change_type
# Iteration 216 / 1500
# change_type
# Iteration 217 / 1500
# add
# Iteration 218 / 1500
# add
# Iteration 219 / 1500
# change_type
# Iteration 220 / 1500
# add
# Iteration 221 / 1500
# add
# Iteration 222 / 1500
# change_type
# Iteration 223 / 1500
# add
# Iteration 224 / 1500
# remove
# Iteration 225 / 1500
# change_type
# Iteration 226 / 1500
# remove
# Iteration 227 / 1500
# change_type
# Iteration 228 / 1500
# change_type
# Iteration 229 / 1500
# add
# Iteration 230 / 1500
# add
# Iteration 231 / 1500
# change_type
# Iteration 232 / 1500
# add
# Iteration 233 / 1500
# change_type
# Iteration 234 / 1500
# add
# Iteration 235 / 1500
# change_type
# Iteration 236 / 1500
# add
# Iteration 237 / 1500
# add
# Iteration 238 / 1500
# change_type
# Iteration 239 / 1500
# remove
# Iteration 240 / 1500
# add
# Iteration 241 / 1500
# add
# Iteration 242 / 1500
# remove
# Iteration 243 / 1500
# add
# Iteration 244 / 1500
# add
# Iteration 245 / 1500
# change_type
# Iteration 246 / 1500
# add
# Iteration 247 / 1500
# change_type
# Iteration 248 / 1500
# add
# Iteration 249 / 1500
# remove
# Iteration 250 / 1500
# remove
# Iteration 251 / 1500
# change_type
# Iteration 252 / 1500
# remove
# Iteration 253 / 1500
# remove
# Iteration 254 / 1500
# remove
# Iteration 255 / 1500
# add
# Iteration 256 / 1500
# remove
# Iteration 257 / 1500
# remove
# Iteration 258 / 1500
# change_type
# Iteration 259 / 1500
# add
# Iteration 260 / 1500
# change_type
# Iteration 261 / 1500
# change_type
# Iteration 262 / 1500
# add
# Iteration 263 / 1500
# add
# Iteration 264 / 1500
# remove
# Iteration 265 / 1500
# remove
# Iteration 266 / 1500
# change_type
# Iteration 267 / 1500
# remove
# Iteration 268 / 1500
# add
# Iteration 269 / 1500
# remove
# Iteration 270 / 1500
# change_type
# Iteration 271 / 1500
# remove
# Iteration 272 / 1500
# change_type
# Iteration 273 / 1500
# add
# Iteration 274 / 1500
# change_type
# Iteration 275 / 1500
# add
# Iteration 276 / 1500
# remove
# Iteration 277 / 1500
# add
# Iteration 278 / 1500
# remove
# Iteration 279 / 1500
# add
# Iteration 280 / 1500
# change_type
# Iteration 281 / 1500
# remove
# Iteration 282 / 1500
# remove
# Iteration 283 / 1500
# add
# Iteration 284 / 1500
# remove
# Iteration 285 / 1500
# change_type
# Iteration 286 / 1500
# change_type
# Iteration 287 / 1500
# add
# Iteration 288 / 1500
# add
# Iteration 289 / 1500
# change_type
# Iteration 290 / 1500
# change_type
# Iteration 291 / 1500
# change_type
# Iteration 292 / 1500
# add
# Iteration 293 / 1500
# add
# Iteration 294 / 1500
# change_type
# Iteration 295 / 1500
# change_type
# Iteration 296 / 1500
# remove
# Iteration 297 / 1500
# add
# Iteration 298 / 1500
# remove
# Iteration 299 / 1500
# remove
# Iteration 300 / 1500
# remove
# Iteration 301 / 1500
# change_type
# Iteration 302 / 1500
# change_type
# Iteration 303 / 1500
# remove
# Iteration 304 / 1500
# change_type
# Iteration 305 / 1500
# add
# Iteration 306 / 1500
# add
# Iteration 307 / 1500
# remove
# Iteration 308 / 1500
# remove
# Iteration 309 / 1500
# change_type
# Iteration 310 / 1500
# change_type
# Iteration 311 / 1500
# change_type
# Iteration 312 / 1500
# add
# Iteration 313 / 1500
# add
# Iteration 314 / 1500
# add
# Iteration 315 / 1500
# add
# Iteration 316 / 1500
# add
# Iteration 317 / 1500
# change_type
# Iteration 318 / 1500
# change_type
# Iteration 319 / 1500
# change_type
# Iteration 320 / 1500
# change_type
# Iteration 321 / 1500
# remove
# Iteration 322 / 1500
# remove
# Iteration 323 / 1500
# add
# Iteration 324 / 1500
# remove
# Iteration 325 / 1500
# add
# Iteration 326 / 1500
# change_type
# Iteration 327 / 1500
# add
# Iteration 328 / 1500
# change_type
# Iteration 329 / 1500
# change_type
# Iteration 330 / 1500
# remove
# Iteration 331 / 1500
# add
# Iteration 332 / 1500
# remove
# Iteration 333 / 1500
# change_type
# Iteration 334 / 1500
# add
# Iteration 335 / 1500
# add
# Iteration 336 / 1500
# add
# Iteration 337 / 1500
# add
# Iteration 338 / 1500
# remove
# Iteration 339 / 1500
# remove
# Iteration 340 / 1500
# add
# Iteration 341 / 1500
# change_type
# Iteration 342 / 1500
# change_type
# Iteration 343 / 1500
# change_type
# Iteration 344 / 1500
# remove
# Iteration 345 / 1500
# remove
# Iteration 346 / 1500
# change_type
# Iteration 347 / 1500
# change_type
# Iteration 348 / 1500
# change_type
# Iteration 349 / 1500
# change_type
# Iteration 350 / 1500
# remove
# Iteration 351 / 1500
# add
# Iteration 352 / 1500
# change_type
# Iteration 353 / 1500
# change_type
# Iteration 354 / 1500
# remove
# Iteration 355 / 1500
# remove
# Iteration 356 / 1500
# add
# Iteration 357 / 1500
# change_type
# Iteration 358 / 1500
# change_type
# Iteration 359 / 1500
# remove
# Iteration 360 / 1500
# remove
# Iteration 361 / 1500
# remove
# Iteration 362 / 1500
# add
# Iteration 363 / 1500
# remove
# Iteration 364 / 1500
# change_type
# Iteration 365 / 1500
# add
# Iteration 366 / 1500
# change_type
# Iteration 367 / 1500
# remove
# Iteration 368 / 1500
# change_type
# Iteration 369 / 1500
# add
# Iteration 370 / 1500
# remove
# Iteration 371 / 1500
# change_type
# Iteration 372 / 1500
# change_type
# Iteration 373 / 1500
# add
# Iteration 374 / 1500
# remove
# Iteration 375 / 1500
# add
# Iteration 376 / 1500
# change_type
# Iteration 377 / 1500
# add
# Iteration 378 / 1500
# add
# Iteration 379 / 1500
# add
# Iteration 380 / 1500
# remove
# Iteration 381 / 1500
# add
# Iteration 382 / 1500
# remove
# Iteration 383 / 1500
# change_type
# Iteration 384 / 1500
# remove
# Iteration 385 / 1500
# add
# Iteration 386 / 1500
# remove
# Iteration 387 / 1500
# add
# Iteration 388 / 1500
# change_type
# Iteration 389 / 1500
# change_type
# Iteration 390 / 1500
# remove
# Iteration 391 / 1500
# remove
# Iteration 392 / 1500
# remove
# Iteration 393 / 1500
# remove
# Iteration 394 / 1500
# add
# Iteration 395 / 1500
# add
# Iteration 396 / 1500
# add
# Iteration 397 / 1500
# change_type
# Iteration 398 / 1500
# add
# Iteration 399 / 1500
# add
# Iteration 400 / 1500
# add
# Iteration 401 / 1500
# change_type
# Iteration 402 / 1500
# add
# Iteration 403 / 1500
# add
# Iteration 404 / 1500
# change_type
# Iteration 405 / 1500
# remove
# Iteration 406 / 1500
# remove
# Iteration 407 / 1500
# remove
# Iteration 408 / 1500
# change_type
# Iteration 409 / 1500
# add
# Iteration 410 / 1500
# change_type
# Iteration 411 / 1500
# remove
# Iteration 412 / 1500
# change_type
# Iteration 413 / 1500
# remove
# Iteration 414 / 1500
# change_type
# Iteration 415 / 1500
# change_type
# Iteration 416 / 1500
# change_type
# Iteration 417 / 1500
# remove
# Iteration 418 / 1500
# remove
# Iteration 419 / 1500
# remove
# Iteration 420 / 1500
# change_type
# Iteration 421 / 1500
# change_type
# Iteration 422 / 1500
# change_type
# Iteration 423 / 1500
# add
# Iteration 424 / 1500
# change_type
# Iteration 425 / 1500
# change_type
# Iteration 426 / 1500
# remove
# Iteration 427 / 1500
# change_type
# Iteration 428 / 1500
# remove
# Iteration 429 / 1500
# add
# Iteration 430 / 1500
# remove
# Iteration 431 / 1500
# add
# Iteration 432 / 1500
# add
# Iteration 433 / 1500
# change_type
# Iteration 434 / 1500
# remove
# Iteration 435 / 1500
# change_type
# Iteration 436 / 1500
# remove
# Iteration 437 / 1500
# change_type
# Iteration 438 / 1500
# change_type
# Iteration 439 / 1500
# change_type
# Iteration 440 / 1500
# change_type
# Iteration 441 / 1500
# change_type
# Iteration 442 / 1500
# remove
# Iteration 443 / 1500
# add
# Iteration 444 / 1500
# change_type
# Iteration 445 / 1500
# remove
# Iteration 446 / 1500
# remove
# Iteration 447 / 1500
# remove
# Iteration 448 / 1500
# add
# Iteration 449 / 1500
# change_type
# Iteration 450 / 1500
# remove
# Iteration 451 / 1500
# add
# Iteration 452 / 1500
# add
# Iteration 453 / 1500
# add
# Iteration 454 / 1500
# change_type
# Iteration 455 / 1500
# change_type
# Iteration 456 / 1500
# add
# Iteration 457 / 1500
# remove
# Iteration 458 / 1500
# change_type
# Iteration 459 / 1500
# remove
# Iteration 460 / 1500
# change_type
# Iteration 461 / 1500
# remove
# Iteration 462 / 1500
# remove
# Iteration 463 / 1500
# change_type
# Iteration 464 / 1500
# remove
# Iteration 465 / 1500
# remove
# Iteration 466 / 1500
# add
# Iteration 467 / 1500
# add
# Iteration 468 / 1500
# change_type
# Iteration 469 / 1500
# remove
# Iteration 470 / 1500
# change_type
# Iteration 471 / 1500
# remove
# Iteration 472 / 1500
# remove
# Iteration 473 / 1500
# remove
# Iteration 474 / 1500
# remove
# Iteration 475 / 1500
# remove
# Iteration 476 / 1500
# remove
# Iteration 477 / 1500
# change_type
# Iteration 478 / 1500
# remove
# Iteration 479 / 1500
# remove
# Iteration 480 / 1500
# remove
# Iteration 481 / 1500
# remove
# Iteration 482 / 1500
# remove
# Iteration 483 / 1500
# add
# Iteration 484 / 1500
# remove
# Iteration 485 / 1500
# remove
# Iteration 486 / 1500
# add
# Iteration 487 / 1500
# change_type
# Iteration 488 / 1500
# remove
# Iteration 489 / 1500
# add
# Iteration 490 / 1500
# change_type
# Iteration 491 / 1500
# add
# Iteration 492 / 1500
# remove
# Iteration 493 / 1500
# add
# Iteration 494 / 1500
# add
# Iteration 495 / 1500
# add
# Iteration 496 / 1500
# change_type
# Iteration 497 / 1500
# add
# Iteration 498 / 1500
# change_type
# Iteration 499 / 1500
# remove
# Iteration 500 / 1500
# change_type
# Iteration 501 / 1500
# add
# Iteration 502 / 1500
# change_type
# Iteration 503 / 1500
# change_type
# Iteration 504 / 1500
# change_type
# Iteration 505 / 1500
# add
# Iteration 506 / 1500
# add
# Iteration 507 / 1500
# change_type
# Iteration 508 / 1500
# add
# Iteration 509 / 1500
# add
# Iteration 510 / 1500
# add
# Iteration 511 / 1500
# change_type
# Iteration 512 / 1500
# remove
# Iteration 513 / 1500
# add
# Iteration 514 / 1500
# add
# Iteration 515 / 1500
# add
# Iteration 516 / 1500
# add
# Iteration 517 / 1500
# remove
# Iteration 518 / 1500
# add
# Iteration 519 / 1500
# add
# Iteration 520 / 1500
# remove
# Iteration 521 / 1500
# remove
# Iteration 522 / 1500
# add
# Iteration 523 / 1500
# change_type
# Iteration 524 / 1500
# change_type
# Iteration 525 / 1500
# change_type
# Iteration 526 / 1500
# remove
# Iteration 527 / 1500
# add
# Iteration 528 / 1500
# add
# Iteration 529 / 1500
# remove
# Iteration 530 / 1500
# add
# Iteration 531 / 1500
# add
# Iteration 532 / 1500
# remove
# Iteration 533 / 1500
# change_type
# Iteration 534 / 1500
# change_type
# Iteration 535 / 1500
# change_type
# Iteration 536 / 1500
# add
# Iteration 537 / 1500
# add
# Iteration 538 / 1500
# change_type
# Iteration 539 / 1500
# change_type
# Iteration 540 / 1500
# change_type
# Iteration 541 / 1500
# add
# Iteration 542 / 1500
# add
# Iteration 543 / 1500
# change_type
# Iteration 544 / 1500
# add
# Iteration 545 / 1500
# remove
# Iteration 546 / 1500
# add
# Iteration 547 / 1500
# remove
# Iteration 548 / 1500
# remove
# Iteration 549 / 1500
# add
# Iteration 550 / 1500
# add
# Iteration 551 / 1500
# add
# Iteration 552 / 1500
# add
# Iteration 553 / 1500
# remove
# Iteration 554 / 1500
# add
# Iteration 555 / 1500
# add
# Iteration 556 / 1500
# add
# Iteration 557 / 1500
# change_type
# Iteration 558 / 1500
# add
# Iteration 559 / 1500
# add
# Iteration 560 / 1500
# remove
# Iteration 561 / 1500
# add
# Iteration 562 / 1500
# add
# Iteration 563 / 1500
# remove
# Iteration 564 / 1500
# remove
# Iteration 565 / 1500
# add
# Iteration 566 / 1500
# change_type
# Iteration 567 / 1500
# add
# Iteration 568 / 1500
# change_type
# Iteration 569 / 1500
# remove
# Iteration 570 / 1500
# remove
# Iteration 571 / 1500
# change_type
# Iteration 572 / 1500
# remove
# Iteration 573 / 1500
# change_type
# Iteration 574 / 1500
# change_type
# Iteration 575 / 1500
# remove
# Iteration 576 / 1500
# change_type
# Iteration 577 / 1500
# change_type
# Iteration 578 / 1500
# add
# Iteration 579 / 1500
# change_type
# Iteration 580 / 1500
# add
# Iteration 581 / 1500
# change_type
# Iteration 582 / 1500
# add
# Iteration 583 / 1500
# remove
# Iteration 584 / 1500
# remove
# Iteration 585 / 1500
# remove
# Iteration 586 / 1500
# remove
# Iteration 587 / 1500
# remove
# Iteration 588 / 1500
# remove
# Iteration 589 / 1500
# add
# Iteration 590 / 1500
# change_type
# Iteration 591 / 1500
# remove
# Iteration 592 / 1500
# remove
# Iteration 593 / 1500
# remove
# Iteration 594 / 1500
# add
# Iteration 595 / 1500
# change_type
# Iteration 596 / 1500
# add
# Iteration 597 / 1500
# add
# Iteration 598 / 1500
# remove
# Iteration 599 / 1500
# add
# Iteration 600 / 1500
# remove
# Iteration 601 / 1500
# remove
# Iteration 602 / 1500
# change_type
# Iteration 603 / 1500
# change_type
# Iteration 604 / 1500
# change_type
# Iteration 605 / 1500
# change_type
# Iteration 606 / 1500
# change_type
# Iteration 607 / 1500
# remove
# Iteration 608 / 1500
# add
# Iteration 609 / 1500
# remove
# Iteration 610 / 1500
# add
# Iteration 611 / 1500
# remove
# Iteration 612 / 1500
# add
# Iteration 613 / 1500
# change_type
# Iteration 614 / 1500
# remove
# Iteration 615 / 1500
# change_type
# Iteration 616 / 1500
# change_type
# Iteration 617 / 1500
# change_type
# Iteration 618 / 1500
# add
# Iteration 619 / 1500
# change_type
# Iteration 620 / 1500
# change_type
# Iteration 621 / 1500
# add
# Iteration 622 / 1500
# change_type
# Iteration 623 / 1500
# change_type
# Iteration 624 / 1500
# add
# Iteration 625 / 1500
# add
# Iteration 626 / 1500
# add
# Iteration 627 / 1500
# add
# Iteration 628 / 1500
# add
# Iteration 629 / 1500
# remove
# Iteration 630 / 1500
# change_type
# Iteration 631 / 1500
# add
# Iteration 632 / 1500
# remove
# Iteration 633 / 1500
# remove
# Iteration 634 / 1500
# add
# Iteration 635 / 1500
# change_type
# Iteration 636 / 1500
# remove
# Iteration 637 / 1500
# add
# Iteration 638 / 1500
# add
# Iteration 639 / 1500
# add
# Iteration 640 / 1500
# add
# Iteration 641 / 1500
# add
# Iteration 642 / 1500
# change_type
# Iteration 643 / 1500
# change_type
# Iteration 644 / 1500
# remove
# Iteration 645 / 1500
# add
# Iteration 646 / 1500
# add
# Iteration 647 / 1500
# add
# Iteration 648 / 1500
# add
# Iteration 649 / 1500
# change_type
# Iteration 650 / 1500
# add
# Iteration 651 / 1500
# add
# Iteration 652 / 1500
# change_type
# Iteration 653 / 1500
# change_type
# Iteration 654 / 1500
# remove
# Iteration 655 / 1500
# change_type
# Iteration 656 / 1500
# remove
# Iteration 657 / 1500
# add
# Iteration 658 / 1500
# add
# Iteration 659 / 1500
# add
# Iteration 660 / 1500
# add
# Iteration 661 / 1500
# add
# Iteration 662 / 1500
# change_type
# Iteration 663 / 1500
# add
# Iteration 664 / 1500
# add
# Iteration 665 / 1500
# change_type
# Iteration 666 / 1500
# add
# Iteration 667 / 1500
# change_type
# Iteration 668 / 1500
# add
# Iteration 669 / 1500
# add
# Iteration 670 / 1500
# add
# Iteration 671 / 1500
# remove
# Iteration 672 / 1500
# change_type
# Iteration 673 / 1500
# change_type
# Iteration 674 / 1500
# change_type
# Iteration 675 / 1500
# remove
# Iteration 676 / 1500
# change_type
# Iteration 677 / 1500
# change_type
# Iteration 678 / 1500
# change_type
# Iteration 679 / 1500
# add
# Iteration 680 / 1500
# remove
# Iteration 681 / 1500
# add
# Iteration 682 / 1500
# add
# Iteration 683 / 1500
# change_type
# Iteration 684 / 1500
# remove
# Iteration 685 / 1500
# add
# Iteration 686 / 1500
# add
# Iteration 687 / 1500
# change_type
# Iteration 688 / 1500
# remove
# Iteration 689 / 1500
# change_type
# Iteration 690 / 1500
# remove
# Iteration 691 / 1500
# add
# Iteration 692 / 1500
# remove
# Iteration 693 / 1500
# add
# Iteration 694 / 1500
# remove
# Iteration 695 / 1500
# remove
# Iteration 696 / 1500
# change_type
# Iteration 697 / 1500
# remove
# Iteration 698 / 1500
# change_type
# Iteration 699 / 1500
# remove
# Iteration 700 / 1500
# remove
# Iteration 701 / 1500
# change_type
# Iteration 702 / 1500
# add
# Iteration 703 / 1500
# change_type
# Iteration 704 / 1500
# remove
# Iteration 705 / 1500
# remove
# Iteration 706 / 1500
# remove
# Iteration 707 / 1500
# add
# Iteration 708 / 1500
# remove
# Iteration 709 / 1500
# remove
# Iteration 710 / 1500
# change_type
# Iteration 711 / 1500
# remove
# Iteration 712 / 1500
# change_type
# Iteration 713 / 1500
# change_type
# Iteration 714 / 1500
# change_type
# Iteration 715 / 1500
# change_type
# Iteration 716 / 1500
# add
# Iteration 717 / 1500
# add
# Iteration 718 / 1500
# remove
# Iteration 719 / 1500
# remove
# Iteration 720 / 1500
# add
# Iteration 721 / 1500
# remove
# Iteration 722 / 1500
# remove
# Iteration 723 / 1500
# change_type
# Iteration 724 / 1500
# add
# Iteration 725 / 1500
# change_type
# Iteration 726 / 1500
# change_type
# Iteration 727 / 1500
# change_type
# Iteration 728 / 1500
# add
# Iteration 729 / 1500
# add
# Iteration 730 / 1500
# remove
# Iteration 731 / 1500
# add
# Iteration 732 / 1500
# add
# Iteration 733 / 1500
# remove
# Iteration 734 / 1500
# remove
# Iteration 735 / 1500
# remove
# Iteration 736 / 1500
# add
# Iteration 737 / 1500
# remove
# Iteration 738 / 1500
# add
# Iteration 739 / 1500
# add
# Iteration 740 / 1500
# remove
# Iteration 741 / 1500
# add
# Iteration 742 / 1500
# add
# Iteration 743 / 1500
# change_type
# Iteration 744 / 1500
# add
# Iteration 745 / 1500
# add
# Iteration 746 / 1500
# add
# Iteration 747 / 1500
# remove
# Iteration 748 / 1500
# remove
# Iteration 749 / 1500
# add
# Iteration 750 / 1500
# remove
# Iteration 751 / 1500
# change_type
# Iteration 752 / 1500
# remove
# Iteration 753 / 1500
# change_type
# Iteration 754 / 1500
# remove
# Iteration 755 / 1500
# add
# Iteration 756 / 1500
# remove
# Iteration 757 / 1500
# change_type
# Iteration 758 / 1500
# change_type
# Iteration 759 / 1500
# add
# Iteration 760 / 1500
# remove
# Iteration 761 / 1500
# add
# Iteration 762 / 1500
# add
# Iteration 763 / 1500
# remove
# Iteration 764 / 1500
# add
# Iteration 765 / 1500
# change_type
# Iteration 766 / 1500
# add
# Iteration 767 / 1500
# add
# Iteration 768 / 1500
# remove
# Iteration 769 / 1500
# change_type
# Iteration 770 / 1500
# remove
# Iteration 771 / 1500
# add
# Iteration 772 / 1500
# add
# Iteration 773 / 1500
# remove
# Iteration 774 / 1500
# change_type
# Iteration 775 / 1500
# remove
# Iteration 776 / 1500
# change_type
# Iteration 777 / 1500
# remove
# Iteration 778 / 1500
# change_type
# Iteration 779 / 1500
# change_type
# Iteration 780 / 1500
# remove
# Iteration 781 / 1500
# add
# Iteration 782 / 1500
# remove
# Iteration 783 / 1500
# change_type
# Iteration 784 / 1500
# add
# Iteration 785 / 1500
# remove
# Iteration 786 / 1500
# remove
# Iteration 787 / 1500
# add
# Iteration 788 / 1500
# remove
# Iteration 789 / 1500
# add
# Iteration 790 / 1500
# remove
# Iteration 791 / 1500
# change_type
# Iteration 792 / 1500
# change_type
# Iteration 793 / 1500
# remove
# Iteration 794 / 1500
# add
# Iteration 795 / 1500
# remove
# Iteration 796 / 1500
# add
# Iteration 797 / 1500
# add
# Iteration 798 / 1500
# add
# Iteration 799 / 1500
# change_type
# Iteration 800 / 1500
# add
# Iteration 801 / 1500
# change_type
# Iteration 802 / 1500
# change_type
# Iteration 803 / 1500
# add
# Iteration 804 / 1500
# add
# Iteration 805 / 1500
# remove
# Iteration 806 / 1500
# remove
# Iteration 807 / 1500
# remove
# Iteration 808 / 1500
# add
# Iteration 809 / 1500
# add
# Iteration 810 / 1500
# add
# Iteration 811 / 1500
# remove
# Iteration 812 / 1500
# remove
# Iteration 813 / 1500
# remove
# Iteration 814 / 1500
# change_type
# Iteration 815 / 1500
# add
# Iteration 816 / 1500
# add
# Iteration 817 / 1500
# change_type
# Iteration 818 / 1500
# add
# Iteration 819 / 1500
# change_type
# Iteration 820 / 1500
# add
# Iteration 821 / 1500
# remove
# Iteration 822 / 1500
# change_type
# Iteration 823 / 1500
# remove
# Iteration 824 / 1500
# change_type
# Iteration 825 / 1500
# change_type
# Iteration 826 / 1500
# change_type
# Iteration 827 / 1500
# remove
# Iteration 828 / 1500
# add
# Iteration 829 / 1500
# add
# Iteration 830 / 1500
# change_type
# Iteration 831 / 1500
# remove
# Iteration 832 / 1500
# add
# Iteration 833 / 1500
# remove
# Iteration 834 / 1500
# change_type
# Iteration 835 / 1500
# remove
# Iteration 836 / 1500
# remove
# Iteration 837 / 1500
# remove
# Iteration 838 / 1500
# change_type
# Iteration 839 / 1500
# remove
# Iteration 840 / 1500
# add
# Iteration 841 / 1500
# add
# Iteration 842 / 1500
# remove
# Iteration 843 / 1500
# add
# Iteration 844 / 1500
# change_type
# Iteration 845 / 1500
# change_type
# Iteration 846 / 1500
# add
# Iteration 847 / 1500
# add
# Iteration 848 / 1500
# remove
# Iteration 849 / 1500
# change_type
# Iteration 850 / 1500
# add
# Iteration 851 / 1500
# change_type
# Iteration 852 / 1500
# add
# Iteration 853 / 1500
# add
# Iteration 854 / 1500
# add
# Iteration 855 / 1500
# add
# Iteration 856 / 1500
# remove
# Iteration 857 / 1500
# change_type
# Iteration 858 / 1500
# change_type
# Iteration 859 / 1500
# add
# Iteration 860 / 1500
# change_type
# Iteration 861 / 1500
# remove
# Iteration 862 / 1500
# change_type
# Iteration 863 / 1500
# add
# Iteration 864 / 1500
# remove
# Iteration 865 / 1500
# add
# Iteration 866 / 1500
# add
# Iteration 867 / 1500
# remove
# Iteration 868 / 1500
# change_type
# Iteration 869 / 1500
# change_type
# Iteration 870 / 1500
# change_type
# Iteration 871 / 1500
# change_type
# Iteration 872 / 1500
# remove
# Iteration 873 / 1500
# remove
# Iteration 874 / 1500
# change_type
# Iteration 875 / 1500
# add
# Iteration 876 / 1500
# add
# Iteration 877 / 1500
# remove
# Iteration 878 / 1500
# change_type
# Iteration 879 / 1500
# remove
# Iteration 880 / 1500
# change_type
# Iteration 881 / 1500
# remove
# Iteration 882 / 1500
# remove
# Iteration 883 / 1500
# change_type
# Iteration 884 / 1500
# remove
# Iteration 885 / 1500
# add
# Iteration 886 / 1500
# change_type
# Iteration 887 / 1500
# remove
# Iteration 888 / 1500
# remove
# Iteration 889 / 1500
# add
# Iteration 890 / 1500
# remove
# Iteration 891 / 1500
# remove
# Iteration 892 / 1500
# remove
# Iteration 893 / 1500
# change_type
# Iteration 894 / 1500
# add
# Iteration 895 / 1500
# remove
# Iteration 896 / 1500
# add
# Iteration 897 / 1500
# remove
# Iteration 898 / 1500
# change_type
# Iteration 899 / 1500
# remove
# Iteration 900 / 1500
# change_type
# Iteration 901 / 1500
# change_type
# Iteration 902 / 1500
# change_type
# Iteration 903 / 1500
# add
# Iteration 904 / 1500
# change_type
# Iteration 905 / 1500
# remove
# Iteration 906 / 1500
# add
# Iteration 907 / 1500
# remove
# Iteration 908 / 1500
# remove
# Iteration 909 / 1500
# add
# Iteration 910 / 1500
# remove
# Iteration 911 / 1500
# add
# Iteration 912 / 1500
# remove
# Iteration 913 / 1500
# change_type
# Iteration 914 / 1500
# change_type
# Iteration 915 / 1500
# remove
# Iteration 916 / 1500
# change_type
# Iteration 917 / 1500
# remove
# Iteration 918 / 1500
# remove
# Iteration 919 / 1500
# add
# Iteration 920 / 1500
# remove
# Iteration 921 / 1500
# add
# Iteration 922 / 1500
# remove
# Iteration 923 / 1500
# remove
# Iteration 924 / 1500
# remove
# Iteration 925 / 1500
# remove
# Iteration 926 / 1500
# remove
# Iteration 927 / 1500
# remove
# Iteration 928 / 1500
# add
# Iteration 929 / 1500
# remove
# Iteration 930 / 1500
# add
# Iteration 931 / 1500
# add
# Iteration 932 / 1500
# remove
# Iteration 933 / 1500
# add
# Iteration 934 / 1500
# change_type
# Iteration 935 / 1500
# remove
# Iteration 936 / 1500
# remove
# Iteration 937 / 1500
# change_type
# Iteration 938 / 1500
# add
# Iteration 939 / 1500
# change_type
# Iteration 940 / 1500
# change_type
# Iteration 941 / 1500
# remove
# Iteration 942 / 1500
# remove
# Iteration 943 / 1500
# add
# Iteration 944 / 1500
# add
# Iteration 945 / 1500
# remove
# Iteration 946 / 1500
# change_type
# Iteration 947 / 1500
# remove
# Iteration 948 / 1500
# add
# Iteration 949 / 1500
# change_type
# Iteration 950 / 1500
# remove
# Iteration 951 / 1500
# remove
# Iteration 952 / 1500
# add
# Iteration 953 / 1500
# remove
# Iteration 954 / 1500
# add
# Iteration 955 / 1500
# add
# Iteration 956 / 1500
# add
# Iteration 957 / 1500
# remove
# Iteration 958 / 1500
# add
# Iteration 959 / 1500
# change_type
# Iteration 960 / 1500
# change_type
# Iteration 961 / 1500
# add
# Iteration 962 / 1500
# add
# Iteration 963 / 1500
# change_type
# Iteration 964 / 1500
# remove
# Iteration 965 / 1500
# change_type
# Iteration 966 / 1500
# remove
# Iteration 967 / 1500
# add
# Iteration 968 / 1500
# change_type
# Iteration 969 / 1500
# change_type
# Iteration 970 / 1500
# remove
# Iteration 971 / 1500
# remove
# Iteration 972 / 1500
# remove
# Iteration 973 / 1500
# remove
# Iteration 974 / 1500
# remove
# Iteration 975 / 1500
# add
# Iteration 976 / 1500
# remove
# Iteration 977 / 1500
# change_type
# Iteration 978 / 1500
# change_type
# Iteration 979 / 1500
# remove
# Iteration 980 / 1500
# remove
# Iteration 981 / 1500
# change_type
# Iteration 982 / 1500
# change_type
# Iteration 983 / 1500
# add
# Iteration 984 / 1500
# remove
# Iteration 985 / 1500
# remove
# Iteration 986 / 1500
# change_type
# Iteration 987 / 1500
# change_type
# Iteration 988 / 1500
# change_type
# Iteration 989 / 1500
# add
# Iteration 990 / 1500
# change_type
# Iteration 991 / 1500
# change_type
# Iteration 992 / 1500
# remove
# Iteration 993 / 1500
# remove
# Iteration 994 / 1500
# add
# Iteration 995 / 1500
# remove
# Iteration 996 / 1500
# remove
# Iteration 997 / 1500
# add
# Iteration 998 / 1500
# change_type
# Iteration 999 / 1500
# change_type
# Iteration 1000 / 1500
# add
# Iteration 1001 / 1500
# change_type
# Iteration 1002 / 1500
# remove
# Iteration 1003 / 1500
# change_type
# Iteration 1004 / 1500
# change_type
# Iteration 1005 / 1500
# change_type
# Iteration 1006 / 1500
# add
# Iteration 1007 / 1500
# add
# Iteration 1008 / 1500
# remove
# Iteration 1009 / 1500
# change_type
# Iteration 1010 / 1500
# change_type
# Iteration 1011 / 1500
# add
# Iteration 1012 / 1500
# remove
# Iteration 1013 / 1500
# change_type
# Iteration 1014 / 1500
# change_type
# Iteration 1015 / 1500
# remove
# Iteration 1016 / 1500
# add
# Iteration 1017 / 1500
# change_type
# Iteration 1018 / 1500
# change_type
# Iteration 1019 / 1500
# change_type
# Iteration 1020 / 1500
# remove
# Iteration 1021 / 1500
# change_type
# Iteration 1022 / 1500
# add
# Iteration 1023 / 1500
# remove
# Iteration 1024 / 1500
# change_type
# Iteration 1025 / 1500
# add
# Iteration 1026 / 1500
# change_type
# Iteration 1027 / 1500
# change_type
# Iteration 1028 / 1500
# change_type
# Iteration 1029 / 1500
# add
# Iteration 1030 / 1500
# change_type
# Iteration 1031 / 1500
# remove
# Iteration 1032 / 1500
# change_type
# Iteration 1033 / 1500
# change_type
# Iteration 1034 / 1500
# change_type
# Iteration 1035 / 1500
# remove
# Iteration 1036 / 1500
# add
# Iteration 1037 / 1500
# remove
# Iteration 1038 / 1500
# change_type
# Iteration 1039 / 1500
# change_type
# Iteration 1040 / 1500
# remove
# Iteration 1041 / 1500
# remove
# Iteration 1042 / 1500
# add
# Iteration 1043 / 1500
# remove
# Iteration 1044 / 1500
# change_type
# Iteration 1045 / 1500
# remove
# Iteration 1046 / 1500
# change_type
# Iteration 1047 / 1500
# remove
# Iteration 1048 / 1500
# change_type
# Iteration 1049 / 1500
# remove
# Iteration 1050 / 1500
# remove
# Iteration 1051 / 1500
# change_type
# Iteration 1052 / 1500
# remove
# Iteration 1053 / 1500
# remove
# Iteration 1054 / 1500
# change_type
# Iteration 1055 / 1500
# add
# Iteration 1056 / 1500
# remove
# Iteration 1057 / 1500
# add
# Iteration 1058 / 1500
# remove
# Iteration 1059 / 1500
# add
# Iteration 1060 / 1500
# add
# Iteration 1061 / 1500
# add
# Iteration 1062 / 1500
# add
# Iteration 1063 / 1500
# remove
# Iteration 1064 / 1500
# remove
# Iteration 1065 / 1500
# remove
# Iteration 1066 / 1500
# change_type
# Iteration 1067 / 1500
# remove
# Iteration 1068 / 1500
# change_type
# Iteration 1069 / 1500
# change_type
# Iteration 1070 / 1500
# change_type
# Iteration 1071 / 1500
# change_type
# Iteration 1072 / 1500
# remove
# Iteration 1073 / 1500
# add
# Iteration 1074 / 1500
# change_type
# Iteration 1075 / 1500
# remove
# Iteration 1076 / 1500
# change_type
# Iteration 1077 / 1500
# add
# Iteration 1078 / 1500
# remove
# Iteration 1079 / 1500
# remove
# Iteration 1080 / 1500
# add
# Iteration 1081 / 1500
# remove
# Iteration 1082 / 1500
# add
# Iteration 1083 / 1500
# change_type
# Iteration 1084 / 1500
# add
# Iteration 1085 / 1500
# remove
# Iteration 1086 / 1500
# add
# Iteration 1087 / 1500
# change_type
# Iteration 1088 / 1500
# remove
# Iteration 1089 / 1500
# remove
# Iteration 1090 / 1500
# change_type
# Iteration 1091 / 1500
# remove
# Iteration 1092 / 1500
# add
# Iteration 1093 / 1500
# remove
# Iteration 1094 / 1500
# change_type
# Iteration 1095 / 1500
# add
# Iteration 1096 / 1500
# add
# Iteration 1097 / 1500
# remove
# Iteration 1098 / 1500
# add
# Iteration 1099 / 1500
# remove
# Iteration 1100 / 1500
# add
# Iteration 1101 / 1500
# add
# Iteration 1102 / 1500
# change_type
# Iteration 1103 / 1500
# change_type
# Iteration 1104 / 1500
# remove
# Iteration 1105 / 1500
# remove
# Iteration 1106 / 1500
# change_type
# Iteration 1107 / 1500
# change_type
# Iteration 1108 / 1500
# remove
# Iteration 1109 / 1500
# add
# Iteration 1110 / 1500
# change_type
# Iteration 1111 / 1500
# add
# Iteration 1112 / 1500
# remove
# Iteration 1113 / 1500
# change_type
# Iteration 1114 / 1500
# remove
# Iteration 1115 / 1500
# change_type
# Iteration 1116 / 1500
# add
# Iteration 1117 / 1500
# remove
# Iteration 1118 / 1500
# add
# Iteration 1119 / 1500
# add
# Iteration 1120 / 1500
# add
# Iteration 1121 / 1500
# add
# Iteration 1122 / 1500
# change_type
# Iteration 1123 / 1500
# change_type
# Iteration 1124 / 1500
# add
# Iteration 1125 / 1500
# add
# Iteration 1126 / 1500
# change_type
# Iteration 1127 / 1500
# add
# Iteration 1128 / 1500
# change_type
# Iteration 1129 / 1500
# add
# Iteration 1130 / 1500
# change_type
# Iteration 1131 / 1500
# change_type
# Iteration 1132 / 1500
# change_type
# Iteration 1133 / 1500
# remove
# Iteration 1134 / 1500
# remove
# Iteration 1135 / 1500
# add
# Iteration 1136 / 1500
# remove
# Iteration 1137 / 1500
# change_type
# Iteration 1138 / 1500
# change_type
# Iteration 1139 / 1500
# add
# Iteration 1140 / 1500
# add
# Iteration 1141 / 1500
# change_type
# Iteration 1142 / 1500
# change_type
# Iteration 1143 / 1500
# change_type
# Iteration 1144 / 1500
# remove
# Iteration 1145 / 1500
# add
# Iteration 1146 / 1500
# remove
# Iteration 1147 / 1500
# change_type
# Iteration 1148 / 1500
# change_type
# Iteration 1149 / 1500
# change_type
# Iteration 1150 / 1500
# add
# Iteration 1151 / 1500
# change_type
# Iteration 1152 / 1500
# add
# Iteration 1153 / 1500
# change_type
# Iteration 1154 / 1500
# add
# Iteration 1155 / 1500
# change_type
# Iteration 1156 / 1500
# change_type
# Iteration 1157 / 1500
# change_type
# Iteration 1158 / 1500
# add
# Iteration 1159 / 1500
# change_type
# Iteration 1160 / 1500
# change_type
# Iteration 1161 / 1500
# add
# Iteration 1162 / 1500
# change_type
# Iteration 1163 / 1500
# change_type
# Iteration 1164 / 1500
# change_type
# Iteration 1165 / 1500
# change_type
# Iteration 1166 / 1500
# remove
# Iteration 1167 / 1500
# add
# Iteration 1168 / 1500
# add
# Iteration 1169 / 1500
# change_type
# Iteration 1170 / 1500
# add
# Iteration 1171 / 1500
# add
# Iteration 1172 / 1500
# change_type
# Iteration 1173 / 1500
# add
# Iteration 1174 / 1500
# add
# Iteration 1175 / 1500
# change_type
# Iteration 1176 / 1500
# add
# Iteration 1177 / 1500
# add
# Iteration 1178 / 1500
# add
# Iteration 1179 / 1500
# add
# Iteration 1180 / 1500
# change_type
# Iteration 1181 / 1500
# add
# Iteration 1182 / 1500
# remove
# Iteration 1183 / 1500
# remove
# Iteration 1184 / 1500
# add
# Iteration 1185 / 1500
# change_type
# Iteration 1186 / 1500
# change_type
# Iteration 1187 / 1500
# add
# Iteration 1188 / 1500
# add
# Iteration 1189 / 1500
# add
# Iteration 1190 / 1500
# add
# Iteration 1191 / 1500
# change_type
# Iteration 1192 / 1500
# remove
# Iteration 1193 / 1500
# change_type
# Iteration 1194 / 1500
# add
# Iteration 1195 / 1500
# add
# Iteration 1196 / 1500
# change_type
# Iteration 1197 / 1500
# remove
# Iteration 1198 / 1500
# remove
# Iteration 1199 / 1500
# change_type
# Iteration 1200 / 1500
# remove
# Iteration 1201 / 1500
# remove
# Iteration 1202 / 1500
# remove
# Iteration 1203 / 1500
# add
# Iteration 1204 / 1500
# change_type
# Iteration 1205 / 1500
# change_type
# Iteration 1206 / 1500
# remove
# Iteration 1207 / 1500
# add
# Iteration 1208 / 1500
# remove
# Iteration 1209 / 1500
# add
# Iteration 1210 / 1500
# add
# Iteration 1211 / 1500
# change_type
# Iteration 1212 / 1500
# remove
# Iteration 1213 / 1500
# remove
# Iteration 1214 / 1500
# change_type
# Iteration 1215 / 1500
# add
# Iteration 1216 / 1500
# add
# Iteration 1217 / 1500
# add
# Iteration 1218 / 1500
# remove
# Iteration 1219 / 1500
# remove
# Iteration 1220 / 1500
# change_type
# Iteration 1221 / 1500
# add
# Iteration 1222 / 1500
# add
# Iteration 1223 / 1500
# remove
# Iteration 1224 / 1500
# remove
# Iteration 1225 / 1500
# remove
# Iteration 1226 / 1500
# remove
# Iteration 1227 / 1500
# add
# Iteration 1228 / 1500
# change_type
# Iteration 1229 / 1500
# remove
# Iteration 1230 / 1500
# remove
# Iteration 1231 / 1500
# remove
# Iteration 1232 / 1500
# remove
# Iteration 1233 / 1500
# remove
# Iteration 1234 / 1500
# add
# Iteration 1235 / 1500
# remove
# Iteration 1236 / 1500
# remove
# Iteration 1237 / 1500
# remove
# Iteration 1238 / 1500
# add
# Iteration 1239 / 1500
# remove
# Iteration 1240 / 1500
# add
# Iteration 1241 / 1500
# add
# Iteration 1242 / 1500
# add
# Iteration 1243 / 1500
# add
# Iteration 1244 / 1500
# change_type
# Iteration 1245 / 1500
# remove
# Iteration 1246 / 1500
# add
# Iteration 1247 / 1500
# remove
# Iteration 1248 / 1500
# change_type
# Iteration 1249 / 1500
# change_type
# Iteration 1250 / 1500
# change_type
# Iteration 1251 / 1500
# remove
# Iteration 1252 / 1500
# add
# Iteration 1253 / 1500
# remove
# Iteration 1254 / 1500
# change_type
# Iteration 1255 / 1500
# remove
# Iteration 1256 / 1500
# change_type
# Iteration 1257 / 1500
# remove
# Iteration 1258 / 1500
# change_type
# Iteration 1259 / 1500
# add
# Iteration 1260 / 1500
# add
# Iteration 1261 / 1500
# add
# Iteration 1262 / 1500
# add
# Iteration 1263 / 1500
# change_type
# Iteration 1264 / 1500
# remove
# Iteration 1265 / 1500
# remove
# Iteration 1266 / 1500
# remove
# Iteration 1267 / 1500
# change_type
# Iteration 1268 / 1500
# add
# Iteration 1269 / 1500
# remove
# Iteration 1270 / 1500
# remove
# Iteration 1271 / 1500
# change_type
# Iteration 1272 / 1500
# add
# Iteration 1273 / 1500
# remove
# Iteration 1274 / 1500
# remove
# Iteration 1275 / 1500
# change_type
# Iteration 1276 / 1500
# remove
# Iteration 1277 / 1500
# remove
# Iteration 1278 / 1500
# change_type
# Iteration 1279 / 1500
# remove
# Iteration 1280 / 1500
# change_type
# Iteration 1281 / 1500
# add
# Iteration 1282 / 1500
# add
# Iteration 1283 / 1500
# change_type
# Iteration 1284 / 1500
# remove
# Iteration 1285 / 1500
# change_type
# Iteration 1286 / 1500
# remove
# Iteration 1287 / 1500
# change_type
# Iteration 1288 / 1500
# add
# Iteration 1289 / 1500
# change_type
# Iteration 1290 / 1500
# change_type
# Iteration 1291 / 1500
# remove
# Iteration 1292 / 1500
# add
# Iteration 1293 / 1500
# change_type
# Iteration 1294 / 1500
# remove
# Iteration 1295 / 1500
# change_type
# Iteration 1296 / 1500
# remove
# Iteration 1297 / 1500
# remove
# Iteration 1298 / 1500
# remove
# Iteration 1299 / 1500
# change_type
# Iteration 1300 / 1500
# add
# Iteration 1301 / 1500
# change_type
# Iteration 1302 / 1500
# change_type
# Iteration 1303 / 1500
# add
# Iteration 1304 / 1500
# remove
# Iteration 1305 / 1500
# change_type
# Iteration 1306 / 1500
# change_type
# Iteration 1307 / 1500
# remove
# Iteration 1308 / 1500
# remove
# Iteration 1309 / 1500
# remove
# Iteration 1310 / 1500
# change_type
# Iteration 1311 / 1500
# change_type
# Iteration 1312 / 1500
# change_type
# Iteration 1313 / 1500
# change_type
# Iteration 1314 / 1500
# add
# Iteration 1315 / 1500
# change_type
# Iteration 1316 / 1500
# change_type
# Iteration 1317 / 1500
# remove
# Iteration 1318 / 1500
# remove
# Iteration 1319 / 1500
# change_type
# Iteration 1320 / 1500
# add
# Iteration 1321 / 1500
# remove
# Iteration 1322 / 1500
# remove
# Iteration 1323 / 1500
# add
# Iteration 1324 / 1500
# remove
# Iteration 1325 / 1500
# add
# Iteration 1326 / 1500
# remove
# Iteration 1327 / 1500
# remove
# Iteration 1328 / 1500
# change_type
# Iteration 1329 / 1500
# add
# Iteration 1330 / 1500
# change_type
# Iteration 1331 / 1500
# add
# Iteration 1332 / 1500
# remove
# Iteration 1333 / 1500
# change_type
# Iteration 1334 / 1500
# change_type
# Iteration 1335 / 1500
# remove
# Iteration 1336 / 1500
# add
# Iteration 1337 / 1500
# change_type
# Iteration 1338 / 1500
# change_type
# Iteration 1339 / 1500
# add
# Iteration 1340 / 1500
# add
# Iteration 1341 / 1500
# change_type
# Iteration 1342 / 1500
# remove
# Iteration 1343 / 1500
# add
# Iteration 1344 / 1500
# change_type
# Iteration 1345 / 1500
# remove
# Iteration 1346 / 1500
# add
# Iteration 1347 / 1500
# remove
# Iteration 1348 / 1500
# change_type
# Iteration 1349 / 1500
# change_type
# Iteration 1350 / 1500
# change_type
# Iteration 1351 / 1500
# remove
# Iteration 1352 / 1500
# change_type
# Iteration 1353 / 1500
# remove
# Iteration 1354 / 1500
# remove
# Iteration 1355 / 1500
# change_type
# Iteration 1356 / 1500
# add
# Iteration 1357 / 1500
# remove
# Iteration 1358 / 1500
# remove
# Iteration 1359 / 1500
# add
# Iteration 1360 / 1500
# change_type
# Iteration 1361 / 1500
# change_type
# Iteration 1362 / 1500
# add
# Iteration 1363 / 1500
# remove
# Iteration 1364 / 1500
# add
# Iteration 1365 / 1500
# change_type
# Iteration 1366 / 1500
# add
# Iteration 1367 / 1500
# add
# Iteration 1368 / 1500
# change_type
# Iteration 1369 / 1500
# add
# Iteration 1370 / 1500
# remove
# Iteration 1371 / 1500
# add
# Iteration 1372 / 1500
# remove
# Iteration 1373 / 1500
# remove
# Iteration 1374 / 1500
# add
# Iteration 1375 / 1500
# add
# Iteration 1376 / 1500
# remove
# Iteration 1377 / 1500
# change_type
# Iteration 1378 / 1500
# remove
# Iteration 1379 / 1500
# change_type
# Iteration 1380 / 1500
# remove
# Iteration 1381 / 1500
# add
# Iteration 1382 / 1500
# add
# Iteration 1383 / 1500
# change_type
# Iteration 1384 / 1500
# add
# Iteration 1385 / 1500
# change_type
# Iteration 1386 / 1500
# remove
# Iteration 1387 / 1500
# add
# Iteration 1388 / 1500
# remove
# Iteration 1389 / 1500
# remove
# Iteration 1390 / 1500
# remove
# Iteration 1391 / 1500
# remove
# Iteration 1392 / 1500
# change_type
# Iteration 1393 / 1500
# add
# Iteration 1394 / 1500
# remove
# Iteration 1395 / 1500
# add
# Iteration 1396 / 1500
# add
# Iteration 1397 / 1500
# remove
# Iteration 1398 / 1500
# change_type
# Iteration 1399 / 1500
# add
# Iteration 1400 / 1500
# remove
# Iteration 1401 / 1500
# change_type
# Iteration 1402 / 1500
# change_type
# Iteration 1403 / 1500
# remove
# Iteration 1404 / 1500
# remove
# Iteration 1405 / 1500
# change_type
# Iteration 1406 / 1500
# add
# Iteration 1407 / 1500
# remove
# Iteration 1408 / 1500
# remove
# Iteration 1409 / 1500
# remove
# Iteration 1410 / 1500
# add
# Iteration 1411 / 1500
# remove
# Iteration 1412 / 1500
# add
# Iteration 1413 / 1500
# change_type
# Iteration 1414 / 1500
# add
# Iteration 1415 / 1500
# add
# Iteration 1416 / 1500
# change_type
# Iteration 1417 / 1500
# remove
# Iteration 1418 / 1500
# remove
# Iteration 1419 / 1500
# add
# Iteration 1420 / 1500
# add
# Iteration 1421 / 1500
# change_type
# Iteration 1422 / 1500
# remove
# Iteration 1423 / 1500
# add
# Iteration 1424 / 1500
# add
# Iteration 1425 / 1500
# add
# Iteration 1426 / 1500
# remove
# Iteration 1427 / 1500
# remove
# Iteration 1428 / 1500
# add
# Iteration 1429 / 1500
# remove
# Iteration 1430 / 1500
# change_type
# Iteration 1431 / 1500
# change_type
# Iteration 1432 / 1500
# remove
# Iteration 1433 / 1500
# change_type
# Iteration 1434 / 1500
# add
# Iteration 1435 / 1500
# remove
# Iteration 1436 / 1500
# change_type
# Iteration 1437 / 1500
# change_type
# Iteration 1438 / 1500
# remove
# Iteration 1439 / 1500
# add
# Iteration 1440 / 1500
# remove
# Iteration 1441 / 1500
# change_type
# Iteration 1442 / 1500
# change_type
# Iteration 1443 / 1500
# add
# Iteration 1444 / 1500
# add
# Iteration 1445 / 1500
# change_type
# Iteration 1446 / 1500
# add
# Iteration 1447 / 1500
# remove
# Iteration 1448 / 1500
# add
# Iteration 1449 / 1500
# change_type
# Iteration 1450 / 1500
# remove
# Iteration 1451 / 1500
# remove
# Iteration 1452 / 1500
# add
# Iteration 1453 / 1500
# remove
# Iteration 1454 / 1500
# remove
# Iteration 1455 / 1500
# change_type
# Iteration 1456 / 1500
# remove
# Iteration 1457 / 1500
# add
# Iteration 1458 / 1500
# change_type
# Iteration 1459 / 1500
# add
# Iteration 1460 / 1500
# change_type
# Iteration 1461 / 1500
# change_type
# Iteration 1462 / 1500
# remove
# Iteration 1463 / 1500
# add
# Iteration 1464 / 1500
# add
# Iteration 1465 / 1500
# remove
# Iteration 1466 / 1500
# add
# Iteration 1467 / 1500
# change_type
# Iteration 1468 / 1500
# change_type
# Iteration 1469 / 1500
# remove
# Iteration 1470 / 1500
# change_type
# Iteration 1471 / 1500
# add
# Iteration 1472 / 1500
# remove
# Iteration 1473 / 1500
# change_type
# Iteration 1474 / 1500
# add
# Iteration 1475 / 1500
# change_type
# Iteration 1476 / 1500
# remove
# Iteration 1477 / 1500
# change_type
# Iteration 1478 / 1500
# add
# Iteration 1479 / 1500
# add
# Iteration 1480 / 1500
# add
# Iteration 1481 / 1500
# change_type
# Iteration 1482 / 1500
# change_type
# Iteration 1483 / 1500
# add
# Iteration 1484 / 1500
# change_type
# Iteration 1485 / 1500
# remove
# Iteration 1486 / 1500
# add
# Iteration 1487 / 1500
# remove
# Iteration 1488 / 1500
# change_type
# Iteration 1489 / 1500
# change_type
# Iteration 1490 / 1500
# remove
# Iteration 1491 / 1500
# add
# Iteration 1492 / 1500
# remove
# Iteration 1493 / 1500
# change_type
# Iteration 1494 / 1500
# add
# Iteration 1495 / 1500
# remove
# Iteration 1496 / 1500
# change_type
# Iteration 1497 / 1500
# add
# Iteration 1498 / 1500
# remove
# Iteration 1499 / 1500
# change_type
# Iteration 1500 / 1500
# change_type

# %%
with open("exp_sa_3.pkl", "rb") as f:
    exp_result3 = pickle.load(f)
exp_result3["runtime"]
# Out:
# 2600.5976734161377

# %%
plot_models_fitness(exp_result3["fitness_history"], params["evaluation_weights"])
plot_total_fitness(exp_result3["fitness_history"])
visualize_solution(exp_result3["solution"], G)
# Out:
# C:\Users\tetia\AppData\Local\Temp\ipykernel_27360\777376565.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# - base parameters
# - starting temperature = 10000

# %%
run_sa("configs/params.yaml", "exp_sa_4.pkl", exp_config_file = "configs/experiments/exp_sa_4.yaml")
# Out:
# Iteration 1 / 1500
# add
# Iteration 2 / 1500
# remove
# Iteration 3 / 1500
# add
# Iteration 4 / 1500
# add
# Iteration 5 / 1500
# change_type
# Iteration 6 / 1500
# add
# Iteration 7 / 1500
# remove
# Iteration 8 / 1500
# add
# Iteration 9 / 1500
# change_type
# Iteration 10 / 1500
# remove
# Iteration 11 / 1500
# change_type
# Iteration 12 / 1500
# remove
# Iteration 13 / 1500
# change_type
# Iteration 14 / 1500
# change_type
# Iteration 15 / 1500
# change_type
# Iteration 16 / 1500
# remove
# Iteration 17 / 1500
# remove
# Iteration 18 / 1500
# remove
# Iteration 19 / 1500
# add
# Iteration 20 / 1500
# add
# Iteration 21 / 1500
# remove
# Iteration 22 / 1500
# add
# Iteration 23 / 1500
# change_type
# Iteration 24 / 1500
# remove
# Iteration 25 / 1500
# add
# Iteration 26 / 1500
# remove
# Iteration 27 / 1500
# remove
# Iteration 28 / 1500
# remove
# Iteration 29 / 1500
# change_type
# Iteration 30 / 1500
# add
# Iteration 31 / 1500
# add
# Iteration 32 / 1500
# change_type
# Iteration 33 / 1500
# add
# Iteration 34 / 1500
# remove
# Iteration 35 / 1500
# change_type
# Iteration 36 / 1500
# change_type
# Iteration 37 / 1500
# add
# Iteration 38 / 1500
# remove
# Iteration 39 / 1500
# remove
# Iteration 40 / 1500
# remove
# Iteration 41 / 1500
# change_type
# Iteration 42 / 1500
# add
# Iteration 43 / 1500
# remove
# Iteration 44 / 1500
# remove
# Iteration 45 / 1500
# change_type
# Iteration 46 / 1500
# add
# Iteration 47 / 1500
# add
# Iteration 48 / 1500
# change_type
# Iteration 49 / 1500
# add
# Iteration 50 / 1500
# add
# Iteration 51 / 1500
# change_type
# Iteration 52 / 1500
# add
# Iteration 53 / 1500
# remove
# Iteration 54 / 1500
# change_type
# Iteration 55 / 1500
# add
# Iteration 56 / 1500
# add
# Iteration 57 / 1500
# change_type
# Iteration 58 / 1500
# change_type
# Iteration 59 / 1500
# add
# Iteration 60 / 1500
# change_type
# Iteration 61 / 1500
# remove
# Iteration 62 / 1500
# change_type
# Iteration 63 / 1500
# remove
# Iteration 64 / 1500
# change_type
# Iteration 65 / 1500
# change_type
# Iteration 66 / 1500
# remove
# Iteration 67 / 1500
# change_type
# Iteration 68 / 1500
# remove
# Iteration 69 / 1500
# remove
# Iteration 70 / 1500
# change_type
# Iteration 71 / 1500
# change_type
# Iteration 72 / 1500
# remove
# Iteration 73 / 1500
# change_type
# Iteration 74 / 1500
# remove
# Iteration 75 / 1500
# change_type
# Iteration 76 / 1500
# remove
# Iteration 77 / 1500
# change_type
# Iteration 78 / 1500
# remove
# Iteration 79 / 1500
# change_type
# Iteration 80 / 1500
# remove
# Iteration 81 / 1500
# change_type
# Iteration 82 / 1500
# remove
# Iteration 83 / 1500
# add
# Iteration 84 / 1500
# add
# Iteration 85 / 1500
# change_type
# Iteration 86 / 1500
# add
# Iteration 87 / 1500
# add
# Iteration 88 / 1500
# change_type
# Iteration 89 / 1500
# change_type
# Iteration 90 / 1500
# change_type
# Iteration 91 / 1500
# remove
# Iteration 92 / 1500
# change_type
# Iteration 93 / 1500
# add
# Iteration 94 / 1500
# remove
# Iteration 95 / 1500
# change_type
# Iteration 96 / 1500
# remove
# Iteration 97 / 1500
# add
# Iteration 98 / 1500
# remove
# Iteration 99 / 1500
# add
# Iteration 100 / 1500
# remove
# Iteration 101 / 1500
# change_type
# Iteration 102 / 1500
# change_type
# Iteration 103 / 1500
# add
# Iteration 104 / 1500
# add
# Iteration 105 / 1500
# remove
# Iteration 106 / 1500
# change_type
# Iteration 107 / 1500
# add
# Iteration 108 / 1500
# add
# Iteration 109 / 1500
# remove
# Iteration 110 / 1500
# change_type
# Iteration 111 / 1500
# add
# Iteration 112 / 1500
# add
# Iteration 113 / 1500
# add
# Iteration 114 / 1500
# add
# Iteration 115 / 1500
# change_type
# Iteration 116 / 1500
# remove
# Iteration 117 / 1500
# change_type
# Iteration 118 / 1500
# remove
# Iteration 119 / 1500
# change_type
# Iteration 120 / 1500
# add
# Iteration 121 / 1500
# add
# Iteration 122 / 1500
# add
# Iteration 123 / 1500
# remove
# Iteration 124 / 1500
# remove
# Iteration 125 / 1500
# add
# Iteration 126 / 1500
# remove
# Iteration 127 / 1500
# remove
# Iteration 128 / 1500
# change_type
# Iteration 129 / 1500
# remove
# Iteration 130 / 1500
# change_type
# Iteration 131 / 1500
# change_type
# Iteration 132 / 1500
# change_type
# Iteration 133 / 1500
# add
# Iteration 134 / 1500
# remove
# Iteration 135 / 1500
# add
# Iteration 136 / 1500
# change_type
# Iteration 137 / 1500
# remove
# Iteration 138 / 1500
# change_type
# Iteration 139 / 1500
# change_type
# Iteration 140 / 1500
# change_type
# Iteration 141 / 1500
# change_type
# Iteration 142 / 1500
# change_type
# Iteration 143 / 1500
# add
# Iteration 144 / 1500
# remove
# Iteration 145 / 1500
# change_type
# Iteration 146 / 1500
# remove
# Iteration 147 / 1500
# add
# Iteration 148 / 1500
# remove
# Iteration 149 / 1500
# change_type
# Iteration 150 / 1500
# add
# Iteration 151 / 1500
# remove
# Iteration 152 / 1500
# add
# Iteration 153 / 1500
# add
# Iteration 154 / 1500
# remove
# Iteration 155 / 1500
# add
# Iteration 156 / 1500
# add
# Iteration 157 / 1500
# add
# Iteration 158 / 1500
# add
# Iteration 159 / 1500
# add
# Iteration 160 / 1500
# change_type
# Iteration 161 / 1500
# remove
# Iteration 162 / 1500
# remove
# Iteration 163 / 1500
# change_type
# Iteration 164 / 1500
# remove
# Iteration 165 / 1500
# add
# Iteration 166 / 1500
# change_type
# Iteration 167 / 1500
# add
# Iteration 168 / 1500
# remove
# Iteration 169 / 1500
# add
# Iteration 170 / 1500
# change_type
# Iteration 171 / 1500
# remove
# Iteration 172 / 1500
# add
# Iteration 173 / 1500
# add
# Iteration 174 / 1500
# add
# Iteration 175 / 1500
# remove
# Iteration 176 / 1500
# remove
# Iteration 177 / 1500
# add
# Iteration 178 / 1500
# add
# Iteration 179 / 1500
# add
# Iteration 180 / 1500
# add
# Iteration 181 / 1500
# remove
# Iteration 182 / 1500
# add
# Iteration 183 / 1500
# remove
# Iteration 184 / 1500
# remove
# Iteration 185 / 1500
# change_type
# Iteration 186 / 1500
# add
# Iteration 187 / 1500
# remove
# Iteration 188 / 1500
# change_type
# Iteration 189 / 1500
# change_type
# Iteration 190 / 1500
# remove
# Iteration 191 / 1500
# remove
# Iteration 192 / 1500
# remove
# Iteration 193 / 1500
# change_type
# Iteration 194 / 1500
# add
# Iteration 195 / 1500
# change_type
# Iteration 196 / 1500
# change_type
# Iteration 197 / 1500
# add
# Iteration 198 / 1500
# remove
# Iteration 199 / 1500
# change_type
# Iteration 200 / 1500
# change_type
# Iteration 201 / 1500
# change_type
# Iteration 202 / 1500
# add
# Iteration 203 / 1500
# change_type
# Iteration 204 / 1500
# remove
# Iteration 205 / 1500
# change_type
# Iteration 206 / 1500
# remove
# Iteration 207 / 1500
# add
# Iteration 208 / 1500
# change_type
# Iteration 209 / 1500
# add
# Iteration 210 / 1500
# remove
# Iteration 211 / 1500
# remove
# Iteration 212 / 1500
# change_type
# Iteration 213 / 1500
# change_type
# Iteration 214 / 1500
# change_type
# Iteration 215 / 1500
# remove
# Iteration 216 / 1500
# remove
# Iteration 217 / 1500
# change_type
# Iteration 218 / 1500
# change_type
# Iteration 219 / 1500
# add
# Iteration 220 / 1500
# add
# Iteration 221 / 1500
# change_type
# Iteration 222 / 1500
# change_type
# Iteration 223 / 1500
# add
# Iteration 224 / 1500
# change_type
# Iteration 225 / 1500
# add
# Iteration 226 / 1500
# remove
# Iteration 227 / 1500
# change_type
# Iteration 228 / 1500
# remove
# Iteration 229 / 1500
# add
# Iteration 230 / 1500
# add
# Iteration 231 / 1500
# add
# Iteration 232 / 1500
# add
# Iteration 233 / 1500
# remove
# Iteration 234 / 1500
# remove
# Iteration 235 / 1500
# add
# Iteration 236 / 1500
# add
# Iteration 237 / 1500
# add
# Iteration 238 / 1500
# change_type
# Iteration 239 / 1500
# remove
# Iteration 240 / 1500
# remove
# Iteration 241 / 1500
# add
# Iteration 242 / 1500
# add
# Iteration 243 / 1500
# remove
# Iteration 244 / 1500
# remove
# Iteration 245 / 1500
# remove
# Iteration 246 / 1500
# add
# Iteration 247 / 1500
# add
# Iteration 248 / 1500
# change_type
# Iteration 249 / 1500
# add
# Iteration 250 / 1500
# change_type
# Iteration 251 / 1500
# change_type
# Iteration 252 / 1500
# change_type
# Iteration 253 / 1500
# remove
# Iteration 254 / 1500
# add
# Iteration 255 / 1500
# add
# Iteration 256 / 1500
# remove
# Iteration 257 / 1500
# change_type
# Iteration 258 / 1500
# add
# Iteration 259 / 1500
# remove
# Iteration 260 / 1500
# change_type
# Iteration 261 / 1500
# add
# Iteration 262 / 1500
# remove
# Iteration 263 / 1500
# add
# Iteration 264 / 1500
# remove
# Iteration 265 / 1500
# add
# Iteration 266 / 1500
# change_type
# Iteration 267 / 1500
# add
# Iteration 268 / 1500
# remove
# Iteration 269 / 1500
# add
# Iteration 270 / 1500
# change_type
# Iteration 271 / 1500
# remove
# Iteration 272 / 1500
# remove
# Iteration 273 / 1500
# remove
# Iteration 274 / 1500
# change_type
# Iteration 275 / 1500
# add
# Iteration 276 / 1500
# remove
# Iteration 277 / 1500
# remove
# Iteration 278 / 1500
# add
# Iteration 279 / 1500
# add
# Iteration 280 / 1500
# add
# Iteration 281 / 1500
# remove
# Iteration 282 / 1500
# change_type
# Iteration 283 / 1500
# change_type
# Iteration 284 / 1500
# remove
# Iteration 285 / 1500
# add
# Iteration 286 / 1500
# add
# Iteration 287 / 1500
# remove
# Iteration 288 / 1500
# change_type
# Iteration 289 / 1500
# add
# Iteration 290 / 1500
# change_type
# Iteration 291 / 1500
# add
# Iteration 292 / 1500
# add
# Iteration 293 / 1500
# add
# Iteration 294 / 1500
# add
# Iteration 295 / 1500
# remove
# Iteration 296 / 1500
# change_type
# Iteration 297 / 1500
# change_type
# Iteration 298 / 1500
# remove
# Iteration 299 / 1500
# change_type
# Iteration 300 / 1500
# remove
# Iteration 301 / 1500
# add
# Iteration 302 / 1500
# add
# Iteration 303 / 1500
# change_type
# Iteration 304 / 1500
# change_type
# Iteration 305 / 1500
# change_type
# Iteration 306 / 1500
# change_type
# Iteration 307 / 1500
# change_type
# Iteration 308 / 1500
# change_type
# Iteration 309 / 1500
# remove
# Iteration 310 / 1500
# add
# Iteration 311 / 1500
# remove
# Iteration 312 / 1500
# add
# Iteration 313 / 1500
# change_type
# Iteration 314 / 1500
# remove
# Iteration 315 / 1500
# add
# Iteration 316 / 1500
# change_type
# Iteration 317 / 1500
# add
# Iteration 318 / 1500
# add
# Iteration 319 / 1500
# remove
# Iteration 320 / 1500
# change_type
# Iteration 321 / 1500
# remove
# Iteration 322 / 1500
# remove
# Iteration 323 / 1500
# add
# Iteration 324 / 1500
# add
# Iteration 325 / 1500
# remove
# Iteration 326 / 1500
# remove
# Iteration 327 / 1500
# change_type
# Iteration 328 / 1500
# remove
# Iteration 329 / 1500
# remove
# Iteration 330 / 1500
# add
# Iteration 331 / 1500
# remove
# Iteration 332 / 1500
# add
# Iteration 333 / 1500
# remove
# Iteration 334 / 1500
# remove
# Iteration 335 / 1500
# remove
# Iteration 336 / 1500
# remove
# Iteration 337 / 1500
# change_type
# Iteration 338 / 1500
# change_type
# Iteration 339 / 1500
# change_type
# Iteration 340 / 1500
# add
# Iteration 341 / 1500
# add
# Iteration 342 / 1500
# change_type
# Iteration 343 / 1500
# add
# Iteration 344 / 1500
# change_type
# Iteration 345 / 1500
# remove
# Iteration 346 / 1500
# add
# Iteration 347 / 1500
# change_type
# Iteration 348 / 1500
# remove
# Iteration 349 / 1500
# add
# Iteration 350 / 1500
# add
# Iteration 351 / 1500
# change_type
# Iteration 352 / 1500
# change_type
# Iteration 353 / 1500
# change_type
# Iteration 354 / 1500
# change_type
# Iteration 355 / 1500
# change_type
# Iteration 356 / 1500
# add
# Iteration 357 / 1500
# add
# Iteration 358 / 1500
# add
# Iteration 359 / 1500
# add
# Iteration 360 / 1500
# add
# Iteration 361 / 1500
# add
# Iteration 362 / 1500
# change_type
# Iteration 363 / 1500
# change_type
# Iteration 364 / 1500
# remove
# Iteration 365 / 1500
# change_type
# Iteration 366 / 1500
# add
# Iteration 367 / 1500
# add
# Iteration 368 / 1500
# change_type
# Iteration 369 / 1500
# remove
# Iteration 370 / 1500
# remove
# Iteration 371 / 1500
# add
# Iteration 372 / 1500
# add
# Iteration 373 / 1500
# add
# Iteration 374 / 1500
# add
# Iteration 375 / 1500
# change_type
# Iteration 376 / 1500
# remove
# Iteration 377 / 1500
# change_type
# Iteration 378 / 1500
# change_type
# Iteration 379 / 1500
# add
# Iteration 380 / 1500
# change_type
# Iteration 381 / 1500
# add
# Iteration 382 / 1500
# add
# Iteration 383 / 1500
# add
# Iteration 384 / 1500
# add
# Iteration 385 / 1500
# add
# Iteration 386 / 1500
# add
# Iteration 387 / 1500
# add
# Iteration 388 / 1500
# remove
# Iteration 389 / 1500
# remove
# Iteration 390 / 1500
# add
# Iteration 391 / 1500
# add
# Iteration 392 / 1500
# change_type
# Iteration 393 / 1500
# add
# Iteration 394 / 1500
# remove
# Iteration 395 / 1500
# change_type
# Iteration 396 / 1500
# change_type
# Iteration 397 / 1500
# change_type
# Iteration 398 / 1500
# change_type
# Iteration 399 / 1500
# add
# Iteration 400 / 1500
# remove
# Iteration 401 / 1500
# remove
# Iteration 402 / 1500
# add
# Iteration 403 / 1500
# remove
# Iteration 404 / 1500
# add
# Iteration 405 / 1500
# add
# Iteration 406 / 1500
# remove
# Iteration 407 / 1500
# change_type
# Iteration 408 / 1500
# remove
# Iteration 409 / 1500
# remove
# Iteration 410 / 1500
# remove
# Iteration 411 / 1500
# add
# Iteration 412 / 1500
# remove
# Iteration 413 / 1500
# add
# Iteration 414 / 1500
# remove
# Iteration 415 / 1500
# change_type
# Iteration 416 / 1500
# change_type
# Iteration 417 / 1500
# change_type
# Iteration 418 / 1500
# change_type
# Iteration 419 / 1500
# change_type
# Iteration 420 / 1500
# change_type
# Iteration 421 / 1500
# remove
# Iteration 422 / 1500
# remove
# Iteration 423 / 1500
# remove
# Iteration 424 / 1500
# add
# Iteration 425 / 1500
# change_type
# Iteration 426 / 1500
# remove
# Iteration 427 / 1500
# add
# Iteration 428 / 1500
# add
# Iteration 429 / 1500
# add
# Iteration 430 / 1500
# remove
# Iteration 431 / 1500
# remove
# Iteration 432 / 1500
# change_type
# Iteration 433 / 1500
# add
# Iteration 434 / 1500
# add
# Iteration 435 / 1500
# change_type
# Iteration 436 / 1500
# change_type
# Iteration 437 / 1500
# add
# Iteration 438 / 1500
# remove
# Iteration 439 / 1500
# change_type
# Iteration 440 / 1500
# change_type
# Iteration 441 / 1500
# add
# Iteration 442 / 1500
# add
# Iteration 443 / 1500
# remove
# Iteration 444 / 1500
# add
# Iteration 445 / 1500
# remove
# Iteration 446 / 1500
# change_type
# Iteration 447 / 1500
# remove
# Iteration 448 / 1500
# add
# Iteration 449 / 1500
# add
# Iteration 450 / 1500
# add
# Iteration 451 / 1500
# add
# Iteration 452 / 1500
# add
# Iteration 453 / 1500
# change_type
# Iteration 454 / 1500
# change_type
# Iteration 455 / 1500
# remove
# Iteration 456 / 1500
# remove
# Iteration 457 / 1500
# remove
# Iteration 458 / 1500
# remove
# Iteration 459 / 1500
# add
# Iteration 460 / 1500
# remove
# Iteration 461 / 1500
# add
# Iteration 462 / 1500
# change_type
# Iteration 463 / 1500
# add
# Iteration 464 / 1500
# add
# Iteration 465 / 1500
# remove
# Iteration 466 / 1500
# change_type
# Iteration 467 / 1500
# remove
# Iteration 468 / 1500
# remove
# Iteration 469 / 1500
# remove
# Iteration 470 / 1500
# remove
# Iteration 471 / 1500
# add
# Iteration 472 / 1500
# add
# Iteration 473 / 1500
# add
# Iteration 474 / 1500
# remove
# Iteration 475 / 1500
# change_type
# Iteration 476 / 1500
# change_type
# Iteration 477 / 1500
# remove
# Iteration 478 / 1500
# change_type
# Iteration 479 / 1500
# add
# Iteration 480 / 1500
# add
# Iteration 481 / 1500
# remove
# Iteration 482 / 1500
# add
# Iteration 483 / 1500
# add
# Iteration 484 / 1500
# add
# Iteration 485 / 1500
# change_type
# Iteration 486 / 1500
# change_type
# Iteration 487 / 1500
# change_type
# Iteration 488 / 1500
# remove
# Iteration 489 / 1500
# add
# Iteration 490 / 1500
# remove
# Iteration 491 / 1500
# remove
# Iteration 492 / 1500
# remove
# Iteration 493 / 1500
# remove
# Iteration 494 / 1500
# remove
# Iteration 495 / 1500
# add
# Iteration 496 / 1500
# add
# Iteration 497 / 1500
# remove
# Iteration 498 / 1500
# add
# Iteration 499 / 1500
# change_type
# Iteration 500 / 1500
# remove
# Iteration 501 / 1500
# add
# Iteration 502 / 1500
# remove
# Iteration 503 / 1500
# add
# Iteration 504 / 1500
# change_type
# Iteration 505 / 1500
# remove
# Iteration 506 / 1500
# change_type
# Iteration 507 / 1500
# change_type
# Iteration 508 / 1500
# remove
# Iteration 509 / 1500
# remove
# Iteration 510 / 1500
# remove
# Iteration 511 / 1500
# add
# Iteration 512 / 1500
# remove
# Iteration 513 / 1500
# change_type
# Iteration 514 / 1500
# remove
# Iteration 515 / 1500
# remove
# Iteration 516 / 1500
# add
# Iteration 517 / 1500
# remove
# Iteration 518 / 1500
# change_type
# Iteration 519 / 1500
# remove
# Iteration 520 / 1500
# add
# Iteration 521 / 1500
# remove
# Iteration 522 / 1500
# change_type
# Iteration 523 / 1500
# remove
# Iteration 524 / 1500
# remove
# Iteration 525 / 1500
# add
# Iteration 526 / 1500
# remove
# Iteration 527 / 1500
# add
# Iteration 528 / 1500
# add
# Iteration 529 / 1500
# change_type
# Iteration 530 / 1500
# change_type
# Iteration 531 / 1500
# remove
# Iteration 532 / 1500
# add
# Iteration 533 / 1500
# change_type
# Iteration 534 / 1500
# remove
# Iteration 535 / 1500
# change_type
# Iteration 536 / 1500
# change_type
# Iteration 537 / 1500
# add
# Iteration 538 / 1500
# remove
# Iteration 539 / 1500
# change_type
# Iteration 540 / 1500
# remove
# Iteration 541 / 1500
# add
# Iteration 542 / 1500
# change_type
# Iteration 543 / 1500
# change_type
# Iteration 544 / 1500
# add
# Iteration 545 / 1500
# change_type
# Iteration 546 / 1500
# remove
# Iteration 547 / 1500
# remove
# Iteration 548 / 1500
# add
# Iteration 549 / 1500
# change_type
# Iteration 550 / 1500
# remove
# Iteration 551 / 1500
# add
# Iteration 552 / 1500
# change_type
# Iteration 553 / 1500
# remove
# Iteration 554 / 1500
# change_type
# Iteration 555 / 1500
# remove
# Iteration 556 / 1500
# remove
# Iteration 557 / 1500
# remove
# Iteration 558 / 1500
# remove
# Iteration 559 / 1500
# change_type
# Iteration 560 / 1500
# add
# Iteration 561 / 1500
# remove
# Iteration 562 / 1500
# add
# Iteration 563 / 1500
# add
# Iteration 564 / 1500
# add
# Iteration 565 / 1500
# remove
# Iteration 566 / 1500
# remove
# Iteration 567 / 1500
# add
# Iteration 568 / 1500
# change_type
# Iteration 569 / 1500
# remove
# Iteration 570 / 1500
# add
# Iteration 571 / 1500
# remove
# Iteration 572 / 1500
# remove
# Iteration 573 / 1500
# remove
# Iteration 574 / 1500
# remove
# Iteration 575 / 1500
# remove
# Iteration 576 / 1500
# change_type
# Iteration 577 / 1500
# change_type
# Iteration 578 / 1500
# add
# Iteration 579 / 1500
# change_type
# Iteration 580 / 1500
# remove
# Iteration 581 / 1500
# change_type
# Iteration 582 / 1500
# change_type
# Iteration 583 / 1500
# change_type
# Iteration 584 / 1500
# change_type
# Iteration 585 / 1500
# change_type
# Iteration 586 / 1500
# add
# Iteration 587 / 1500
# remove
# Iteration 588 / 1500
# add
# Iteration 589 / 1500
# change_type
# Iteration 590 / 1500
# remove
# Iteration 591 / 1500
# remove
# Iteration 592 / 1500
# remove
# Iteration 593 / 1500
# remove
# Iteration 594 / 1500
# remove
# Iteration 595 / 1500
# change_type
# Iteration 596 / 1500
# remove
# Iteration 597 / 1500
# remove
# Iteration 598 / 1500
# remove
# Iteration 599 / 1500
# add
# Iteration 600 / 1500
# add
# Iteration 601 / 1500
# change_type
# Iteration 602 / 1500
# change_type
# Iteration 603 / 1500
# remove
# Iteration 604 / 1500
# change_type
# Iteration 605 / 1500
# add
# Iteration 606 / 1500
# change_type
# Iteration 607 / 1500
# add
# Iteration 608 / 1500
# remove
# Iteration 609 / 1500
# change_type
# Iteration 610 / 1500
# change_type
# Iteration 611 / 1500
# remove
# Iteration 612 / 1500
# add
# Iteration 613 / 1500
# add
# Iteration 614 / 1500
# add
# Iteration 615 / 1500
# remove
# Iteration 616 / 1500
# remove
# Iteration 617 / 1500
# change_type
# Iteration 618 / 1500
# remove
# Iteration 619 / 1500
# change_type
# Iteration 620 / 1500
# remove
# Iteration 621 / 1500
# change_type
# Iteration 622 / 1500
# add
# Iteration 623 / 1500
# change_type
# Iteration 624 / 1500
# remove
# Iteration 625 / 1500
# add
# Iteration 626 / 1500
# remove
# Iteration 627 / 1500
# remove
# Iteration 628 / 1500
# change_type
# Iteration 629 / 1500
# add
# Iteration 630 / 1500
# add
# Iteration 631 / 1500
# change_type
# Iteration 632 / 1500
# add
# Iteration 633 / 1500
# change_type
# Iteration 634 / 1500
# add
# Iteration 635 / 1500
# remove
# Iteration 636 / 1500
# remove
# Iteration 637 / 1500
# add
# Iteration 638 / 1500
# add
# Iteration 639 / 1500
# remove
# Iteration 640 / 1500
# change_type
# Iteration 641 / 1500
# change_type
# Iteration 642 / 1500
# add
# Iteration 643 / 1500
# remove
# Iteration 644 / 1500
# add
# Iteration 645 / 1500
# remove
# Iteration 646 / 1500
# change_type
# Iteration 647 / 1500
# add
# Iteration 648 / 1500
# remove
# Iteration 649 / 1500
# change_type
# Iteration 650 / 1500
# change_type
# Iteration 651 / 1500
# change_type
# Iteration 652 / 1500
# remove
# Iteration 653 / 1500
# change_type
# Iteration 654 / 1500
# remove
# Iteration 655 / 1500
# change_type
# Iteration 656 / 1500
# add
# Iteration 657 / 1500
# add
# Iteration 658 / 1500
# change_type
# Iteration 659 / 1500
# add
# Iteration 660 / 1500
# remove
# Iteration 661 / 1500
# change_type
# Iteration 662 / 1500
# remove
# Iteration 663 / 1500
# add
# Iteration 664 / 1500
# remove
# Iteration 665 / 1500
# remove
# Iteration 666 / 1500
# add
# Iteration 667 / 1500
# change_type
# Iteration 668 / 1500
# change_type
# Iteration 669 / 1500
# change_type
# Iteration 670 / 1500
# change_type
# Iteration 671 / 1500
# add
# Iteration 672 / 1500
# change_type
# Iteration 673 / 1500
# change_type
# Iteration 674 / 1500
# change_type
# Iteration 675 / 1500
# change_type
# Iteration 676 / 1500
# change_type
# Iteration 677 / 1500
# change_type
# Iteration 678 / 1500
# add
# Iteration 679 / 1500
# remove
# Iteration 680 / 1500
# add
# Iteration 681 / 1500
# add
# Iteration 682 / 1500
# remove
# Iteration 683 / 1500
# add
# Iteration 684 / 1500
# remove
# Iteration 685 / 1500
# remove
# Iteration 686 / 1500
# remove
# Iteration 687 / 1500
# add
# Iteration 688 / 1500
# change_type
# Iteration 689 / 1500
# change_type
# Iteration 690 / 1500
# change_type
# Iteration 691 / 1500
# remove
# Iteration 692 / 1500
# change_type
# Iteration 693 / 1500
# add
# Iteration 694 / 1500
# change_type
# Iteration 695 / 1500
# add
# Iteration 696 / 1500
# change_type
# Iteration 697 / 1500
# change_type
# Iteration 698 / 1500
# add
# Iteration 699 / 1500
# add
# Iteration 700 / 1500
# change_type
# Iteration 701 / 1500
# add
# Iteration 702 / 1500
# change_type
# Iteration 703 / 1500
# remove
# Iteration 704 / 1500
# add
# Iteration 705 / 1500
# remove
# Iteration 706 / 1500
# change_type
# Iteration 707 / 1500
# remove
# Iteration 708 / 1500
# remove
# Iteration 709 / 1500
# remove
# Iteration 710 / 1500
# remove
# Iteration 711 / 1500
# change_type
# Iteration 712 / 1500
# change_type
# Iteration 713 / 1500
# add
# Iteration 714 / 1500
# add
# Iteration 715 / 1500
# change_type
# Iteration 716 / 1500
# remove
# Iteration 717 / 1500
# change_type
# Iteration 718 / 1500
# add
# Iteration 719 / 1500
# change_type
# Iteration 720 / 1500
# remove
# Iteration 721 / 1500
# add
# Iteration 722 / 1500
# change_type
# Iteration 723 / 1500
# remove
# Iteration 724 / 1500
# change_type
# Iteration 725 / 1500
# add
# Iteration 726 / 1500
# change_type
# Iteration 727 / 1500
# change_type
# Iteration 728 / 1500
# change_type
# Iteration 729 / 1500
# remove
# Iteration 730 / 1500
# add
# Iteration 731 / 1500
# remove
# Iteration 732 / 1500
# change_type
# Iteration 733 / 1500
# add
# Iteration 734 / 1500
# remove
# Iteration 735 / 1500
# change_type
# Iteration 736 / 1500
# remove
# Iteration 737 / 1500
# remove
# Iteration 738 / 1500
# add
# Iteration 739 / 1500
# add
# Iteration 740 / 1500
# change_type
# Iteration 741 / 1500
# remove
# Iteration 742 / 1500
# remove
# Iteration 743 / 1500
# remove
# Iteration 744 / 1500
# add
# Iteration 745 / 1500
# change_type
# Iteration 746 / 1500
# change_type
# Iteration 747 / 1500
# add
# Iteration 748 / 1500
# add
# Iteration 749 / 1500
# add
# Iteration 750 / 1500
# change_type
# Iteration 751 / 1500
# add
# Iteration 752 / 1500
# remove
# Iteration 753 / 1500
# change_type
# Iteration 754 / 1500
# add
# Iteration 755 / 1500
# change_type
# Iteration 756 / 1500
# change_type
# Iteration 757 / 1500
# change_type
# Iteration 758 / 1500
# add
# Iteration 759 / 1500
# add
# Iteration 760 / 1500
# change_type
# Iteration 761 / 1500
# change_type
# Iteration 762 / 1500
# add
# Iteration 763 / 1500
# remove
# Iteration 764 / 1500
# remove
# Iteration 765 / 1500
# remove
# Iteration 766 / 1500
# change_type
# Iteration 767 / 1500
# remove
# Iteration 768 / 1500
# remove
# Iteration 769 / 1500
# change_type
# Iteration 770 / 1500
# remove
# Iteration 771 / 1500
# remove
# Iteration 772 / 1500
# remove
# Iteration 773 / 1500
# remove
# Iteration 774 / 1500
# add
# Iteration 775 / 1500
# change_type
# Iteration 776 / 1500
# change_type
# Iteration 777 / 1500
# remove
# Iteration 778 / 1500
# change_type
# Iteration 779 / 1500
# add
# Iteration 780 / 1500
# remove
# Iteration 781 / 1500
# change_type
# Iteration 782 / 1500
# change_type
# Iteration 783 / 1500
# add
# Iteration 784 / 1500
# add
# Iteration 785 / 1500
# add
# Iteration 786 / 1500
# change_type
# Iteration 787 / 1500
# remove
# Iteration 788 / 1500
# add
# Iteration 789 / 1500
# remove
# Iteration 790 / 1500
# add
# Iteration 791 / 1500
# remove
# Iteration 792 / 1500
# change_type
# Iteration 793 / 1500
# change_type
# Iteration 794 / 1500
# add
# Iteration 795 / 1500
# remove
# Iteration 796 / 1500
# add
# Iteration 797 / 1500
# change_type
# Iteration 798 / 1500
# change_type
# Iteration 799 / 1500
# remove
# Iteration 800 / 1500
# add
# Iteration 801 / 1500
# change_type
# Iteration 802 / 1500
# change_type
# Iteration 803 / 1500
# add
# Iteration 804 / 1500
# add
# Iteration 805 / 1500
# change_type
# Iteration 806 / 1500
# change_type
# Iteration 807 / 1500
# remove
# Iteration 808 / 1500
# add
# Iteration 809 / 1500
# change_type
# Iteration 810 / 1500
# remove
# Iteration 811 / 1500
# add
# Iteration 812 / 1500
# change_type
# Iteration 813 / 1500
# change_type
# Iteration 814 / 1500
# remove
# Iteration 815 / 1500
# add
# Iteration 816 / 1500
# change_type
# Iteration 817 / 1500
# remove
# Iteration 818 / 1500
# remove
# Iteration 819 / 1500
# remove
# Iteration 820 / 1500
# add
# Iteration 821 / 1500
# remove
# Iteration 822 / 1500
# remove
# Iteration 823 / 1500
# change_type
# Iteration 824 / 1500
# change_type
# Iteration 825 / 1500
# remove
# Iteration 826 / 1500
# add
# Iteration 827 / 1500
# remove
# Iteration 828 / 1500
# change_type
# Iteration 829 / 1500
# change_type
# Iteration 830 / 1500
# add
# Iteration 831 / 1500
# add
# Iteration 832 / 1500
# add
# Iteration 833 / 1500
# change_type
# Iteration 834 / 1500
# change_type
# Iteration 835 / 1500
# change_type
# Iteration 836 / 1500
# change_type
# Iteration 837 / 1500
# add
# Iteration 838 / 1500
# remove
# Iteration 839 / 1500
# add
# Iteration 840 / 1500
# change_type
# Iteration 841 / 1500
# change_type
# Iteration 842 / 1500
# change_type
# Iteration 843 / 1500
# remove
# Iteration 844 / 1500
# add
# Iteration 845 / 1500
# change_type
# Iteration 846 / 1500
# remove
# Iteration 847 / 1500
# remove
# Iteration 848 / 1500
# change_type
# Iteration 849 / 1500
# change_type
# Iteration 850 / 1500
# add
# Iteration 851 / 1500
# change_type
# Iteration 852 / 1500
# change_type
# Iteration 853 / 1500
# remove
# Iteration 854 / 1500
# add
# Iteration 855 / 1500
# remove
# Iteration 856 / 1500
# change_type
# Iteration 857 / 1500
# remove
# Iteration 858 / 1500
# add
# Iteration 859 / 1500
# change_type
# Iteration 860 / 1500
# remove
# Iteration 861 / 1500
# add
# Iteration 862 / 1500
# change_type
# Iteration 863 / 1500
# change_type
# Iteration 864 / 1500
# change_type
# Iteration 865 / 1500
# add
# Iteration 866 / 1500
# remove
# Iteration 867 / 1500
# change_type
# Iteration 868 / 1500
# add
# Iteration 869 / 1500
# remove
# Iteration 870 / 1500
# change_type
# Iteration 871 / 1500
# change_type
# Iteration 872 / 1500
# add
# Iteration 873 / 1500
# change_type
# Iteration 874 / 1500
# change_type
# Iteration 875 / 1500
# remove
# Iteration 876 / 1500
# remove
# Iteration 877 / 1500
# add
# Iteration 878 / 1500
# change_type
# Iteration 879 / 1500
# remove
# Iteration 880 / 1500
# add
# Iteration 881 / 1500
# change_type
# Iteration 882 / 1500
# remove
# Iteration 883 / 1500
# change_type
# Iteration 884 / 1500
# remove
# Iteration 885 / 1500
# change_type
# Iteration 886 / 1500
# change_type
# Iteration 887 / 1500
# add
# Iteration 888 / 1500
# add
# Iteration 889 / 1500
# add
# Iteration 890 / 1500
# remove
# Iteration 891 / 1500
# remove
# Iteration 892 / 1500
# add
# Iteration 893 / 1500
# add
# Iteration 894 / 1500
# change_type
# Iteration 895 / 1500
# change_type
# Iteration 896 / 1500
# add
# Iteration 897 / 1500
# remove
# Iteration 898 / 1500
# change_type
# Iteration 899 / 1500
# add
# Iteration 900 / 1500
# add
# Iteration 901 / 1500
# change_type
# Iteration 902 / 1500
# remove
# Iteration 903 / 1500
# remove
# Iteration 904 / 1500
# change_type
# Iteration 905 / 1500
# remove
# Iteration 906 / 1500
# add
# Iteration 907 / 1500
# change_type
# Iteration 908 / 1500
# remove
# Iteration 909 / 1500
# add
# Iteration 910 / 1500
# remove
# Iteration 911 / 1500
# change_type
# Iteration 912 / 1500
# remove
# Iteration 913 / 1500
# change_type
# Iteration 914 / 1500
# remove
# Iteration 915 / 1500
# change_type
# Iteration 916 / 1500
# change_type
# Iteration 917 / 1500
# remove
# Iteration 918 / 1500
# add
# Iteration 919 / 1500
# add
# Iteration 920 / 1500
# add
# Iteration 921 / 1500
# add
# Iteration 922 / 1500
# change_type
# Iteration 923 / 1500
# add
# Iteration 924 / 1500
# add
# Iteration 925 / 1500
# change_type
# Iteration 926 / 1500
# add
# Iteration 927 / 1500
# remove
# Iteration 928 / 1500
# add
# Iteration 929 / 1500
# change_type
# Iteration 930 / 1500
# remove
# Iteration 931 / 1500
# add
# Iteration 932 / 1500
# remove
# Iteration 933 / 1500
# change_type
# Iteration 934 / 1500
# remove
# Iteration 935 / 1500
# add
# Iteration 936 / 1500
# add
# Iteration 937 / 1500
# add
# Iteration 938 / 1500
# remove
# Iteration 939 / 1500
# remove
# Iteration 940 / 1500
# change_type
# Iteration 941 / 1500
# add
# Iteration 942 / 1500
# remove
# Iteration 943 / 1500
# change_type
# Iteration 944 / 1500
# change_type
# Iteration 945 / 1500
# add
# Iteration 946 / 1500
# change_type
# Iteration 947 / 1500
# remove
# Iteration 948 / 1500
# remove
# Iteration 949 / 1500
# remove
# Iteration 950 / 1500
# remove
# Iteration 951 / 1500
# change_type
# Iteration 952 / 1500
# remove
# Iteration 953 / 1500
# remove
# Iteration 954 / 1500
# add
# Iteration 955 / 1500
# add
# Iteration 956 / 1500
# change_type
# Iteration 957 / 1500
# change_type
# Iteration 958 / 1500
# remove
# Iteration 959 / 1500
# remove
# Iteration 960 / 1500
# add
# Iteration 961 / 1500
# add
# Iteration 962 / 1500
# remove
# Iteration 963 / 1500
# add
# Iteration 964 / 1500
# add
# Iteration 965 / 1500
# add
# Iteration 966 / 1500
# add
# Iteration 967 / 1500
# remove
# Iteration 968 / 1500
# remove
# Iteration 969 / 1500
# remove
# Iteration 970 / 1500
# change_type
# Iteration 971 / 1500
# change_type
# Iteration 972 / 1500
# add
# Iteration 973 / 1500
# remove
# Iteration 974 / 1500
# add
# Iteration 975 / 1500
# add
# Iteration 976 / 1500
# change_type
# Iteration 977 / 1500
# change_type
# Iteration 978 / 1500
# change_type
# Iteration 979 / 1500
# change_type
# Iteration 980 / 1500
# add
# Iteration 981 / 1500
# remove
# Iteration 982 / 1500
# add
# Iteration 983 / 1500
# add
# Iteration 984 / 1500
# remove
# Iteration 985 / 1500
# remove
# Iteration 986 / 1500
# remove
# Iteration 987 / 1500
# add
# Iteration 988 / 1500
# remove
# Iteration 989 / 1500
# change_type
# Iteration 990 / 1500
# remove
# Iteration 991 / 1500
# change_type
# Iteration 992 / 1500
# remove
# Iteration 993 / 1500
# add
# Iteration 994 / 1500
# add
# Iteration 995 / 1500
# remove
# Iteration 996 / 1500
# change_type
# Iteration 997 / 1500
# remove
# Iteration 998 / 1500
# change_type
# Iteration 999 / 1500
# remove
# Iteration 1000 / 1500
# change_type
# Iteration 1001 / 1500
# remove
# Iteration 1002 / 1500
# change_type
# Iteration 1003 / 1500
# change_type
# Iteration 1004 / 1500
# add
# Iteration 1005 / 1500
# remove
# Iteration 1006 / 1500
# remove
# Iteration 1007 / 1500
# remove
# Iteration 1008 / 1500
# change_type
# Iteration 1009 / 1500
# change_type
# Iteration 1010 / 1500
# add
# Iteration 1011 / 1500
# add
# Iteration 1012 / 1500
# change_type
# Iteration 1013 / 1500
# remove
# Iteration 1014 / 1500
# change_type
# Iteration 1015 / 1500
# add
# Iteration 1016 / 1500
# remove
# Iteration 1017 / 1500
# remove
# Iteration 1018 / 1500
# change_type
# Iteration 1019 / 1500
# change_type
# Iteration 1020 / 1500
# add
# Iteration 1021 / 1500
# add
# Iteration 1022 / 1500
# add
# Iteration 1023 / 1500
# remove
# Iteration 1024 / 1500
# change_type
# Iteration 1025 / 1500
# remove
# Iteration 1026 / 1500
# change_type
# Iteration 1027 / 1500
# remove
# Iteration 1028 / 1500
# change_type
# Iteration 1029 / 1500
# change_type
# Iteration 1030 / 1500
# add
# Iteration 1031 / 1500
# remove
# Iteration 1032 / 1500
# add
# Iteration 1033 / 1500
# change_type
# Iteration 1034 / 1500
# change_type
# Iteration 1035 / 1500
# remove
# Iteration 1036 / 1500
# remove
# Iteration 1037 / 1500
# change_type
# Iteration 1038 / 1500
# change_type
# Iteration 1039 / 1500
# change_type
# Iteration 1040 / 1500
# change_type
# Iteration 1041 / 1500
# remove
# Iteration 1042 / 1500
# add
# Iteration 1043 / 1500
# add
# Iteration 1044 / 1500
# change_type
# Iteration 1045 / 1500
# change_type
# Iteration 1046 / 1500
# change_type
# Iteration 1047 / 1500
# remove
# Iteration 1048 / 1500
# add
# Iteration 1049 / 1500
# change_type
# Iteration 1050 / 1500
# add
# Iteration 1051 / 1500
# remove
# Iteration 1052 / 1500
# remove
# Iteration 1053 / 1500
# change_type
# Iteration 1054 / 1500
# remove
# Iteration 1055 / 1500
# remove
# Iteration 1056 / 1500
# add
# Iteration 1057 / 1500
# remove
# Iteration 1058 / 1500
# change_type
# Iteration 1059 / 1500
# change_type
# Iteration 1060 / 1500
# add
# Iteration 1061 / 1500
# remove
# Iteration 1062 / 1500
# add
# Iteration 1063 / 1500
# change_type
# Iteration 1064 / 1500
# remove
# Iteration 1065 / 1500
# add
# Iteration 1066 / 1500
# remove
# Iteration 1067 / 1500
# change_type
# Iteration 1068 / 1500
# change_type
# Iteration 1069 / 1500
# remove
# Iteration 1070 / 1500
# remove
# Iteration 1071 / 1500
# add
# Iteration 1072 / 1500
# add
# Iteration 1073 / 1500
# remove
# Iteration 1074 / 1500
# change_type
# Iteration 1075 / 1500
# remove
# Iteration 1076 / 1500
# add
# Iteration 1077 / 1500
# remove
# Iteration 1078 / 1500
# add
# Iteration 1079 / 1500
# change_type
# Iteration 1080 / 1500
# change_type
# Iteration 1081 / 1500
# change_type
# Iteration 1082 / 1500
# add
# Iteration 1083 / 1500
# remove
# Iteration 1084 / 1500
# change_type
# Iteration 1085 / 1500
# change_type
# Iteration 1086 / 1500
# change_type
# Iteration 1087 / 1500
# change_type
# Iteration 1088 / 1500
# change_type
# Iteration 1089 / 1500
# remove
# Iteration 1090 / 1500
# change_type
# Iteration 1091 / 1500
# add
# Iteration 1092 / 1500
# add
# Iteration 1093 / 1500
# change_type
# Iteration 1094 / 1500
# change_type
# Iteration 1095 / 1500
# remove
# Iteration 1096 / 1500
# add
# Iteration 1097 / 1500
# add
# Iteration 1098 / 1500
# add
# Iteration 1099 / 1500
# remove
# Iteration 1100 / 1500
# add
# Iteration 1101 / 1500
# change_type
# Iteration 1102 / 1500
# remove
# Iteration 1103 / 1500
# remove
# Iteration 1104 / 1500
# add
# Iteration 1105 / 1500
# add
# Iteration 1106 / 1500
# change_type
# Iteration 1107 / 1500
# add
# Iteration 1108 / 1500
# add
# Iteration 1109 / 1500
# add
# Iteration 1110 / 1500
# add
# Iteration 1111 / 1500
# change_type
# Iteration 1112 / 1500
# add
# Iteration 1113 / 1500
# change_type
# Iteration 1114 / 1500
# change_type
# Iteration 1115 / 1500
# change_type
# Iteration 1116 / 1500
# change_type
# Iteration 1117 / 1500
# add
# Iteration 1118 / 1500
# change_type
# Iteration 1119 / 1500
# add
# Iteration 1120 / 1500
# add
# Iteration 1121 / 1500
# add
# Iteration 1122 / 1500
# add
# Iteration 1123 / 1500
# add
# Iteration 1124 / 1500
# remove
# Iteration 1125 / 1500
# change_type
# Iteration 1126 / 1500
# add
# Iteration 1127 / 1500
# remove
# Iteration 1128 / 1500
# remove
# Iteration 1129 / 1500
# add
# Iteration 1130 / 1500
# change_type
# Iteration 1131 / 1500
# change_type
# Iteration 1132 / 1500
# add
# Iteration 1133 / 1500
# add
# Iteration 1134 / 1500
# add
# Iteration 1135 / 1500
# change_type
# Iteration 1136 / 1500
# change_type
# Iteration 1137 / 1500
# change_type
# Iteration 1138 / 1500
# remove
# Iteration 1139 / 1500
# change_type
# Iteration 1140 / 1500
# add
# Iteration 1141 / 1500
# remove
# Iteration 1142 / 1500
# remove
# Iteration 1143 / 1500
# remove
# Iteration 1144 / 1500
# add
# Iteration 1145 / 1500
# change_type
# Iteration 1146 / 1500
# add
# Iteration 1147 / 1500
# remove
# Iteration 1148 / 1500
# change_type
# Iteration 1149 / 1500
# add
# Iteration 1150 / 1500
# add
# Iteration 1151 / 1500
# add
# Iteration 1152 / 1500
# add
# Iteration 1153 / 1500
# change_type
# Iteration 1154 / 1500
# change_type
# Iteration 1155 / 1500
# change_type
# Iteration 1156 / 1500
# add
# Iteration 1157 / 1500
# change_type
# Iteration 1158 / 1500
# remove
# Iteration 1159 / 1500
# change_type
# Iteration 1160 / 1500
# add
# Iteration 1161 / 1500
# remove
# Iteration 1162 / 1500
# add
# Iteration 1163 / 1500
# remove
# Iteration 1164 / 1500
# remove
# Iteration 1165 / 1500
# add
# Iteration 1166 / 1500
# remove
# Iteration 1167 / 1500
# add
# Iteration 1168 / 1500
# change_type
# Iteration 1169 / 1500
# remove
# Iteration 1170 / 1500
# change_type
# Iteration 1171 / 1500
# add
# Iteration 1172 / 1500
# remove
# Iteration 1173 / 1500
# remove
# Iteration 1174 / 1500
# change_type
# Iteration 1175 / 1500
# change_type
# Iteration 1176 / 1500
# change_type
# Iteration 1177 / 1500
# remove
# Iteration 1178 / 1500
# change_type
# Iteration 1179 / 1500
# add
# Iteration 1180 / 1500
# remove
# Iteration 1181 / 1500
# remove
# Iteration 1182 / 1500
# change_type
# Iteration 1183 / 1500
# remove
# Iteration 1184 / 1500
# remove
# Iteration 1185 / 1500
# add
# Iteration 1186 / 1500
# remove
# Iteration 1187 / 1500
# remove
# Iteration 1188 / 1500
# add
# Iteration 1189 / 1500
# change_type
# Iteration 1190 / 1500
# remove
# Iteration 1191 / 1500
# change_type
# Iteration 1192 / 1500
# add
# Iteration 1193 / 1500
# remove
# Iteration 1194 / 1500
# remove
# Iteration 1195 / 1500
# change_type
# Iteration 1196 / 1500
# change_type
# Iteration 1197 / 1500
# add
# Iteration 1198 / 1500
# change_type
# Iteration 1199 / 1500
# add
# Iteration 1200 / 1500
# change_type
# Iteration 1201 / 1500
# add
# Iteration 1202 / 1500
# change_type
# Iteration 1203 / 1500
# change_type
# Iteration 1204 / 1500
# change_type
# Iteration 1205 / 1500
# remove
# Iteration 1206 / 1500
# change_type
# Iteration 1207 / 1500
# change_type
# Iteration 1208 / 1500
# remove
# Iteration 1209 / 1500
# add
# Iteration 1210 / 1500
# change_type
# Iteration 1211 / 1500
# change_type
# Iteration 1212 / 1500
# change_type
# Iteration 1213 / 1500
# remove
# Iteration 1214 / 1500
# remove
# Iteration 1215 / 1500
# change_type
# Iteration 1216 / 1500
# remove
# Iteration 1217 / 1500
# change_type
# Iteration 1218 / 1500
# remove
# Iteration 1219 / 1500
# change_type
# Iteration 1220 / 1500
# remove
# Iteration 1221 / 1500
# change_type
# Iteration 1222 / 1500
# add
# Iteration 1223 / 1500
# add
# Iteration 1224 / 1500
# add
# Iteration 1225 / 1500
# change_type
# Iteration 1226 / 1500
# change_type
# Iteration 1227 / 1500
# change_type
# Iteration 1228 / 1500
# add
# Iteration 1229 / 1500
# add
# Iteration 1230 / 1500
# remove
# Iteration 1231 / 1500
# change_type
# Iteration 1232 / 1500
# remove
# Iteration 1233 / 1500
# remove
# Iteration 1234 / 1500
# add
# Iteration 1235 / 1500
# remove
# Iteration 1236 / 1500
# add
# Iteration 1237 / 1500
# change_type
# Iteration 1238 / 1500
# add
# Iteration 1239 / 1500
# remove
# Iteration 1240 / 1500
# change_type
# Iteration 1241 / 1500
# add
# Iteration 1242 / 1500
# remove
# Iteration 1243 / 1500
# add
# Iteration 1244 / 1500
# change_type
# Iteration 1245 / 1500
# add
# Iteration 1246 / 1500
# change_type
# Iteration 1247 / 1500
# add
# Iteration 1248 / 1500
# remove
# Iteration 1249 / 1500
# change_type
# Iteration 1250 / 1500
# change_type
# Iteration 1251 / 1500
# change_type
# Iteration 1252 / 1500
# remove
# Iteration 1253 / 1500
# remove
# Iteration 1254 / 1500
# add
# Iteration 1255 / 1500
# remove
# Iteration 1256 / 1500
# change_type
# Iteration 1257 / 1500
# add
# Iteration 1258 / 1500
# change_type
# Iteration 1259 / 1500
# change_type
# Iteration 1260 / 1500
# change_type
# Iteration 1261 / 1500
# change_type
# Iteration 1262 / 1500
# change_type
# Iteration 1263 / 1500
# change_type
# Iteration 1264 / 1500
# change_type
# Iteration 1265 / 1500
# add
# Iteration 1266 / 1500
# add
# Iteration 1267 / 1500
# change_type
# Iteration 1268 / 1500
# change_type
# Iteration 1269 / 1500
# add
# Iteration 1270 / 1500
# remove
# Iteration 1271 / 1500
# remove
# Iteration 1272 / 1500
# change_type
# Iteration 1273 / 1500
# add
# Iteration 1274 / 1500
# change_type
# Iteration 1275 / 1500
# add
# Iteration 1276 / 1500
# remove
# Iteration 1277 / 1500
# remove
# Iteration 1278 / 1500
# add
# Iteration 1279 / 1500
# change_type
# Iteration 1280 / 1500
# remove
# Iteration 1281 / 1500
# add
# Iteration 1282 / 1500
# add
# Iteration 1283 / 1500
# change_type
# Iteration 1284 / 1500
# change_type
# Iteration 1285 / 1500
# remove
# Iteration 1286 / 1500
# add
# Iteration 1287 / 1500
# add
# Iteration 1288 / 1500
# remove
# Iteration 1289 / 1500
# add
# Iteration 1290 / 1500
# add
# Iteration 1291 / 1500
# add
# Iteration 1292 / 1500
# change_type
# Iteration 1293 / 1500
# add
# Iteration 1294 / 1500
# add
# Iteration 1295 / 1500
# add
# Iteration 1296 / 1500
# add
# Iteration 1297 / 1500
# add
# Iteration 1298 / 1500
# change_type
# Iteration 1299 / 1500
# add
# Iteration 1300 / 1500
# remove
# Iteration 1301 / 1500
# remove
# Iteration 1302 / 1500
# add
# Iteration 1303 / 1500
# remove
# Iteration 1304 / 1500
# add
# Iteration 1305 / 1500
# change_type
# Iteration 1306 / 1500
# change_type
# Iteration 1307 / 1500
# change_type
# Iteration 1308 / 1500
# remove
# Iteration 1309 / 1500
# add
# Iteration 1310 / 1500
# change_type
# Iteration 1311 / 1500
# change_type
# Iteration 1312 / 1500
# add
# Iteration 1313 / 1500
# change_type
# Iteration 1314 / 1500
# remove
# Iteration 1315 / 1500
# add
# Iteration 1316 / 1500
# add
# Iteration 1317 / 1500
# change_type
# Iteration 1318 / 1500
# change_type
# Iteration 1319 / 1500
# remove
# Iteration 1320 / 1500
# add
# Iteration 1321 / 1500
# change_type
# Iteration 1322 / 1500
# remove
# Iteration 1323 / 1500
# remove
# Iteration 1324 / 1500
# add
# Iteration 1325 / 1500
# change_type
# Iteration 1326 / 1500
# change_type
# Iteration 1327 / 1500
# remove
# Iteration 1328 / 1500
# change_type
# Iteration 1329 / 1500
# change_type
# Iteration 1330 / 1500
# remove
# Iteration 1331 / 1500
# add
# Iteration 1332 / 1500
# add
# Iteration 1333 / 1500
# change_type
# Iteration 1334 / 1500
# add
# Iteration 1335 / 1500
# add
# Iteration 1336 / 1500
# remove
# Iteration 1337 / 1500
# remove
# Iteration 1338 / 1500
# change_type
# Iteration 1339 / 1500
# add
# Iteration 1340 / 1500
# add
# Iteration 1341 / 1500
# change_type
# Iteration 1342 / 1500
# add
# Iteration 1343 / 1500
# remove
# Iteration 1344 / 1500
# change_type
# Iteration 1345 / 1500
# change_type
# Iteration 1346 / 1500
# remove
# Iteration 1347 / 1500
# remove
# Iteration 1348 / 1500
# add
# Iteration 1349 / 1500
# add
# Iteration 1350 / 1500
# remove
# Iteration 1351 / 1500
# change_type
# Iteration 1352 / 1500
# change_type
# Iteration 1353 / 1500
# change_type
# Iteration 1354 / 1500
# change_type
# Iteration 1355 / 1500
# remove
# Iteration 1356 / 1500
# remove
# Iteration 1357 / 1500
# add
# Iteration 1358 / 1500
# remove
# Iteration 1359 / 1500
# add
# Iteration 1360 / 1500
# change_type
# Iteration 1361 / 1500
# add
# Iteration 1362 / 1500
# change_type
# Iteration 1363 / 1500
# add
# Iteration 1364 / 1500
# change_type
# Iteration 1365 / 1500
# change_type
# Iteration 1366 / 1500
# change_type
# Iteration 1367 / 1500
# change_type
# Iteration 1368 / 1500
# add
# Iteration 1369 / 1500
# change_type
# Iteration 1370 / 1500
# add
# Iteration 1371 / 1500
# add
# Iteration 1372 / 1500
# add
# Iteration 1373 / 1500
# change_type
# Iteration 1374 / 1500
# change_type
# Iteration 1375 / 1500
# add
# Iteration 1376 / 1500
# change_type
# Iteration 1377 / 1500
# add
# Iteration 1378 / 1500
# remove
# Iteration 1379 / 1500
# change_type
# Iteration 1380 / 1500
# change_type
# Iteration 1381 / 1500
# change_type
# Iteration 1382 / 1500
# change_type
# Iteration 1383 / 1500
# add
# Iteration 1384 / 1500
# add
# Iteration 1385 / 1500
# remove
# Iteration 1386 / 1500
# change_type
# Iteration 1387 / 1500
# change_type
# Iteration 1388 / 1500
# add
# Iteration 1389 / 1500
# change_type
# Iteration 1390 / 1500
# change_type
# Iteration 1391 / 1500
# add
# Iteration 1392 / 1500
# change_type
# Iteration 1393 / 1500
# remove
# Iteration 1394 / 1500
# remove
# Iteration 1395 / 1500
# add
# Iteration 1396 / 1500
# change_type
# Iteration 1397 / 1500
# change_type
# Iteration 1398 / 1500
# remove
# Iteration 1399 / 1500
# add
# Iteration 1400 / 1500
# remove
# Iteration 1401 / 1500
# change_type
# Iteration 1402 / 1500
# add
# Iteration 1403 / 1500
# remove
# Iteration 1404 / 1500
# add
# Iteration 1405 / 1500
# change_type
# Iteration 1406 / 1500
# change_type
# Iteration 1407 / 1500
# change_type
# Iteration 1408 / 1500
# change_type
# Iteration 1409 / 1500
# add
# Iteration 1410 / 1500
# add
# Iteration 1411 / 1500
# add
# Iteration 1412 / 1500
# change_type
# Iteration 1413 / 1500
# change_type
# Iteration 1414 / 1500
# remove
# Iteration 1415 / 1500
# add
# Iteration 1416 / 1500
# remove
# Iteration 1417 / 1500
# change_type
# Iteration 1418 / 1500
# remove
# Iteration 1419 / 1500
# remove
# Iteration 1420 / 1500
# change_type
# Iteration 1421 / 1500
# remove
# Iteration 1422 / 1500
# change_type
# Iteration 1423 / 1500
# add
# Iteration 1424 / 1500
# remove
# Iteration 1425 / 1500
# change_type
# Iteration 1426 / 1500
# remove
# Iteration 1427 / 1500
# add
# Iteration 1428 / 1500
# add
# Iteration 1429 / 1500
# change_type
# Iteration 1430 / 1500
# change_type
# Iteration 1431 / 1500
# change_type
# Iteration 1432 / 1500
# add
# Iteration 1433 / 1500
# remove
# Iteration 1434 / 1500
# remove
# Iteration 1435 / 1500
# add
# Iteration 1436 / 1500
# add
# Iteration 1437 / 1500
# add
# Iteration 1438 / 1500
# change_type
# Iteration 1439 / 1500
# remove
# Iteration 1440 / 1500
# remove
# Iteration 1441 / 1500
# change_type
# Iteration 1442 / 1500
# change_type
# Iteration 1443 / 1500
# remove
# Iteration 1444 / 1500
# remove
# Iteration 1445 / 1500
# change_type
# Iteration 1446 / 1500
# remove
# Iteration 1447 / 1500
# change_type
# Iteration 1448 / 1500
# change_type
# Iteration 1449 / 1500
# add
# Iteration 1450 / 1500
# remove
# Iteration 1451 / 1500
# change_type
# Iteration 1452 / 1500
# remove
# Iteration 1453 / 1500
# add
# Iteration 1454 / 1500
# change_type
# Iteration 1455 / 1500
# add
# Iteration 1456 / 1500
# add
# Iteration 1457 / 1500
# add
# Iteration 1458 / 1500
# add
# Iteration 1459 / 1500
# change_type
# Iteration 1460 / 1500
# change_type
# Iteration 1461 / 1500
# add
# Iteration 1462 / 1500
# remove
# Iteration 1463 / 1500
# remove
# Iteration 1464 / 1500
# change_type
# Iteration 1465 / 1500
# change_type
# Iteration 1466 / 1500
# add
# Iteration 1467 / 1500
# remove
# Iteration 1468 / 1500
# change_type
# Iteration 1469 / 1500
# remove
# Iteration 1470 / 1500
# change_type
# Iteration 1471 / 1500
# add
# Iteration 1472 / 1500
# remove
# Iteration 1473 / 1500
# change_type
# Iteration 1474 / 1500
# add
# Iteration 1475 / 1500
# add
# Iteration 1476 / 1500
# add
# Iteration 1477 / 1500
# remove
# Iteration 1478 / 1500
# remove
# Iteration 1479 / 1500
# remove
# Iteration 1480 / 1500
# change_type
# Iteration 1481 / 1500
# change_type
# Iteration 1482 / 1500
# remove
# Iteration 1483 / 1500
# remove
# Iteration 1484 / 1500
# change_type
# Iteration 1485 / 1500
# remove
# Iteration 1486 / 1500
# change_type
# Iteration 1487 / 1500
# add
# Iteration 1488 / 1500
# change_type
# Iteration 1489 / 1500
# add
# Iteration 1490 / 1500
# remove
# Iteration 1491 / 1500
# remove
# Iteration 1492 / 1500
# add
# Iteration 1493 / 1500
# add
# Iteration 1494 / 1500
# add
# Iteration 1495 / 1500
# remove
# Iteration 1496 / 1500
# remove
# Iteration 1497 / 1500
# change_type
# Iteration 1498 / 1500
# remove
# Iteration 1499 / 1500
# add
# Iteration 1500 / 1500
# change_type

# %%
with open("exp_sa_4.pkl", "rb") as f:
    exp_result4 = pickle.load(f)
exp_result4["runtime"]
# Out:
# 1046.7988181114197

# %%
plot_models_fitness(exp_result4["fitness_history"], params["evaluation_weights"])
plot_total_fitness(exp_result4["fitness_history"])
visualize_solution(exp_result4["solution"], G)

# %% [markdown]
# ## Experiment 5

# %% [markdown]
# - base parameters
# - city = Kyiv

# %%
run_sa("configs/params.yaml", "exp_sa_5.pkl", exp_config_file = "configs/experiments/exp_sa_5.yaml")
# Out:
# Iteration 1 / 1500
# change_type
# Iteration 2 / 1500
# remove
# Iteration 3 / 1500
# add
# Iteration 4 / 1500
# remove
# Iteration 5 / 1500
# remove
# Iteration 6 / 1500
# change_type
# Iteration 7 / 1500
# remove
# Iteration 8 / 1500
# remove
# Iteration 9 / 1500
# remove
# Iteration 10 / 1500
# remove
# Iteration 11 / 1500
# remove
# Iteration 12 / 1500
# add
# Iteration 13 / 1500
# remove
# Iteration 14 / 1500
# add
# Iteration 15 / 1500
# add
# Iteration 16 / 1500
# remove
# Iteration 17 / 1500
# add
# Iteration 18 / 1500
# change_type
# Iteration 19 / 1500
# remove
# Iteration 20 / 1500
# remove
# Iteration 21 / 1500
# add
# Iteration 22 / 1500
# change_type
# Iteration 23 / 1500
# change_type
# Iteration 24 / 1500
# change_type
# Iteration 25 / 1500
# change_type
# Iteration 26 / 1500
# add
# Iteration 27 / 1500
# remove
# Iteration 28 / 1500
# add
# Iteration 29 / 1500
# remove
# Iteration 30 / 1500
# change_type
# Iteration 31 / 1500
# change_type
# Iteration 32 / 1500
# add
# Iteration 33 / 1500
# change_type
# Iteration 34 / 1500
# add
# Iteration 35 / 1500
# add
# Iteration 36 / 1500
# add
# Iteration 37 / 1500
# add
# Iteration 38 / 1500
# remove
# Iteration 39 / 1500
# change_type
# Iteration 40 / 1500
# remove
# Iteration 41 / 1500
# add
# Iteration 42 / 1500
# add
# Iteration 43 / 1500
# change_type
# Iteration 44 / 1500
# change_type
# Iteration 45 / 1500
# remove
# Iteration 46 / 1500
# change_type
# Iteration 47 / 1500
# change_type
# Iteration 48 / 1500
# remove
# Iteration 49 / 1500
# change_type
# Iteration 50 / 1500
# change_type
# Iteration 51 / 1500
# add
# Iteration 52 / 1500
# add
# Iteration 53 / 1500
# add
# Iteration 54 / 1500
# add
# Iteration 55 / 1500
# remove
# Iteration 56 / 1500
# remove
# Iteration 57 / 1500
# add
# Iteration 58 / 1500
# remove
# Iteration 59 / 1500
# add
# Iteration 60 / 1500
# change_type
# Iteration 61 / 1500
# add
# Iteration 62 / 1500
# change_type
# Iteration 63 / 1500
# remove
# Iteration 64 / 1500
# change_type
# Iteration 65 / 1500
# change_type
# Iteration 66 / 1500
# add
# Iteration 67 / 1500
# change_type
# Iteration 68 / 1500
# add
# Iteration 69 / 1500
# remove
# Iteration 70 / 1500
# add
# Iteration 71 / 1500
# change_type
# Iteration 72 / 1500
# change_type
# Iteration 73 / 1500
# remove
# Iteration 74 / 1500
# add
# Iteration 75 / 1500
# remove
# Iteration 76 / 1500
# change_type
# Iteration 77 / 1500
# change_type
# Iteration 78 / 1500
# change_type
# Iteration 79 / 1500
# change_type
# Iteration 80 / 1500
# remove
# Iteration 81 / 1500
# remove
# Iteration 82 / 1500
# remove
# Iteration 83 / 1500
# remove
# Iteration 84 / 1500
# change_type
# Iteration 85 / 1500
# remove
# Iteration 86 / 1500
# add
# Iteration 87 / 1500
# remove
# Iteration 88 / 1500
# add
# Iteration 89 / 1500
# change_type
# Iteration 90 / 1500
# add
# Iteration 91 / 1500
# remove
# Iteration 92 / 1500
# remove
# Iteration 93 / 1500
# add
# Iteration 94 / 1500
# change_type
# Iteration 95 / 1500
# change_type
# Iteration 96 / 1500
# add
# Iteration 97 / 1500
# change_type
# Iteration 98 / 1500
# change_type
# Iteration 99 / 1500
# remove
# Iteration 100 / 1500
# change_type
# Iteration 101 / 1500
# remove
# Iteration 102 / 1500
# add
# Iteration 103 / 1500
# remove
# Iteration 104 / 1500
# change_type
# Iteration 105 / 1500
# remove
# Iteration 106 / 1500
# change_type
# Iteration 107 / 1500
# add
# Iteration 108 / 1500
# change_type
# Iteration 109 / 1500
# change_type
# Iteration 110 / 1500
# remove
# Iteration 111 / 1500
# remove
# Iteration 112 / 1500
# change_type
# Iteration 113 / 1500
# add
# Iteration 114 / 1500
# add
# Iteration 115 / 1500
# change_type
# Iteration 116 / 1500
# change_type
# Iteration 117 / 1500
# add
# Iteration 118 / 1500
# change_type
# Iteration 119 / 1500
# remove
# Iteration 120 / 1500
# change_type
# Iteration 121 / 1500
# change_type
# Iteration 122 / 1500
# remove
# Iteration 123 / 1500
# remove
# Iteration 124 / 1500
# change_type
# Iteration 125 / 1500
# change_type
# Iteration 126 / 1500
# add
# Iteration 127 / 1500
# remove
# Iteration 128 / 1500
# change_type
# Iteration 129 / 1500
# change_type
# Iteration 130 / 1500
# change_type
# Iteration 131 / 1500
# remove
# Iteration 132 / 1500
# add
# Iteration 133 / 1500
# add
# Iteration 134 / 1500
# add
# Iteration 135 / 1500
# change_type
# Iteration 136 / 1500
# remove
# Iteration 137 / 1500
# remove
# Iteration 138 / 1500
# add
# Iteration 139 / 1500
# change_type
# Iteration 140 / 1500
# remove
# Iteration 141 / 1500
# add
# Iteration 142 / 1500
# add
# Iteration 143 / 1500
# remove
# Iteration 144 / 1500
# add
# Iteration 145 / 1500
# add
# Iteration 146 / 1500
# change_type
# Iteration 147 / 1500
# remove
# Iteration 148 / 1500
# remove
# Iteration 149 / 1500
# remove
# Iteration 150 / 1500
# remove
# Iteration 151 / 1500
# change_type
# Iteration 152 / 1500
# add
# Iteration 153 / 1500
# remove
# Iteration 154 / 1500
# add
# Iteration 155 / 1500
# remove
# Iteration 156 / 1500
# change_type
# Iteration 157 / 1500
# change_type
# Iteration 158 / 1500
# change_type
# Iteration 159 / 1500
# change_type
# Iteration 160 / 1500
# change_type
# Iteration 161 / 1500
# add
# Iteration 162 / 1500
# add
# Iteration 163 / 1500
# change_type
# Iteration 164 / 1500
# remove
# Iteration 165 / 1500
# add
# Iteration 166 / 1500
# remove
# Iteration 167 / 1500
# change_type
# Iteration 168 / 1500
# change_type
# Iteration 169 / 1500
# change_type
# Iteration 170 / 1500
# add
# Iteration 171 / 1500
# add
# Iteration 172 / 1500
# change_type
# Iteration 173 / 1500
# remove
# Iteration 174 / 1500
# add
# Iteration 175 / 1500
# add
# Iteration 176 / 1500
# remove
# Iteration 177 / 1500
# add
# Iteration 178 / 1500
# change_type
# Iteration 179 / 1500
# add
# Iteration 180 / 1500
# remove
# Iteration 181 / 1500
# change_type
# Iteration 182 / 1500
# change_type
# Iteration 183 / 1500
# add
# Iteration 184 / 1500
# add
# Iteration 185 / 1500
# change_type
# Iteration 186 / 1500
# add
# Iteration 187 / 1500
# remove
# Iteration 188 / 1500
# add
# Iteration 189 / 1500
# change_type
# Iteration 190 / 1500
# change_type
# Iteration 191 / 1500
# change_type
# Iteration 192 / 1500
# remove
# Iteration 193 / 1500
# change_type
# Iteration 194 / 1500
# change_type
# Iteration 195 / 1500
# remove
# Iteration 196 / 1500
# change_type
# Iteration 197 / 1500
# add
# Iteration 198 / 1500
# change_type
# Iteration 199 / 1500
# add
# Iteration 200 / 1500
# change_type
# Iteration 201 / 1500
# change_type
# Iteration 202 / 1500
# change_type
# Iteration 203 / 1500
# change_type
# Iteration 204 / 1500
# remove
# Iteration 205 / 1500
# add
# Iteration 206 / 1500
# remove
# Iteration 207 / 1500
# add
# Iteration 208 / 1500
# add
# Iteration 209 / 1500
# add
# Iteration 210 / 1500
# add
# Iteration 211 / 1500
# add
# Iteration 212 / 1500
# change_type
# Iteration 213 / 1500
# add
# Iteration 214 / 1500
# change_type
# Iteration 215 / 1500
# remove
# Iteration 216 / 1500
# remove
# Iteration 217 / 1500
# change_type
# Iteration 218 / 1500
# change_type
# Iteration 219 / 1500
# remove
# Iteration 220 / 1500
# change_type
# Iteration 221 / 1500
# remove
# Iteration 222 / 1500
# add
# Iteration 223 / 1500
# change_type
# Iteration 224 / 1500
# change_type
# Iteration 225 / 1500
# add
# Iteration 226 / 1500
# add
# Iteration 227 / 1500
# remove
# Iteration 228 / 1500
# change_type
# Iteration 229 / 1500
# remove
# Iteration 230 / 1500
# add
# Iteration 231 / 1500
# add
# Iteration 232 / 1500
# remove
# Iteration 233 / 1500
# add
# Iteration 234 / 1500
# remove
# Iteration 235 / 1500
# remove
# Iteration 236 / 1500
# change_type
# Iteration 237 / 1500
# add
# Iteration 238 / 1500
# remove
# Iteration 239 / 1500
# add
# Iteration 240 / 1500
# change_type
# Iteration 241 / 1500
# add
# Iteration 242 / 1500
# change_type
# Iteration 243 / 1500
# change_type
# Iteration 244 / 1500
# remove
# Iteration 245 / 1500
# add
# Iteration 246 / 1500
# change_type
# Iteration 247 / 1500
# add
# Iteration 248 / 1500
# change_type
# Iteration 249 / 1500
# remove
# Iteration 250 / 1500
# change_type
# Iteration 251 / 1500
# add
# Iteration 252 / 1500
# add
# Iteration 253 / 1500
# remove
# Iteration 254 / 1500
# change_type
# Iteration 255 / 1500
# remove
# Iteration 256 / 1500
# remove
# Iteration 257 / 1500
# remove
# Iteration 258 / 1500
# change_type
# Iteration 259 / 1500
# change_type
# Iteration 260 / 1500
# add
# Iteration 261 / 1500
# remove
# Iteration 262 / 1500
# remove
# Iteration 263 / 1500
# change_type
# Iteration 264 / 1500
# remove
# Iteration 265 / 1500
# add
# Iteration 266 / 1500
# remove
# Iteration 267 / 1500
# change_type
# Iteration 268 / 1500
# remove
# Iteration 269 / 1500
# remove
# Iteration 270 / 1500
# remove
# Iteration 271 / 1500
# change_type
# Iteration 272 / 1500
# add
# Iteration 273 / 1500
# change_type
# Iteration 274 / 1500
# add
# Iteration 275 / 1500
# change_type
# Iteration 276 / 1500
# change_type
# Iteration 277 / 1500
# add
# Iteration 278 / 1500
# remove
# Iteration 279 / 1500
# add
# Iteration 280 / 1500
# add
# Iteration 281 / 1500
# remove
# Iteration 282 / 1500
# change_type
# Iteration 283 / 1500
# add
# Iteration 284 / 1500
# change_type
# Iteration 285 / 1500
# change_type
# Iteration 286 / 1500
# add
# Iteration 287 / 1500
# change_type
# Iteration 288 / 1500
# remove
# Iteration 289 / 1500
# remove
# Iteration 290 / 1500
# remove
# Iteration 291 / 1500
# add
# Iteration 292 / 1500
# remove
# Iteration 293 / 1500
# add
# Iteration 294 / 1500
# add
# Iteration 295 / 1500
# change_type
# Iteration 296 / 1500
# remove
# Iteration 297 / 1500
# change_type
# Iteration 298 / 1500
# add
# Iteration 299 / 1500
# add
# Iteration 300 / 1500
# add
# Iteration 301 / 1500
# change_type
# Iteration 302 / 1500
# remove
# Iteration 303 / 1500
# change_type
# Iteration 304 / 1500
# change_type
# Iteration 305 / 1500
# remove
# Iteration 306 / 1500
# remove
# Iteration 307 / 1500
# add
# Iteration 308 / 1500
# change_type
# Iteration 309 / 1500
# remove
# Iteration 310 / 1500
# remove
# Iteration 311 / 1500
# remove
# Iteration 312 / 1500
# change_type
# Iteration 313 / 1500
# change_type
# Iteration 314 / 1500
# add
# Iteration 315 / 1500
# change_type
# Iteration 316 / 1500
# add
# Iteration 317 / 1500
# change_type
# Iteration 318 / 1500
# remove
# Iteration 319 / 1500
# add
# Iteration 320 / 1500
# change_type
# Iteration 321 / 1500
# remove
# Iteration 322 / 1500
# remove
# Iteration 323 / 1500
# change_type
# Iteration 324 / 1500
# add
# Iteration 325 / 1500
# remove
# Iteration 326 / 1500
# add
# Iteration 327 / 1500
# add
# Iteration 328 / 1500
# add
# Iteration 329 / 1500
# change_type
# Iteration 330 / 1500
# remove
# Iteration 331 / 1500
# change_type
# Iteration 332 / 1500
# change_type
# Iteration 333 / 1500
# change_type
# Iteration 334 / 1500
# change_type
# Iteration 335 / 1500
# add
# Iteration 336 / 1500
# add
# Iteration 337 / 1500
# change_type
# Iteration 338 / 1500
# add
# Iteration 339 / 1500
# change_type
# Iteration 340 / 1500
# change_type
# Iteration 341 / 1500
# add
# Iteration 342 / 1500
# change_type
# Iteration 343 / 1500
# remove
# Iteration 344 / 1500
# add
# Iteration 345 / 1500
# remove
# Iteration 346 / 1500
# change_type
# Iteration 347 / 1500
# add
# Iteration 348 / 1500
# change_type
# Iteration 349 / 1500
# add
# Iteration 350 / 1500
# change_type
# Iteration 351 / 1500
# add
# Iteration 352 / 1500
# change_type
# Iteration 353 / 1500
# change_type
# Iteration 354 / 1500
# remove
# Iteration 355 / 1500
# remove
# Iteration 356 / 1500
# add
# Iteration 357 / 1500
# change_type
# Iteration 358 / 1500
# add
# Iteration 359 / 1500
# change_type
# Iteration 360 / 1500
# change_type
# Iteration 361 / 1500
# add
# Iteration 362 / 1500
# add
# Iteration 363 / 1500
# add
# Iteration 364 / 1500
# add
# Iteration 365 / 1500
# change_type
# Iteration 366 / 1500
# change_type
# Iteration 367 / 1500
# add
# Iteration 368 / 1500
# add
# Iteration 369 / 1500
# add
# Iteration 370 / 1500
# remove
# Iteration 371 / 1500
# change_type
# Iteration 372 / 1500
# add
# Iteration 373 / 1500
# change_type
# Iteration 374 / 1500
# add
# Iteration 375 / 1500
# remove
# Iteration 376 / 1500
# add
# Iteration 377 / 1500
# add
# Iteration 378 / 1500
# remove
# Iteration 379 / 1500
# remove
# Iteration 380 / 1500
# change_type
# Iteration 381 / 1500
# change_type
# Iteration 382 / 1500
# add
# Iteration 383 / 1500
# remove
# Iteration 384 / 1500
# change_type
# Iteration 385 / 1500
# remove
# Iteration 386 / 1500
# change_type
# Iteration 387 / 1500
# add
# Iteration 388 / 1500
# remove
# Iteration 389 / 1500
# add
# Iteration 390 / 1500
# remove
# Iteration 391 / 1500
# remove
# Iteration 392 / 1500
# remove
# Iteration 393 / 1500
# remove
# Iteration 394 / 1500
# add
# Iteration 395 / 1500
# add
# Iteration 396 / 1500
# add
# Iteration 397 / 1500
# add
# Iteration 398 / 1500
# change_type
# Iteration 399 / 1500
# add
# Iteration 400 / 1500
# remove
# Iteration 401 / 1500
# add
# Iteration 402 / 1500
# add
# Iteration 403 / 1500
# add
# Iteration 404 / 1500
# add
# Iteration 405 / 1500
# change_type
# Iteration 406 / 1500
# remove
# Iteration 407 / 1500
# remove
# Iteration 408 / 1500
# change_type
# Iteration 409 / 1500
# add
# Iteration 410 / 1500
# remove
# Iteration 411 / 1500
# add
# Iteration 412 / 1500
# remove
# Iteration 413 / 1500
# remove
# Iteration 414 / 1500
# remove
# Iteration 415 / 1500
# change_type
# Iteration 416 / 1500
# remove
# Iteration 417 / 1500
# add
# Iteration 418 / 1500
# change_type
# Iteration 419 / 1500
# remove
# Iteration 420 / 1500
# remove
# Iteration 421 / 1500
# remove
# Iteration 422 / 1500
# add
# Iteration 423 / 1500
# add
# Iteration 424 / 1500
# remove
# Iteration 425 / 1500
# change_type
# Iteration 426 / 1500
# change_type
# Iteration 427 / 1500
# change_type
# Iteration 428 / 1500
# change_type
# Iteration 429 / 1500
# change_type
# Iteration 430 / 1500
# add
# Iteration 431 / 1500
# change_type
# Iteration 432 / 1500
# add
# Iteration 433 / 1500
# add
# Iteration 434 / 1500
# remove
# Iteration 435 / 1500
# change_type
# Iteration 436 / 1500
# add
# Iteration 437 / 1500
# add
# Iteration 438 / 1500
# remove
# Iteration 439 / 1500
# remove
# Iteration 440 / 1500
# add
# Iteration 441 / 1500
# remove
# Iteration 442 / 1500
# change_type
# Iteration 443 / 1500
# change_type
# Iteration 444 / 1500
# add
# Iteration 445 / 1500
# remove
# Iteration 446 / 1500
# change_type
# Iteration 447 / 1500
# add
# Iteration 448 / 1500
# change_type
# Iteration 449 / 1500
# remove
# Iteration 450 / 1500
# remove
# Iteration 451 / 1500
# remove
# Iteration 452 / 1500
# remove
# Iteration 453 / 1500
# remove
# Iteration 454 / 1500
# change_type
# Iteration 455 / 1500
# add
# Iteration 456 / 1500
# remove
# Iteration 457 / 1500
# change_type
# Iteration 458 / 1500
# change_type
# Iteration 459 / 1500
# remove
# Iteration 460 / 1500
# remove
# Iteration 461 / 1500
# remove
# Iteration 462 / 1500
# remove
# Iteration 463 / 1500
# add
# Iteration 464 / 1500
# remove
# Iteration 465 / 1500
# change_type
# Iteration 466 / 1500
# change_type
# Iteration 467 / 1500
# remove
# Iteration 468 / 1500
# change_type
# Iteration 469 / 1500
# change_type
# Iteration 470 / 1500
# remove
# Iteration 471 / 1500
# change_type
# Iteration 472 / 1500
# change_type
# Iteration 473 / 1500
# add
# Iteration 474 / 1500
# remove
# Iteration 475 / 1500
# remove
# Iteration 476 / 1500
# change_type
# Iteration 477 / 1500
# add
# Iteration 478 / 1500
# remove
# Iteration 479 / 1500
# add
# Iteration 480 / 1500
# add
# Iteration 481 / 1500
# remove
# Iteration 482 / 1500
# add
# Iteration 483 / 1500
# add
# Iteration 484 / 1500
# change_type
# Iteration 485 / 1500
# remove
# Iteration 486 / 1500
# add
# Iteration 487 / 1500
# remove
# Iteration 488 / 1500
# change_type
# Iteration 489 / 1500
# add
# Iteration 490 / 1500
# add
# Iteration 491 / 1500
# remove
# Iteration 492 / 1500
# change_type
# Iteration 493 / 1500
# remove
# Iteration 494 / 1500
# remove
# Iteration 495 / 1500
# change_type
# Iteration 496 / 1500
# add
# Iteration 497 / 1500
# remove
# Iteration 498 / 1500
# change_type
# Iteration 499 / 1500
# change_type
# Iteration 500 / 1500
# change_type
# Iteration 501 / 1500
# add
# Iteration 502 / 1500
# add
# Iteration 503 / 1500
# change_type
# Iteration 504 / 1500
# remove
# Iteration 505 / 1500
# change_type
# Iteration 506 / 1500
# add
# Iteration 507 / 1500
# change_type
# Iteration 508 / 1500
# add
# Iteration 509 / 1500
# remove
# Iteration 510 / 1500
# add
# Iteration 511 / 1500
# add
# Iteration 512 / 1500
# remove
# Iteration 513 / 1500
# add
# Iteration 514 / 1500
# change_type
# Iteration 515 / 1500
# remove
# Iteration 516 / 1500
# change_type
# Iteration 517 / 1500
# remove
# Iteration 518 / 1500
# add
# Iteration 519 / 1500
# remove
# Iteration 520 / 1500
# remove
# Iteration 521 / 1500
# remove
# Iteration 522 / 1500
# remove
# Iteration 523 / 1500
# add
# Iteration 524 / 1500
# remove
# Iteration 525 / 1500
# change_type
# Iteration 526 / 1500
# add
# Iteration 527 / 1500
# remove
# Iteration 528 / 1500
# remove
# Iteration 529 / 1500
# add
# Iteration 530 / 1500
# add
# Iteration 531 / 1500
# remove
# Iteration 532 / 1500
# change_type
# Iteration 533 / 1500
# remove
# Iteration 534 / 1500
# remove
# Iteration 535 / 1500
# add
# Iteration 536 / 1500
# remove
# Iteration 537 / 1500
# remove
# Iteration 538 / 1500
# add
# Iteration 539 / 1500
# add
# Iteration 540 / 1500
# add
# Iteration 541 / 1500
# add
# Iteration 542 / 1500
# change_type
# Iteration 543 / 1500
# change_type
# Iteration 544 / 1500
# remove
# Iteration 545 / 1500
# remove
# Iteration 546 / 1500
# add
# Iteration 547 / 1500
# add
# Iteration 548 / 1500
# add
# Iteration 549 / 1500
# remove
# Iteration 550 / 1500
# add
# Iteration 551 / 1500
# add
# Iteration 552 / 1500
# add
# Iteration 553 / 1500
# remove
# Iteration 554 / 1500
# add
# Iteration 555 / 1500
# change_type
# Iteration 556 / 1500
# add
# Iteration 557 / 1500
# remove
# Iteration 558 / 1500
# add
# Iteration 559 / 1500
# add
# Iteration 560 / 1500
# add
# Iteration 561 / 1500
# remove
# Iteration 562 / 1500
# add
# Iteration 563 / 1500
# add
# Iteration 564 / 1500
# change_type
# Iteration 565 / 1500
# add
# Iteration 566 / 1500
# change_type
# Iteration 567 / 1500
# add
# Iteration 568 / 1500
# change_type
# Iteration 569 / 1500
# change_type
# Iteration 570 / 1500
# add
# Iteration 571 / 1500
# change_type
# Iteration 572 / 1500
# change_type
# Iteration 573 / 1500
# add
# Iteration 574 / 1500
# add
# Iteration 575 / 1500
# add
# Iteration 576 / 1500
# remove
# Iteration 577 / 1500
# add
# Iteration 578 / 1500
# add
# Iteration 579 / 1500
# add
# Iteration 580 / 1500
# remove
# Iteration 581 / 1500
# add
# Iteration 582 / 1500
# add
# Iteration 583 / 1500
# change_type
# Iteration 584 / 1500
# remove
# Iteration 585 / 1500
# remove
# Iteration 586 / 1500
# change_type
# Iteration 587 / 1500
# change_type
# Iteration 588 / 1500
# change_type
# Iteration 589 / 1500
# add
# Iteration 590 / 1500
# change_type
# Iteration 591 / 1500
# remove
# Iteration 592 / 1500
# add
# Iteration 593 / 1500
# add
# Iteration 594 / 1500
# change_type
# Iteration 595 / 1500
# add
# Iteration 596 / 1500
# remove
# Iteration 597 / 1500
# remove
# Iteration 598 / 1500
# remove
# Iteration 599 / 1500
# add
# Iteration 600 / 1500
# remove
# Iteration 601 / 1500
# add
# Iteration 602 / 1500
# remove
# Iteration 603 / 1500
# add
# Iteration 604 / 1500
# remove
# Iteration 605 / 1500
# change_type
# Iteration 606 / 1500
# change_type
# Iteration 607 / 1500
# remove
# Iteration 608 / 1500
# change_type
# Iteration 609 / 1500
# change_type
# Iteration 610 / 1500
# add
# Iteration 611 / 1500
# add
# Iteration 612 / 1500
# change_type
# Iteration 613 / 1500
# change_type
# Iteration 614 / 1500
# change_type
# Iteration 615 / 1500
# change_type
# Iteration 616 / 1500
# change_type
# Iteration 617 / 1500
# remove
# Iteration 618 / 1500
# change_type
# Iteration 619 / 1500
# add
# Iteration 620 / 1500
# add
# Iteration 621 / 1500
# remove
# Iteration 622 / 1500
# add
# Iteration 623 / 1500
# remove
# Iteration 624 / 1500
# add
# Iteration 625 / 1500
# add
# Iteration 626 / 1500
# remove
# Iteration 627 / 1500
# remove
# Iteration 628 / 1500
# add
# Iteration 629 / 1500
# change_type
# Iteration 630 / 1500
# remove
# Iteration 631 / 1500
# remove
# Iteration 632 / 1500
# change_type
# Iteration 633 / 1500
# change_type
# Iteration 634 / 1500
# change_type
# Iteration 635 / 1500
# add
# Iteration 636 / 1500
# add
# Iteration 637 / 1500
# change_type
# Iteration 638 / 1500
# add
# Iteration 639 / 1500
# change_type
# Iteration 640 / 1500
# remove
# Iteration 641 / 1500
# change_type
# Iteration 642 / 1500
# change_type
# Iteration 643 / 1500
# remove
# Iteration 644 / 1500
# change_type
# Iteration 645 / 1500
# remove
# Iteration 646 / 1500
# add
# Iteration 647 / 1500
# change_type
# Iteration 648 / 1500
# change_type
# Iteration 649 / 1500
# change_type
# Iteration 650 / 1500
# remove
# Iteration 651 / 1500
# remove
# Iteration 652 / 1500
# remove
# Iteration 653 / 1500
# add
# Iteration 654 / 1500
# remove
# Iteration 655 / 1500
# remove
# Iteration 656 / 1500
# add
# Iteration 657 / 1500
# remove
# Iteration 658 / 1500
# remove
# Iteration 659 / 1500
# add
# Iteration 660 / 1500
# add
# Iteration 661 / 1500
# add
# Iteration 662 / 1500
# change_type
# Iteration 663 / 1500
# add
# Iteration 664 / 1500
# remove
# Iteration 665 / 1500
# change_type
# Iteration 666 / 1500
# add
# Iteration 667 / 1500
# change_type
# Iteration 668 / 1500
# add
# Iteration 669 / 1500
# change_type
# Iteration 670 / 1500
# remove
# Iteration 671 / 1500
# remove
# Iteration 672 / 1500
# change_type
# Iteration 673 / 1500
# remove
# Iteration 674 / 1500
# add
# Iteration 675 / 1500
# add
# Iteration 676 / 1500
# add
# Iteration 677 / 1500
# add
# Iteration 678 / 1500
# add
# Iteration 679 / 1500
# change_type
# Iteration 680 / 1500
# change_type
# Iteration 681 / 1500
# change_type
# Iteration 682 / 1500
# add
# Iteration 683 / 1500
# remove
# Iteration 684 / 1500
# remove
# Iteration 685 / 1500
# change_type
# Iteration 686 / 1500
# remove
# Iteration 687 / 1500
# change_type
# Iteration 688 / 1500
# change_type
# Iteration 689 / 1500
# change_type
# Iteration 690 / 1500
# remove
# Iteration 691 / 1500
# add
# Iteration 692 / 1500
# remove
# Iteration 693 / 1500
# remove
# Iteration 694 / 1500
# add
# Iteration 695 / 1500
# add
# Iteration 696 / 1500
# remove
# Iteration 697 / 1500
# change_type
# Iteration 698 / 1500
# remove
# Iteration 699 / 1500
# add
# Iteration 700 / 1500
# remove
# Iteration 701 / 1500
# remove
# Iteration 702 / 1500
# add
# Iteration 703 / 1500
# add
# Iteration 704 / 1500
# add
# Iteration 705 / 1500
# change_type
# Iteration 706 / 1500
# add
# Iteration 707 / 1500
# add
# Iteration 708 / 1500
# change_type
# Iteration 709 / 1500
# change_type
# Iteration 710 / 1500
# change_type
# Iteration 711 / 1500
# change_type
# Iteration 712 / 1500
# change_type
# Iteration 713 / 1500
# change_type
# Iteration 714 / 1500
# add
# Iteration 715 / 1500
# remove
# Iteration 716 / 1500
# add
# Iteration 717 / 1500
# change_type
# Iteration 718 / 1500
# add
# Iteration 719 / 1500
# change_type
# Iteration 720 / 1500
# add
# Iteration 721 / 1500
# add
# Iteration 722 / 1500
# change_type
# Iteration 723 / 1500
# remove
# Iteration 724 / 1500
# remove
# Iteration 725 / 1500
# change_type
# Iteration 726 / 1500
# add
# Iteration 727 / 1500
# remove
# Iteration 728 / 1500
# add
# Iteration 729 / 1500
# change_type
# Iteration 730 / 1500
# remove
# Iteration 731 / 1500
# change_type
# Iteration 732 / 1500
# change_type
# Iteration 733 / 1500
# change_type
# Iteration 734 / 1500
# change_type
# Iteration 735 / 1500
# change_type
# Iteration 736 / 1500
# add
# Iteration 737 / 1500
# change_type
# Iteration 738 / 1500
# remove
# Iteration 739 / 1500
# remove
# Iteration 740 / 1500
# change_type
# Iteration 741 / 1500
# add
# Iteration 742 / 1500
# remove
# Iteration 743 / 1500
# remove
# Iteration 744 / 1500
# remove
# Iteration 745 / 1500
# change_type
# Iteration 746 / 1500
# add
# Iteration 747 / 1500
# remove
# Iteration 748 / 1500
# add
# Iteration 749 / 1500
# add
# Iteration 750 / 1500
# change_type
# Iteration 751 / 1500
# remove
# Iteration 752 / 1500
# add
# Iteration 753 / 1500
# remove
# Iteration 754 / 1500
# remove
# Iteration 755 / 1500
# change_type
# Iteration 756 / 1500
# change_type
# Iteration 757 / 1500
# change_type
# Iteration 758 / 1500
# remove
# Iteration 759 / 1500
# remove
# Iteration 760 / 1500
# change_type
# Iteration 761 / 1500
# change_type
# Iteration 762 / 1500
# change_type
# Iteration 763 / 1500
# add
# Iteration 764 / 1500
# remove
# Iteration 765 / 1500
# add
# Iteration 766 / 1500
# add
# Iteration 767 / 1500
# remove
# Iteration 768 / 1500
# remove
# Iteration 769 / 1500
# remove
# Iteration 770 / 1500
# remove
# Iteration 771 / 1500
# remove
# Iteration 772 / 1500
# change_type
# Iteration 773 / 1500
# add
# Iteration 774 / 1500
# add
# Iteration 775 / 1500
# add
# Iteration 776 / 1500
# change_type
# Iteration 777 / 1500
# add
# Iteration 778 / 1500
# remove
# Iteration 779 / 1500
# remove
# Iteration 780 / 1500
# change_type
# Iteration 781 / 1500
# change_type
# Iteration 782 / 1500
# remove
# Iteration 783 / 1500
# add
# Iteration 784 / 1500
# remove
# Iteration 785 / 1500
# change_type
# Iteration 786 / 1500
# add
# Iteration 787 / 1500
# add
# Iteration 788 / 1500
# change_type
# Iteration 789 / 1500
# remove
# Iteration 790 / 1500
# remove
# Iteration 791 / 1500
# add
# Iteration 792 / 1500
# change_type
# Iteration 793 / 1500
# add
# Iteration 794 / 1500
# remove
# Iteration 795 / 1500
# add
# Iteration 796 / 1500
# change_type
# Iteration 797 / 1500
# add
# Iteration 798 / 1500
# change_type
# Iteration 799 / 1500
# remove
# Iteration 800 / 1500
# remove
# Iteration 801 / 1500
# remove
# Iteration 802 / 1500
# add
# Iteration 803 / 1500
# add
# Iteration 804 / 1500
# change_type
# Iteration 805 / 1500
# remove
# Iteration 806 / 1500
# change_type
# Iteration 807 / 1500
# change_type
# Iteration 808 / 1500
# remove
# Iteration 809 / 1500
# remove
# Iteration 810 / 1500
# add
# Iteration 811 / 1500
# change_type
# Iteration 812 / 1500
# change_type
# Iteration 813 / 1500
# add
# Iteration 814 / 1500
# remove
# Iteration 815 / 1500
# remove
# Iteration 816 / 1500
# change_type
# Iteration 817 / 1500
# change_type
# Iteration 818 / 1500
# add
# Iteration 819 / 1500
# add
# Iteration 820 / 1500
# remove
# Iteration 821 / 1500
# remove
# Iteration 822 / 1500
# change_type
# Iteration 823 / 1500
# add
# Iteration 824 / 1500
# add
# Iteration 825 / 1500
# add
# Iteration 826 / 1500
# remove
# Iteration 827 / 1500
# add
# Iteration 828 / 1500
# change_type
# Iteration 829 / 1500
# remove
# Iteration 830 / 1500
# change_type
# Iteration 831 / 1500
# change_type
# Iteration 832 / 1500
# remove
# Iteration 833 / 1500
# change_type
# Iteration 834 / 1500
# remove
# Iteration 835 / 1500
# add
# Iteration 836 / 1500
# change_type
# Iteration 837 / 1500
# add
# Iteration 838 / 1500
# change_type
# Iteration 839 / 1500
# add
# Iteration 840 / 1500
# add
# Iteration 841 / 1500
# remove
# Iteration 842 / 1500
# add
# Iteration 843 / 1500
# change_type
# Iteration 844 / 1500
# remove
# Iteration 845 / 1500
# add
# Iteration 846 / 1500
# add
# Iteration 847 / 1500
# remove
# Iteration 848 / 1500
# add
# Iteration 849 / 1500
# add
# Iteration 850 / 1500
# change_type
# Iteration 851 / 1500
# change_type
# Iteration 852 / 1500
# add
# Iteration 853 / 1500
# change_type
# Iteration 854 / 1500
# remove
# Iteration 855 / 1500
# add
# Iteration 856 / 1500
# remove
# Iteration 857 / 1500
# change_type
# Iteration 858 / 1500
# add
# Iteration 859 / 1500
# change_type
# Iteration 860 / 1500
# change_type
# Iteration 861 / 1500
# add
# Iteration 862 / 1500
# remove
# Iteration 863 / 1500
# change_type
# Iteration 864 / 1500
# add
# Iteration 865 / 1500
# change_type
# Iteration 866 / 1500
# change_type
# Iteration 867 / 1500
# change_type
# Iteration 868 / 1500
# add
# Iteration 869 / 1500
# change_type
# Iteration 870 / 1500
# remove
# Iteration 871 / 1500
# remove
# Iteration 872 / 1500
# add
# Iteration 873 / 1500
# change_type
# Iteration 874 / 1500
# add
# Iteration 875 / 1500
# add
# Iteration 876 / 1500
# add
# Iteration 877 / 1500
# add
# Iteration 878 / 1500
# add
# Iteration 879 / 1500
# add
# Iteration 880 / 1500
# add
# Iteration 881 / 1500
# remove
# Iteration 882 / 1500
# add
# Iteration 883 / 1500
# remove
# Iteration 884 / 1500
# change_type
# Iteration 885 / 1500
# add
# Iteration 886 / 1500
# change_type
# Iteration 887 / 1500
# change_type
# Iteration 888 / 1500
# change_type
# Iteration 889 / 1500
# add
# Iteration 890 / 1500
# change_type
# Iteration 891 / 1500
# change_type
# Iteration 892 / 1500
# add
# Iteration 893 / 1500
# add
# Iteration 894 / 1500
# change_type
# Iteration 895 / 1500
# add
# Iteration 896 / 1500
# remove
# Iteration 897 / 1500
# remove
# Iteration 898 / 1500
# add
# Iteration 899 / 1500
# add
# Iteration 900 / 1500
# add
# Iteration 901 / 1500
# remove
# Iteration 902 / 1500
# add
# Iteration 903 / 1500
# add
# Iteration 904 / 1500
# remove
# Iteration 905 / 1500
# add
# Iteration 906 / 1500
# add
# Iteration 907 / 1500
# remove
# Iteration 908 / 1500
# add
# Iteration 909 / 1500
# add
# Iteration 910 / 1500
# change_type
# Iteration 911 / 1500
# add
# Iteration 912 / 1500
# add
# Iteration 913 / 1500
# add
# Iteration 914 / 1500
# remove
# Iteration 915 / 1500
# remove
# Iteration 916 / 1500
# add
# Iteration 917 / 1500
# add
# Iteration 918 / 1500
# change_type
# Iteration 919 / 1500
# remove
# Iteration 920 / 1500
# add
# Iteration 921 / 1500
# remove
# Iteration 922 / 1500
# remove
# Iteration 923 / 1500
# add
# Iteration 924 / 1500
# add
# Iteration 925 / 1500
# add
# Iteration 926 / 1500
# change_type
# Iteration 927 / 1500
# change_type
# Iteration 928 / 1500
# remove
# Iteration 929 / 1500
# remove
# Iteration 930 / 1500
# remove
# Iteration 931 / 1500
# remove
# Iteration 932 / 1500
# add
# Iteration 933 / 1500
# add
# Iteration 934 / 1500
# remove
# Iteration 935 / 1500
# change_type
# Iteration 936 / 1500
# remove
# Iteration 937 / 1500
# change_type
# Iteration 938 / 1500
# add
# Iteration 939 / 1500
# add
# Iteration 940 / 1500
# change_type
# Iteration 941 / 1500
# remove
# Iteration 942 / 1500
# remove
# Iteration 943 / 1500
# change_type
# Iteration 944 / 1500
# add
# Iteration 945 / 1500
# remove
# Iteration 946 / 1500
# remove
# Iteration 947 / 1500
# add
# Iteration 948 / 1500
# add
# Iteration 949 / 1500
# change_type
# Iteration 950 / 1500
# change_type
# Iteration 951 / 1500
# change_type
# Iteration 952 / 1500
# change_type
# Iteration 953 / 1500
# add
# Iteration 954 / 1500
# remove
# Iteration 955 / 1500
# add
# Iteration 956 / 1500
# add
# Iteration 957 / 1500
# add
# Iteration 958 / 1500
# remove
# Iteration 959 / 1500
# change_type
# Iteration 960 / 1500
# remove
# Iteration 961 / 1500
# change_type
# Iteration 962 / 1500
# add
# Iteration 963 / 1500
# change_type
# Iteration 964 / 1500
# remove
# Iteration 965 / 1500
# remove
# Iteration 966 / 1500
# remove
# Iteration 967 / 1500
# add
# Iteration 968 / 1500
# add
# Iteration 969 / 1500
# add
# Iteration 970 / 1500
# remove
# Iteration 971 / 1500
# remove
# Iteration 972 / 1500
# change_type
# Iteration 973 / 1500
# change_type
# Iteration 974 / 1500
# add
# Iteration 975 / 1500
# change_type
# Iteration 976 / 1500
# remove
# Iteration 977 / 1500
# remove
# Iteration 978 / 1500
# change_type
# Iteration 979 / 1500
# remove
# Iteration 980 / 1500
# add
# Iteration 981 / 1500
# change_type
# Iteration 982 / 1500
# add
# Iteration 983 / 1500
# add
# Iteration 984 / 1500
# add
# Iteration 985 / 1500
# add
# Iteration 986 / 1500
# remove
# Iteration 987 / 1500
# add
# Iteration 988 / 1500
# add
# Iteration 989 / 1500
# remove
# Iteration 990 / 1500
# change_type
# Iteration 991 / 1500
# remove
# Iteration 992 / 1500
# change_type
# Iteration 993 / 1500
# remove
# Iteration 994 / 1500
# add
# Iteration 995 / 1500
# change_type
# Iteration 996 / 1500
# remove
# Iteration 997 / 1500
# change_type
# Iteration 998 / 1500
# remove
# Iteration 999 / 1500
# add
# Iteration 1000 / 1500
# change_type
# Iteration 1001 / 1500
# change_type
# Iteration 1002 / 1500
# change_type
# Iteration 1003 / 1500
# remove
# Iteration 1004 / 1500
# change_type
# Iteration 1005 / 1500
# add
# Iteration 1006 / 1500
# change_type
# Iteration 1007 / 1500
# add
# Iteration 1008 / 1500
# change_type
# Iteration 1009 / 1500
# add
# Iteration 1010 / 1500
# remove
# Iteration 1011 / 1500
# remove
# Iteration 1012 / 1500
# remove
# Iteration 1013 / 1500
# remove
# Iteration 1014 / 1500
# add
# Iteration 1015 / 1500
# change_type
# Iteration 1016 / 1500
# remove
# Iteration 1017 / 1500
# change_type
# Iteration 1018 / 1500
# add
# Iteration 1019 / 1500
# add
# Iteration 1020 / 1500
# remove
# Iteration 1021 / 1500
# add
# Iteration 1022 / 1500
# remove
# Iteration 1023 / 1500
# change_type
# Iteration 1024 / 1500
# change_type
# Iteration 1025 / 1500
# remove
# Iteration 1026 / 1500
# remove
# Iteration 1027 / 1500
# add
# Iteration 1028 / 1500
# change_type
# Iteration 1029 / 1500
# add
# Iteration 1030 / 1500
# add
# Iteration 1031 / 1500
# add
# Iteration 1032 / 1500
# remove
# Iteration 1033 / 1500
# change_type
# Iteration 1034 / 1500
# change_type
# Iteration 1035 / 1500
# change_type
# Iteration 1036 / 1500
# add
# Iteration 1037 / 1500
# change_type
# Iteration 1038 / 1500
# add
# Iteration 1039 / 1500
# add
# Iteration 1040 / 1500
# remove
# Iteration 1041 / 1500
# remove
# Iteration 1042 / 1500
# add
# Iteration 1043 / 1500
# change_type
# Iteration 1044 / 1500
# remove
# Iteration 1045 / 1500
# change_type
# Iteration 1046 / 1500
# add
# Iteration 1047 / 1500
# change_type
# Iteration 1048 / 1500
# remove
# Iteration 1049 / 1500
# change_type
# Iteration 1050 / 1500
# remove
# Iteration 1051 / 1500
# remove
# Iteration 1052 / 1500
# add
# Iteration 1053 / 1500
# add
# Iteration 1054 / 1500
# add
# Iteration 1055 / 1500
# change_type
# Iteration 1056 / 1500
# change_type
# Iteration 1057 / 1500
# add
# Iteration 1058 / 1500
# remove
# Iteration 1059 / 1500
# change_type
# Iteration 1060 / 1500
# add
# Iteration 1061 / 1500
# add
# Iteration 1062 / 1500
# remove
# Iteration 1063 / 1500
# change_type
# Iteration 1064 / 1500
# change_type
# Iteration 1065 / 1500
# change_type
# Iteration 1066 / 1500
# remove
# Iteration 1067 / 1500
# change_type
# Iteration 1068 / 1500
# remove
# Iteration 1069 / 1500
# add
# Iteration 1070 / 1500
# remove
# Iteration 1071 / 1500
# add
# Iteration 1072 / 1500
# remove
# Iteration 1073 / 1500
# change_type
# Iteration 1074 / 1500
# add
# Iteration 1075 / 1500
# add
# Iteration 1076 / 1500
# remove
# Iteration 1077 / 1500
# add
# Iteration 1078 / 1500
# add
# Iteration 1079 / 1500
# remove
# Iteration 1080 / 1500
# change_type
# Iteration 1081 / 1500
# add
# Iteration 1082 / 1500
# remove
# Iteration 1083 / 1500
# add
# Iteration 1084 / 1500
# remove
# Iteration 1085 / 1500
# remove
# Iteration 1086 / 1500
# add
# Iteration 1087 / 1500
# remove
# Iteration 1088 / 1500
# change_type
# Iteration 1089 / 1500
# change_type
# Iteration 1090 / 1500
# change_type
# Iteration 1091 / 1500
# change_type
# Iteration 1092 / 1500
# add
# Iteration 1093 / 1500
# add
# Iteration 1094 / 1500
# change_type
# Iteration 1095 / 1500
# add
# Iteration 1096 / 1500
# add
# Iteration 1097 / 1500
# change_type
# Iteration 1098 / 1500
# change_type
# Iteration 1099 / 1500
# change_type
# Iteration 1100 / 1500
# add
# Iteration 1101 / 1500
# add
# Iteration 1102 / 1500
# remove
# Iteration 1103 / 1500
# change_type
# Iteration 1104 / 1500
# remove
# Iteration 1105 / 1500
# add
# Iteration 1106 / 1500
# add
# Iteration 1107 / 1500
# remove
# Iteration 1108 / 1500
# change_type
# Iteration 1109 / 1500
# add
# Iteration 1110 / 1500
# add
# Iteration 1111 / 1500
# change_type
# Iteration 1112 / 1500
# remove
# Iteration 1113 / 1500
# remove
# Iteration 1114 / 1500
# change_type
# Iteration 1115 / 1500
# add
# Iteration 1116 / 1500
# remove
# Iteration 1117 / 1500
# change_type
# Iteration 1118 / 1500
# remove
# Iteration 1119 / 1500
# remove
# Iteration 1120 / 1500
# add
# Iteration 1121 / 1500
# change_type
# Iteration 1122 / 1500
# add
# Iteration 1123 / 1500
# remove
# Iteration 1124 / 1500
# add
# Iteration 1125 / 1500
# remove
# Iteration 1126 / 1500
# remove
# Iteration 1127 / 1500
# add
# Iteration 1128 / 1500
# change_type
# Iteration 1129 / 1500
# change_type
# Iteration 1130 / 1500
# remove
# Iteration 1131 / 1500
# change_type
# Iteration 1132 / 1500
# change_type
# Iteration 1133 / 1500
# remove
# Iteration 1134 / 1500
# change_type
# Iteration 1135 / 1500
# change_type
# Iteration 1136 / 1500
# remove
# Iteration 1137 / 1500
# change_type
# Iteration 1138 / 1500
# change_type
# Iteration 1139 / 1500
# change_type
# Iteration 1140 / 1500
# remove
# Iteration 1141 / 1500
# change_type
# Iteration 1142 / 1500
# change_type
# Iteration 1143 / 1500
# remove
# Iteration 1144 / 1500
# change_type
# Iteration 1145 / 1500
# remove
# Iteration 1146 / 1500
# remove
# Iteration 1147 / 1500
# add
# Iteration 1148 / 1500
# change_type
# Iteration 1149 / 1500
# add
# Iteration 1150 / 1500
# remove
# Iteration 1151 / 1500
# change_type
# Iteration 1152 / 1500
# change_type
# Iteration 1153 / 1500
# change_type
# Iteration 1154 / 1500
# change_type
# Iteration 1155 / 1500
# add
# Iteration 1156 / 1500
# add
# Iteration 1157 / 1500
# remove
# Iteration 1158 / 1500
# remove
# Iteration 1159 / 1500
# add
# Iteration 1160 / 1500
# remove
# Iteration 1161 / 1500
# change_type
# Iteration 1162 / 1500
# remove
# Iteration 1163 / 1500
# remove
# Iteration 1164 / 1500
# remove
# Iteration 1165 / 1500
# add
# Iteration 1166 / 1500
# change_type
# Iteration 1167 / 1500
# remove
# Iteration 1168 / 1500
# add
# Iteration 1169 / 1500
# add
# Iteration 1170 / 1500
# remove
# Iteration 1171 / 1500
# change_type
# Iteration 1172 / 1500
# change_type
# Iteration 1173 / 1500
# remove
# Iteration 1174 / 1500
# change_type
# Iteration 1175 / 1500
# change_type
# Iteration 1176 / 1500
# change_type
# Iteration 1177 / 1500
# change_type
# Iteration 1178 / 1500
# remove
# Iteration 1179 / 1500
# add
# Iteration 1180 / 1500
# remove
# Iteration 1181 / 1500
# remove
# Iteration 1182 / 1500
# add
# Iteration 1183 / 1500
# change_type
# Iteration 1184 / 1500
# add
# Iteration 1185 / 1500
# add
# Iteration 1186 / 1500
# remove
# Iteration 1187 / 1500
# change_type
# Iteration 1188 / 1500
# remove
# Iteration 1189 / 1500
# change_type
# Iteration 1190 / 1500
# add
# Iteration 1191 / 1500
# change_type
# Iteration 1192 / 1500
# change_type
# Iteration 1193 / 1500
# remove
# Iteration 1194 / 1500
# add
# Iteration 1195 / 1500
# add
# Iteration 1196 / 1500
# add
# Iteration 1197 / 1500
# add
# Iteration 1198 / 1500
# remove
# Iteration 1199 / 1500
# change_type
# Iteration 1200 / 1500
# remove
# Iteration 1201 / 1500
# add
# Iteration 1202 / 1500
# add
# Iteration 1203 / 1500
# remove
# Iteration 1204 / 1500
# remove
# Iteration 1205 / 1500
# add
# Iteration 1206 / 1500
# remove
# Iteration 1207 / 1500
# remove
# Iteration 1208 / 1500
# change_type
# Iteration 1209 / 1500
# change_type
# Iteration 1210 / 1500
# change_type
# Iteration 1211 / 1500
# remove
# Iteration 1212 / 1500
# change_type
# Iteration 1213 / 1500
# remove
# Iteration 1214 / 1500
# add
# Iteration 1215 / 1500
# add
# Iteration 1216 / 1500
# change_type
# Iteration 1217 / 1500
# add
# Iteration 1218 / 1500
# change_type
# Iteration 1219 / 1500
# change_type
# Iteration 1220 / 1500
# change_type
# Iteration 1221 / 1500
# add
# Iteration 1222 / 1500
# change_type
# Iteration 1223 / 1500
# add
# Iteration 1224 / 1500
# change_type
# Iteration 1225 / 1500
# add
# Iteration 1226 / 1500
# remove
# Iteration 1227 / 1500
# change_type
# Iteration 1228 / 1500
# change_type
# Iteration 1229 / 1500
# add
# Iteration 1230 / 1500
# add
# Iteration 1231 / 1500
# add
# Iteration 1232 / 1500
# change_type
# Iteration 1233 / 1500
# add
# Iteration 1234 / 1500
# change_type
# Iteration 1235 / 1500
# change_type
# Iteration 1236 / 1500
# remove
# Iteration 1237 / 1500
# remove
# Iteration 1238 / 1500
# add
# Iteration 1239 / 1500
# change_type
# Iteration 1240 / 1500
# change_type
# Iteration 1241 / 1500
# change_type
# Iteration 1242 / 1500
# change_type
# Iteration 1243 / 1500
# change_type
# Iteration 1244 / 1500
# remove
# Iteration 1245 / 1500
# remove
# Iteration 1246 / 1500
# add
# Iteration 1247 / 1500
# change_type
# Iteration 1248 / 1500
# add
# Iteration 1249 / 1500
# remove
# Iteration 1250 / 1500
# remove
# Iteration 1251 / 1500
# change_type
# Iteration 1252 / 1500
# remove
# Iteration 1253 / 1500
# add
# Iteration 1254 / 1500
# change_type
# Iteration 1255 / 1500
# change_type
# Iteration 1256 / 1500
# remove
# Iteration 1257 / 1500
# add
# Iteration 1258 / 1500
# add
# Iteration 1259 / 1500
# change_type
# Iteration 1260 / 1500
# change_type
# Iteration 1261 / 1500
# add
# Iteration 1262 / 1500
# change_type
# Iteration 1263 / 1500
# change_type
# Iteration 1264 / 1500
# add
# Iteration 1265 / 1500
# remove
# Iteration 1266 / 1500
# add
# Iteration 1267 / 1500
# change_type
# Iteration 1268 / 1500
# add
# Iteration 1269 / 1500
# change_type
# Iteration 1270 / 1500
# remove
# Iteration 1271 / 1500
# remove
# Iteration 1272 / 1500
# change_type
# Iteration 1273 / 1500
# add
# Iteration 1274 / 1500
# change_type
# Iteration 1275 / 1500
# add
# Iteration 1276 / 1500
# change_type
# Iteration 1277 / 1500
# change_type
# Iteration 1278 / 1500
# remove
# Iteration 1279 / 1500
# remove
# Iteration 1280 / 1500
# add
# Iteration 1281 / 1500
# add
# Iteration 1282 / 1500
# change_type
# Iteration 1283 / 1500
# remove
# Iteration 1284 / 1500
# add
# Iteration 1285 / 1500
# change_type
# Iteration 1286 / 1500
# change_type
# Iteration 1287 / 1500
# change_type
# Iteration 1288 / 1500
# add
# Iteration 1289 / 1500
# change_type
# Iteration 1290 / 1500
# remove
# Iteration 1291 / 1500
# add
# Iteration 1292 / 1500
# add
# Iteration 1293 / 1500
# remove
# Iteration 1294 / 1500
# remove
# Iteration 1295 / 1500
# add
# Iteration 1296 / 1500
# remove
# Iteration 1297 / 1500
# add
# Iteration 1298 / 1500
# change_type
# Iteration 1299 / 1500
# remove
# Iteration 1300 / 1500
# add
# Iteration 1301 / 1500
# remove
# Iteration 1302 / 1500
# add
# Iteration 1303 / 1500
# add
# Iteration 1304 / 1500
# change_type
# Iteration 1305 / 1500
# change_type
# Iteration 1306 / 1500
# add
# Iteration 1307 / 1500
# remove
# Iteration 1308 / 1500
# remove
# Iteration 1309 / 1500
# add
# Iteration 1310 / 1500
# remove
# Iteration 1311 / 1500
# change_type
# Iteration 1312 / 1500
# add
# Iteration 1313 / 1500
# add
# Iteration 1314 / 1500
# change_type
# Iteration 1315 / 1500
# remove
# Iteration 1316 / 1500
# change_type
# Iteration 1317 / 1500
# add
# Iteration 1318 / 1500
# remove
# Iteration 1319 / 1500
# add
# Iteration 1320 / 1500
# add
# Iteration 1321 / 1500
# add
# Iteration 1322 / 1500
# change_type
# Iteration 1323 / 1500
# change_type
# Iteration 1324 / 1500
# add
# Iteration 1325 / 1500
# change_type
# Iteration 1326 / 1500
# change_type
# Iteration 1327 / 1500
# change_type
# Iteration 1328 / 1500
# remove
# Iteration 1329 / 1500
# add
# Iteration 1330 / 1500
# add
# Iteration 1331 / 1500
# change_type
# Iteration 1332 / 1500
# change_type
# Iteration 1333 / 1500
# remove
# Iteration 1334 / 1500
# add
# Iteration 1335 / 1500
# change_type
# Iteration 1336 / 1500
# change_type
# Iteration 1337 / 1500
# change_type
# Iteration 1338 / 1500
# remove
# Iteration 1339 / 1500
# change_type
# Iteration 1340 / 1500
# change_type
# Iteration 1341 / 1500
# change_type
# Iteration 1342 / 1500
# remove
# Iteration 1343 / 1500
# add
# Iteration 1344 / 1500
# add
# Iteration 1345 / 1500
# remove
# Iteration 1346 / 1500
# remove
# Iteration 1347 / 1500
# add
# Iteration 1348 / 1500
# remove
# Iteration 1349 / 1500
# add
# Iteration 1350 / 1500
# change_type
# Iteration 1351 / 1500
# add
# Iteration 1352 / 1500
# add
# Iteration 1353 / 1500
# change_type
# Iteration 1354 / 1500
# remove
# Iteration 1355 / 1500
# add
# Iteration 1356 / 1500
# add
# Iteration 1357 / 1500
# remove
# Iteration 1358 / 1500
# add
# Iteration 1359 / 1500
# change_type
# Iteration 1360 / 1500
# change_type
# Iteration 1361 / 1500
# add
# Iteration 1362 / 1500
# remove
# Iteration 1363 / 1500
# remove
# Iteration 1364 / 1500
# remove
# Iteration 1365 / 1500
# add
# Iteration 1366 / 1500
# add
# Iteration 1367 / 1500
# change_type
# Iteration 1368 / 1500
# remove
# Iteration 1369 / 1500
# remove
# Iteration 1370 / 1500
# change_type
# Iteration 1371 / 1500
# change_type
# Iteration 1372 / 1500
# remove
# Iteration 1373 / 1500
# remove
# Iteration 1374 / 1500
# add
# Iteration 1375 / 1500
# remove
# Iteration 1376 / 1500
# add
# Iteration 1377 / 1500
# remove
# Iteration 1378 / 1500
# remove
# Iteration 1379 / 1500
# add
# Iteration 1380 / 1500
# add
# Iteration 1381 / 1500
# add
# Iteration 1382 / 1500
# remove
# Iteration 1383 / 1500
# remove
# Iteration 1384 / 1500
# add
# Iteration 1385 / 1500
# remove
# Iteration 1386 / 1500
# remove
# Iteration 1387 / 1500
# remove
# Iteration 1388 / 1500
# add
# Iteration 1389 / 1500
# remove
# Iteration 1390 / 1500
# remove
# Iteration 1391 / 1500
# change_type
# Iteration 1392 / 1500
# change_type
# Iteration 1393 / 1500
# change_type
# Iteration 1394 / 1500
# add
# Iteration 1395 / 1500
# change_type
# Iteration 1396 / 1500
# change_type
# Iteration 1397 / 1500
# change_type
# Iteration 1398 / 1500
# add
# Iteration 1399 / 1500
# add
# Iteration 1400 / 1500
# change_type
# Iteration 1401 / 1500
# remove
# Iteration 1402 / 1500
# remove
# Iteration 1403 / 1500
# remove
# Iteration 1404 / 1500
# remove
# Iteration 1405 / 1500
# remove
# Iteration 1406 / 1500
# add
# Iteration 1407 / 1500
# remove
# Iteration 1408 / 1500
# remove
# Iteration 1409 / 1500
# remove
# Iteration 1410 / 1500
# change_type
# Iteration 1411 / 1500
# add
# Iteration 1412 / 1500
# add
# Iteration 1413 / 1500
# add
# Iteration 1414 / 1500
# add
# Iteration 1415 / 1500
# remove
# Iteration 1416 / 1500
# change_type
# Iteration 1417 / 1500
# add
# Iteration 1418 / 1500
# add
# Iteration 1419 / 1500
# change_type
# Iteration 1420 / 1500
# remove
# Iteration 1421 / 1500
# change_type
# Iteration 1422 / 1500
# change_type
# Iteration 1423 / 1500
# add
# Iteration 1424 / 1500
# add
# Iteration 1425 / 1500
# remove
# Iteration 1426 / 1500
# add
# Iteration 1427 / 1500
# remove
# Iteration 1428 / 1500
# remove
# Iteration 1429 / 1500
# change_type
# Iteration 1430 / 1500
# add
# Iteration 1431 / 1500
# change_type
# Iteration 1432 / 1500
# remove
# Iteration 1433 / 1500
# remove
# Iteration 1434 / 1500
# remove
# Iteration 1435 / 1500
# add
# Iteration 1436 / 1500
# change_type
# Iteration 1437 / 1500
# add
# Iteration 1438 / 1500
# change_type
# Iteration 1439 / 1500
# change_type
# Iteration 1440 / 1500
# remove
# Iteration 1441 / 1500
# remove
# Iteration 1442 / 1500
# change_type
# Iteration 1443 / 1500
# remove
# Iteration 1444 / 1500
# add
# Iteration 1445 / 1500
# add
# Iteration 1446 / 1500
# remove
# Iteration 1447 / 1500
# remove
# Iteration 1448 / 1500
# remove
# Iteration 1449 / 1500
# add
# Iteration 1450 / 1500
# change_type
# Iteration 1451 / 1500
# change_type
# Iteration 1452 / 1500
# change_type
# Iteration 1453 / 1500
# remove
# Iteration 1454 / 1500
# change_type
# Iteration 1455 / 1500
# remove
# Iteration 1456 / 1500
# remove
# Iteration 1457 / 1500
# add
# Iteration 1458 / 1500
# remove
# Iteration 1459 / 1500
# change_type
# Iteration 1460 / 1500
# remove
# Iteration 1461 / 1500
# remove
# Iteration 1462 / 1500
# add
# Iteration 1463 / 1500
# add
# Iteration 1464 / 1500
# add
# Iteration 1465 / 1500
# remove
# Iteration 1466 / 1500
# add
# Iteration 1467 / 1500
# remove
# Iteration 1468 / 1500
# add
# Iteration 1469 / 1500
# remove
# Iteration 1470 / 1500
# remove
# Iteration 1471 / 1500
# add
# Iteration 1472 / 1500
# add
# Iteration 1473 / 1500
# change_type
# Iteration 1474 / 1500
# change_type
# Iteration 1475 / 1500
# change_type
# Iteration 1476 / 1500
# remove
# Iteration 1477 / 1500
# remove
# Iteration 1478 / 1500
# change_type
# Iteration 1479 / 1500
# change_type
# Iteration 1480 / 1500
# remove
# Iteration 1481 / 1500
# add
# Iteration 1482 / 1500
# remove
# Iteration 1483 / 1500
# remove
# Iteration 1484 / 1500
# change_type
# Iteration 1485 / 1500
# remove
# Iteration 1486 / 1500
# remove
# Iteration 1487 / 1500
# change_type
# Iteration 1488 / 1500
# change_type
# Iteration 1489 / 1500
# remove
# Iteration 1490 / 1500
# add
# Iteration 1491 / 1500
# add
# Iteration 1492 / 1500
# add
# Iteration 1493 / 1500
# add
# Iteration 1494 / 1500
# remove
# Iteration 1495 / 1500
# add
# Iteration 1496 / 1500
# remove
# Iteration 1497 / 1500
# add
# Iteration 1498 / 1500
# remove
# Iteration 1499 / 1500
# add
# Iteration 1500 / 1500
# change_type
# C:\Users\tetia\AppData\Local\Temp\ipykernel_9184\2990666065.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))

# %%
with open("exp_sa_5.pkl", "rb") as f:
    exp_result5 = pickle.load(f)
exp_result5["runtime"]
# Out:
# 5435.174190759659

# %%
# plot_models_fitness(exp_result5["fitness_history"], params["evaluation_weights"])
# plot_total_fitness(exp_result5["fitness_history"])
# visualize_solution(exp_result5["solution"], G)

# %% [markdown]
# ## Experiment 6

# %% [markdown]
# - base parameters
# - EV per capita = 0.08

# %%
run_sa("configs/params.yaml", "exp_sa_6.pkl", exp_config_file = "configs/experiments/exp_sa_6.yaml")

# %%
run_sa("configs/params.yaml", "exp.pkl", exp_config_file = None)
# Out:
# Iteration 1 / 15
# change_type
# Iteration 2 / 15
# change_type
# Iteration 3 / 15
# change_type
# Iteration 4 / 15
# add
# Iteration 5 / 15
# add
# Iteration 6 / 15
# add
# Iteration 7 / 15
# add
# Iteration 8 / 15
# add
# Iteration 9 / 15
# remove
# Iteration 10 / 15
# change_type
# Iteration 11 / 15
# add
# Iteration 12 / 15
# add
# Iteration 13 / 15
# change_type
# Iteration 14 / 15
# remove
# Iteration 15 / 15
# add
# C:\Users\tetia\AppData\Local\Temp\ipykernel_9184\777376565.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = {cs_type: plt.cm.get_cmap('plasma')(i / len(unique_cs_types))
